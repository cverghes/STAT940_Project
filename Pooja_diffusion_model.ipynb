# %% [markdown]
# # Preprocess and store the data as npz files (for better training)

# %%
import os
import json
import numpy as np

def preprocess_symbolic_regression(data_folder, output_folder):
    """
    Preprocesses JSON files for symbolic regression and saves the processed data.

    Parameters:
        data_folder (str): Path to the folder containing the train, val, and test subfolders with JSON files.
        output_folder (str): Path to the folder where preprocessed files will be saved.
    """
    os.makedirs(output_folder, exist_ok=True)
    splits = ['train', 'val', 'test']
    max_consts = 0
    
    for split in splits:
        split_folder = os.path.join(data_folder, split)
        output_split_folder = os.path.join(output_folder, split)
        os.makedirs(output_split_folder, exist_ok=True)
        
        files = [f for f in os.listdir(split_folder) if f.endswith('.json') and not f.startswith('properties')]
        X_all, y_all = [], []
        
        # First pass to find the maximum number of constants
        for file in files:
            with open(os.path.join(split_folder, file), 'r') as f:
                data = json.load(f)
                const_value_dict = data.get('const_value_dict', {})
                max_consts = max(max_consts, len(const_value_dict))
        
        # Second pass to process the data
        for file in files:
            with open(os.path.join(split_folder, file), 'r') as f:
                data = json.load(f)
                
                # Variables
                vars_array = np.array([data['points'][f'var_{i}'] for i in range(data['n_vars'])]).T
                
                # Constants (padded with zeros if fewer than max_consts)
                const_value_dict = data.get('const_value_dict', {})
                consts_array = np.zeros((len(vars_array), max_consts))
                consts = list(const_value_dict.values())

                # print(f"File: {file}, Constants: {len(consts)}, Max Constants: {max_consts}")
                
                consts_array[:, :len(consts)] = consts

                # Combine variables and constants
                X = np.hstack([vars_array, consts_array])
                y = np.array(data['points']['target']).reshape(-1, 1)

                print(f"Before preprocessing: {split, X.shape}") 
                
                X_all.append(X)
                y_all.append(y)
        
        # Stack all data for this split
        X_all = np.vstack(X_all)
        y_all = np.vstack(y_all)
        
        # Save preprocessed data
        np.savez_compressed(os.path.join(output_split_folder, f'{split}.npz'), X=X_all, y=y_all)
        print(f"Processed {split} data: {X_all.shape[0]} samples saved.")

# Define input and output folders
data_folder = "data_symbolic_regression"
output_folder = "preprocessed_symbolic_regression"

# Run preprocessing
preprocess_symbolic_regression(data_folder, output_folder)
# Out:
# File: f_473.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_189.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_536.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_166.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_49.json, Constants: 1, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_424.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_8.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_131.json, Constants: 1, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_561.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_648.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_218.json, Constants: 1, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_432.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_598.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_577.json, Constants: 1, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_127.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_465.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_170.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_520.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_609.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_259.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_73.json, Constants: 1, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_737.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_367.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_672.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_388.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_222.json, Constants: 1, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_449.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_24.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_330.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_275.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_625.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_32.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_326.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_633.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_263.json, Constants: 1, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_408.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_65.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_371.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_721.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_234.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_664.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_613.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_243.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_306.json, Constants: 1, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_12.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_185.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_490.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_214.json, Constants: 1, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_644.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_351.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_701.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_428.json, Constants: 1, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_4.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_45.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_582.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_652.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_202.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_717.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_347.json, Constants: 1, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_53.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_594.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_255.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_605.json, Constants: 1, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_310.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_740.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_469.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_193.json, Constants: 1, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_486.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_691.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_384.json, Constants: 1, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_90.json, Constants: 1, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_557.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_107.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_412.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_296.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_629.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_279.json, Constants: 1, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_150.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_500.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_28.json, Constants: 1, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_445.json, Constants: 1, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_280.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_516.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_146.json, Constants: 2, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_453.json, Constants: 1, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_687.json, Constants: 1, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_668.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_392.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_238.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_111.json, Constants: 1, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_86.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_541.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_69.json, Constants: 1, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_404.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_110.json, Constants: 1, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_540.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_87.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_68.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_405.json, Constants: 1, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_686.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_669.json, Constants: 1, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_393.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_239.json, Constants: 1, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_517.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_147.json, Constants: 3, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_452.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_281.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_151.json, Constants: 1, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_501.json, Constants: 1, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_29.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_444.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_297.json, Constants: 1, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_628.json, Constants: 1, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_278.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_556.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_91.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_106.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_413.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_690.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_385.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_468.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_192.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_487.json, Constants: 1, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_254.json, Constants: 1, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_604.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_311.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_741.json, Constants: 1, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_595.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_52.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_653.json, Constants: 1, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_203.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_716.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_346.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_429.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_5.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_583.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_44.json, Constants: 2, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_215.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_645.json, Constants: 1, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_350.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_700.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_13.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_184.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_491.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_612.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_242.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_307.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_370.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_720.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_235.json, Constants: 1, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_665.json, Constants: 2, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_409.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_64.json, Constants: 1, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_327.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_632.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_262.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_33.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_331.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_274.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_624.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_448.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_25.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_736.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_366.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_673.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f_389.json, Constants: 2, Max Constants: 3
# Before preprocessing: ('train', (100, 6))
# File: f
json, Constants: 1, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_110.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_87.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_68.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_147.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_151.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_29.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_91.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_106.json, Constants: 1, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_52.json, Constants: 1, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_5.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_44.json, Constants: 1, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_13.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_64.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_33.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_25.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_72.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_126.json, Constants: 1, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_48.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_9.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_130.json, Constants: 1, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_14.json, Constants: 1, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_2.json, Constants: 1, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_43.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_55.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_96.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_101.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_79.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_156.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_140.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_38.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_117.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_80.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_18.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_160.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_137.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_59.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_121.json, Constants: 1, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_75.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_22.json, Constants: 1, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_34.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_63.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_62.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_35.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_23.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_74.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_58.json, Constants: 1, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_120.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_136.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_19.json, Constants: 1, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_116.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_81.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_141.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_39.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_157.json, Constants: 1, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_97.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_100.json, Constants: 1, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_78.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_54.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_3.json, Constants: 1, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_42.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_15.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_115.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_82.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_142.json, Constants: 1, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_154.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_94.json, Constants: 1, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_103.json, Constants: 1, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_57.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_139.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_0.json, Constants: 1, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_41.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_16.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_61.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_119.json, Constants: 1, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_36.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_20.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_158.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_77.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_98.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_123.json, Constants: 1, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_135.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_134.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_122.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_76.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_99.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_21.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_159.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_37.json, Constants: 1, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_60.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_118.json, Constants: 1, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_17.json, Constants: 1, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_138.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_1.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_40.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_56.json, Constants: 2, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_95.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_102.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_155.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_143.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_114.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_83.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_67.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_88.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_30.json, Constants: 2, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_148.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_26.json, Constants: 1, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_71.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_109.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_125.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_133.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_113.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_84.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_144.json, Constants: 1, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_152.json, Constants: 1, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_92.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_105.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_129.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_51.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_6.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_47.json, Constants: 1, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_10.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_11.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_7.json, Constants: 1, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_46.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_128.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_50.json, Constants: 2, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_93.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_104.json, Constants: 1, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_153.json, Constants: 1, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_145.json, Constants: 1, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_112.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_85.json, Constants: 1, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_132.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_124.json, Constants: 1, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_70.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_108.json, Constants: 1, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_27.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_31.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_149.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_66.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# File: f_89.json, Constants: 0, Max Constants: 3
# Before preprocessing: ('test', (100, 6))
# Processed test data: 16100 samples saved.

# %% [markdown]
# # Preprocess and store the data as a Dataframe (for better visualization)

# %%
import pandas as pd

def preprocess_to_dataframe(data_folder, output_folder):
    os.makedirs(output_folder, exist_ok=True)
    splits = ['train', 'val', 'test']
    
    for split in splits:
        split_folder = os.path.join(data_folder, split)
        output_split_folder = os.path.join(output_folder, split)
        os.makedirs(output_split_folder, exist_ok=True)
        
        files = [f for f in os.listdir(split_folder) if f.endswith('.json') and not f.startswith('properties')]
        data_rows = []
        
        for file in files:
            with open(os.path.join(split_folder, file), 'r') as f:
                data = json.load(f)
                
                const_value_dict = data.get('const_value_dict', {})
                consts = list(const_value_dict.values())
                
                for i in range(len(data['points']['target'])):
                    row = {
                        **{f'var_{j}': data['points'][f'var_{j}'][i] for j in range(data['n_vars'])},
                        **{f'const_{k}': consts[k] if k < len(consts) else 0 for k in range(max(len(consts), 3))},
                        'target': data['points']['target'][i]
                    }
                    data_rows.append(row)
        
        # Create a DataFrame
        df = pd.DataFrame(data_rows)
        df.to_csv(os.path.join(output_split_folder, f'{split}.csv'), index=False)
        print(f"Processed {split} data: {len(df)} samples saved.")

# Run the preprocessing
# Define input and output folders
data_folder = "data_symbolic_regression"
output_folder = "preprocessed_df_symbolic_regression"
preprocess_to_dataframe(data_folder, output_folder)
# Out:
# Processed train data: 74700 samples saved.
# Processed val data: 16000 samples saved.
# Processed test data: 16100 samples saved.

# %% [markdown]
# # Load the data in batches for the Diffusion model

# %%
import numpy as np
import torch
from torch.utils.data import DataLoader, Dataset
from sklearn.preprocessing import StandardScaler

# Dataset class
class SymbolicRegressionDataset(Dataset):
    def __init__(self, file_path):
        # Load the .npz file
        data = np.load(file_path)
        self.X = data['X']
        self.y = data['y']
        
        # Normalize data
        self.scaler_X = StandardScaler().fit(self.X)
        self.scaler_y = StandardScaler().fit(self.y.reshape(-1, 1))
        self.X = self.scaler_X.transform(self.X)
        self.y = self.scaler_y.transform(self.y.reshape(-1, 1)).squeeze()
    
    def __len__(self):
        return len(self.X)
    
    def __getitem__(self, idx):
        return torch.tensor(self.X[idx], dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.float32)

# Create data loaders
def create_data_loaders(train_file, val_file, test_file, batch_size=32):
    train_dataset = SymbolicRegressionDataset(train_file)
    val_dataset = SymbolicRegressionDataset(val_file)
    test_dataset = SymbolicRegressionDataset(test_file)
    
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=batch_size)
    test_loader = DataLoader(test_dataset, batch_size=batch_size)
    
    return train_loader, val_loader, test_loader
