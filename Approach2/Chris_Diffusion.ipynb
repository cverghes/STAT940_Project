# %%
import os
import json

# Define the paths to the folders
folders = ["data_symbolic_regression/test", "data_symbolic_regression/train", "data_symbolic_regression/val"]

# Dictionary to hold the data from each folder
data = {folder: [] for folder in folders}

# Iterate through each folder and read JSON files
for folder in folders:
    if os.path.exists(folder):
        for file_name in os.listdir(folder):
            if file_name.endswith(".json"):
                file_path = os.path.join(folder, file_name)
                try:
                    with open(file_path, "r") as file:
                        content = json.load(file)
                        data[folder].append(content)
                except Exception as e:
                    print(f"Error reading {file_path}: {e}")
    else:
        print(f"Folder {folder} does not exist.")

# Example: Accessing data
for folder, files in data.items():
    print(f"Folder: {folder}, Number of files: {len(files)}")
# Out:
# Folder: data_symbolic_regression/test, Number of files: 161
# Folder: data_symbolic_regression/train, Number of files: 747
# Folder: data_symbolic_regression/val, Number of files: 160

# %%
if data["data_symbolic_regression/test"]:
    # Access the first item in the test folder
    test = data["data_symbolic_regression/test"]

if data["data_symbolic_regression/train"]:
    # Access the first item in the test folder
    train = data["data_symbolic_regression/train"]

if data["data_symbolic_regression/val"]:
    # Access the first item in the test folder
    val = data["data_symbolic_regression/val"]

# %%
len(train)
for i in range(len(train)):
    print(i)
    print(train[i]['formula'])
# Out:
# 0
# mult(add(cos(var_1, N), mult(var_2, C_0)), mult(mult(var_0, var_0), cos(var_2, N)))
# 1
# add(add(add(var_1, C_0), tan(var_0, N)), tanh(exp(var_2, N), N(N, N)))
# 2
# add(pow_2(cosh(var_2, N), N(N, N)), reverse(mult(var_1, var_0), N(N, N)))
# 3
# add(add(gaussian(var_1, N), add(var_0, C_0)), tan(mult(var_1, var_2), N(N, N)))
# 4
# add(sqrt(mult(var_2, var_0), N(N, N)), neg(cosh(var_1, N), N(N, N)))
# 5
# mult(mult(add(var_2, var_0), sqrt(var_1, N)), tanh(add(var_1, var_2), N(N, N)))
# 6
# log(mult(add(var_0, C_0), add(var_1, var_2)), N(N(N, N), N(N, N)))
# 7
# mult(add(sin(var_1, N), tanh(var_0, N)), sinh(sqrt(var_2, N), N(N, N)))
# 8
# add(tanh(log(var_0, N), N(N, N)), tanh(add(var_2, var_1), N(N, N)))
# 9
# add(sinh(tanh(var_0, N), N(N, N)), cos(mult(var_1, var_2), N(N, N)))
# 10
# add(log(sinh(var_0, N), N(N, N)), neg(mult(var_2, var_1), N(N, N)))
# 11
# add(mult(log(var_0, N), sqrt(var_1, N)), sin(pow_2(var_2, N), N(N, N)))
# 12
# mult(add(mult(var_0, C_0), sinh(var_1, N)), reverse(gaussian(var_2, N), N(N, N)))
# 13
# add(tan(reverse(var_2, N), N(N, N)), exp(add(var_0, var_1), N(N, N)))
# 14
# mult(log(add(var_1, var_0), N(N, N)), sqrt(add(var_2, C_0), N(N, N)))
# 15
# add(add(gaussian(var_1, N), mult(var_0, C_0)), sqrt(var_2(N, N), N(N, N)))
# 16
# mult(mult(var_1(N, N), cos(var_2, N)), tanh(sqrt(var_0, N), N(N, N)))
# 17
# neg(mult(tan(var_2, N), mult(var_0, var_1)), N(N(N, N), N(N, N)))
# 18
# add(mult(tan(var_2, N), sin(var_1, N)), cos(var_0(N, N), N(N, N)))
# 19
# mult(add(mult(var_2, C_0), tan(var_0, N)), sinh(mult(var_0, var_1), N(N, N)))
# 20
# mult(add(cos(var_0, N), tanh(var_2, N)), sqrt(sin(var_1, N), N(N, N)))
# 21
# mult(sin(add(var_0, var_2), N(N, N)), pow_2(neg(var_1, N), N(N, N)))
# 22
# mult(mult(log(var_0, N), var_2(N, N)), cosh(mult(var_2, var_1), N(N, N)))
# 23
# mult(neg(mult(var_1, var_0), N(N, N)), sin(sqrt(var_2, N), N(N, N)))
# 24
# add(cosh(cosh(var_2, N), N(N, N)), exp(add(var_1, var_0), N(N, N)))
# 25
# add(neg(cosh(var_0, N), N(N, N)), cosh(mult(var_2, var_1), N(N, N)))
# 26
# add(reverse(log(var_0, N), N(N, N)), cosh(mult(var_2, var_1), N(N, N)))
# 27
# add(tan(mult(var_1, var_0), N(N, N)), sin(add(var_2, C_0), N(N, N)))
# 28
# add(exp(add(var_0, var_2), N(N, N)), pow_2(sqrt(var_1, N), N(N, N)))
# 29
# add(add(cosh(var_2, N), tan(var_1, N)), sqrt(tan(var_0, N), N(N, N)))
# 30
# mult(log(add(var_0, var_1), N(N, N)), pow_2(add(var_2, C_0), N(N, N)))
# 31
# add(mult(cosh(var_2, N), var_2(N, N)), mult(add(var_0, var_1), sinh(var_0, N)))
# 32
# add(mult(tan(var_0, N), tanh(var_1, N)), cosh(cos(var_2, N), N(N, N)))
# 33
# mult(cosh(mult(var_1, var_2), N(N, N)), log(add(var_0, var_2), N(N, N)))
# 34
# mult(add(sqrt(var_1, N), cos(var_2, N)), add(log(var_0, N), reverse(var_2, N)))
# 35
# mult(sqrt(sinh(var_0, N), N(N, N)), pow_2(mult(var_2, var_1), N(N, N)))
# 36
# mult(mult(exp(var_1, N), sqrt(var_2, N)), tanh(tan(var_0, N), N(N, N)))
# 37
# mult(add(add(var_2, var_0), gaussian(var_1, N)), log(add(var_2, C_0), N(N, N)))
# 38
# add(reverse(sin(var_2, N), N(N, N)), pow_2(add(var_1, var_0), N(N, N)))
# 39
# mult(mult(exp(var_2, N), tanh(var_1, N)), pow_2(cosh(var_0, N), N(N, N)))
# 40
# mult(sqrt(sqrt(var_2, N), N(N, N)), sinh(add(var_1, var_0), N(N, N)))
# 41
# add(add(sin(var_0, N), tan(var_2, N)), add(sin(var_1, N), neg(var_1, N)))
# 42
# add(mult(mult(var_1, var_2), reverse(var_2, N)), sqrt(mult(var_0, C_0), N(N, N)))
# 43
# mult(add(sin(var_1, N), sqrt(var_0, N)), reverse(exp(var_2, N), N(N, N)))
# 44
# add(reverse(mult(var_1, var_0), N(N, N)), tan(add(var_2, C_0), N(N, N)))
# 45
# mult(reverse(mult(var_2, var_1), N(N, N)), pow_2(gaussian(var_0, N), N(N, N)))
# 46
# add(mult(mult(var_1, C_0), mult(var_0, var_1)), log(var_2(N, N), N(N, N)))
# 47
# add(add(add(var_2, var_1), log(var_0, N)), cosh(C_0(N, N), N(N, N)))
# 48
# add(reverse(mult(var_0, var_1), N(N, N)), gaussian(var_2(N, N), N(N, N)))
# 49
# add(mult(pow_2(var_1, N), gaussian(var_2, N)), cosh(tanh(var_0, N), N(N, N)))
# 50
# mult(add(reverse(var_0, N), tanh(var_1, N)), tan(gaussian(var_2, N), N(N, N)))
# 51
# mult(add(exp(var_1, N), reverse(var_0, N)), sin(var_2(N, N), N(N, N)))
# 52
# add(mult(C_0(N, N), cosh(var_2, N)), pow_2(add(var_1, var_0), N(N, N)))
# 53
# add(add(C_0(N, N), C_1(N, N)), mult(add(var_0, var_1), var_2(N, N)))
# 54
# add(add(mult(var_1, C_0), cos(var_0, N)), add(add(var_2, C_1), C_2(N, N)))
# 55
# add(pow_2(sin(var_0, N), N(N, N)), gaussian(mult(var_2, var_1), N(N, N)))
# 56
# add(mult(tan(var_1, N), tan(var_2, N)), reverse(cosh(var_0, N), N(N, N)))
# 57
# add(log(mult(var_2, var_0), N(N, N)), pow_2(sinh(var_1, N), N(N, N)))
# 58
# mult(add(neg(var_2, N), tanh(var_0, N)), tanh(reverse(var_1, N), N(N, N)))
# 59
# add(tan(mult(var_2, C_0), N(N, N)), neg(mult(var_0, var_1), N(N, N)))
# 60
# mult(neg(mult(var_2, var_0), N(N, N)), cosh(gaussian(var_1, N), N(N, N)))
# 61
# add(mult(pow_2(var_1, N), mult(var_0, var_0)), exp(add(var_2, var_2), N(N, N)))
# 62
# mult(neg(add(var_1, var_2), N(N, N)), tanh(tan(var_0, N), N(N, N)))
# 63
# add(exp(sin(var_2, N), N(N, N)), cosh(add(var_0, var_1), N(N, N)))
# 64
# add(cosh(add(var_1, var_2), N(N, N)), sin(add(var_0, C_0), N(N, N)))
# 65
# add(mult(tan(var_1, N), sin(var_1, N)), add(tan(var_0, N), cos(var_2, N)))
# 66
# add(mult(var_0(N, N), sinh(var_2, N)), mult(sqrt(var_1, N), reverse(var_1, N)))
# 67
# mult(add(exp(var_1, N), mult(var_1, C_0)), add(gaussian(var_2, N), sinh(var_0, N)))
# 68
# add(neg(mult(var_0, C_0), N(N, N)), sin(mult(var_2, var_1), N(N, N)))
# 69
# mult(add(neg(var_0, N), tanh(var_2, N)), sqrt(sin(var_1, N), N(N, N)))
# 70
# mult(mult(add(var_0, C_0), add(var_1, C_1)), pow_2(neg(var_2, N), N(N, N)))
# 71
# sinh(add(var_1(N, N), add(var_2, var_0)), N(N(N, N), N(N, N)))
# 72
# mult(mult(sin(var_2, N), cosh(var_1, N)), neg(var_0(N, N), N(N, N)))
# 73
# add(mult(cos(var_1, N), add(var_0, var_1)), exp(mult(var_2, C_0), N(N, N)))
# 74
# add(mult(pow_2(var_1, N), cosh(var_0, N)), log(cos(var_2, N), N(N, N)))
# 75
# mult(mult(pow_2(var_1, N), log(var_0, N)), neg(var_2(N, N), N(N, N)))
# 76
# mult(add(sin(var_2, N), add(var_1, var_2)), sin(add(var_0, C_0), N(N, N)))
# 77
# add(mult(mult(var_2, C_0), mult(var_0, var_1)), neg(reverse(var_2, N), N(N, N)))
# 78
# add(add(sqrt(var_0, N), add(var_2, C_0)), pow_2(sqrt(var_1, N), N(N, N)))
# 79
# mult(neg(tan(var_2, N), N(N, N)), exp(mult(var_1, var_0), N(N, N)))
# 80
# add(sqrt(mult(var_2, var_1), N(N, N)), neg(cosh(var_0, N), N(N, N)))
# 81
# add(cosh(reverse(var_1, N), N(N, N)), cosh(add(var_0, var_2), N(N, N)))
# 82
# add(mult(tanh(var_2, N), cos(var_2, N)), add(add(var_1, C_0), add(var_0, C_1)))
# 83
# add(add(cos(var_0, N), sqrt(var_2, N)), sin(sqrt(var_1, N), N(N, N)))
# 84
# mult(sinh(sqrt(var_2, N), N(N, N)), tanh(add(var_1, var_0), N(N, N)))
# 85
# mult(sinh(sqrt(var_2, N), N(N, N)), sinh(add(var_1, var_0), N(N, N)))
# 86
# add(neg(mult(var_2, C_0), N(N, N)), sin(mult(var_1, var_0), N(N, N)))
# 87
# add(neg(gaussian(var_1, N), N(N, N)), neg(add(var_0, var_2), N(N, N)))
# 88
# add(reverse(add(var_0, var_1), N(N, N)), pow_2(gaussian(var_2, N), N(N, N)))
# 89
# add(add(sin(var_1, N), cosh(var_0, N)), sinh(log(var_2, N), N(N, N)))
# 90
# add(add(mult(var_0, C_0), add(var_2, var_1)), sqrt(add(var_1, var_2), N(N, N)))
# 91
# mult(add(reverse(var_0, N), sin(var_1, N)), sqrt(mult(var_1, var_2), N(N, N)))
# 92
# add(gaussian(cosh(var_2, N), N(N, N)), reverse(mult(var_1, var_0), N(N, N)))
# 93
# add(add(add(var_0, C_0), sqrt(var_1, N)), cos(mult(var_2, C_1), N(N, N)))
# 94
# add(mult(var_2(N, N), mult(var_1, C_0)), pow_2(cosh(var_0, N), N(N, N)))
# 95
# add(mult(exp(var_0, N), var_2(N, N)), reverse(neg(var_1, N), N(N, N)))
# 96
# mult(add(sin(var_0, N), gaussian(var_2, N)), cos(pow_2(var_1, N), N(N, N)))
# 97
# sqrt(add(add(var_0, var_2), reverse(var_1, N)), N(N(N, N), N(N, N)))
# 98
# mult(add(gaussian(var_1, N), mult(var_2, C_0)), log(pow_2(var_0, N), N(N, N)))
# 99
# mult(add(add(var_0, C_0), sqrt(var_2, N)), gaussian(pow_2(var_1, N), N(N, N)))
# 100
# mult(gaussian(reverse(var_1, N), N(N, N)), gaussian(mult(var_0, var_2), N(N, N)))
# 101
# mult(add(mult(var_0, var_1), add(var_1, C_0)), exp(reverse(var_2, N), N(N, N)))
# 102
# add(add(tanh(var_1, N), pow_2(var_0, N)), tan(var_2(N, N), N(N, N)))
# 103
# add(add(cosh(var_1, N), sinh(var_1, N)), cos(add(var_2, var_0), N(N, N)))
# 104
# add(tan(mult(var_2, var_1), N(N, N)), sin(neg(var_0, N), N(N, N)))
# 105
# mult(neg(mult(var_0, C_0), N(N, N)), neg(mult(var_2, var_1), N(N, N)))
# 106
# mult(add(add(var_0, C_0), var_1(N, N)), mult(log(var_1, N), tanh(var_2, N)))
# 107
# mult(pow_2(add(var_0, var_1), N(N, N)), reverse(sqrt(var_2, N), N(N, N)))
# 108
# mult(sin(pow_2(var_0, N), N(N, N)), sqrt(mult(var_1, var_2), N(N, N)))
# 109
# mult(tanh(sin(var_0, N), N(N, N)), tanh(add(var_1, var_2), N(N, N)))
# 110
# mult(add(cosh(var_0, N), pow_2(var_1, N)), exp(neg(var_2, N), N(N, N)))
# 111
# mult(gaussian(add(var_2, var_1), N(N, N)), pow_2(cosh(var_0, N), N(N, N)))
# 112
# mult(log(sqrt(var_1, N), N(N, N)), tan(add(var_2, var_0), N(N, N)))
# 113
# add(sinh(add(var_2, var_1), N(N, N)), sqrt(tan(var_0, N), N(N, N)))
# 114
# mult(add(add(var_2, C_0), sin(var_1, N)), gaussian(gaussian(var_0, N), N(N, N)))
# 115
# add(mult(pow_2(var_2, N), cosh(var_1, N)), log(mult(var_0, C_0), N(N, N)))
# 116
# mult(exp(cosh(var_1, N), N(N, N)), exp(mult(var_0, var_2), N(N, N)))
# 117
# mult(tan(mult(var_0, var_1), N(N, N)), exp(var_2(N, N), N(N, N)))
# 118
# mult(tanh(log(var_2, N), N(N, N)), sqrt(mult(var_0, var_1), N(N, N)))
# 119
# add(add(tan(var_1, N), log(var_2, N)), log(cosh(var_0, N), N(N, N)))
# 120
# add(tanh(add(var_2, C_0), N(N, N)), sqrt(add(var_0, var_1), N(N, N)))
# 121
# add(cosh(add(var_1, var_2), N(N, N)), gaussian(add(var_0, var_2), N(N, N)))
# 122
# mult(tanh(cosh(var_0, N), N(N, N)), reverse(add(var_2, var_1), N(N, N)))
# 123
# mult(sin(add(var_2, var_0), N(N, N)), reverse(log(var_1, N), N(N, N)))
# 124
# add(gaussian(add(var_0, var_2), N(N, N)), sinh(log(var_1, N), N(N, N)))
# 125
# add(sqrt(log(var_2, N), N(N, N)), sqrt(add(var_0, var_1), N(N, N)))
# 126
# add(exp(add(var_2, var_1), N(N, N)), sinh(reverse(var_0, N), N(N, N)))
# 127
# mult(sin(mult(var_0, var_2), N(N, N)), sinh(sinh(var_1, N), N(N, N)))
# 128
# add(mult(reverse(var_1, N), log(var_2, N)), sin(add(var_1, var_0), N(N, N)))
# 129
# add(add(sqrt(var_1, N), mult(var_1, var_2)), add(C_0(N, N), var_0(N, N)))
# 130
# add(sqrt(add(var_1, var_2), N(N, N)), gaussian(pow_2(var_0, N), N(N, N)))
# 131
# mult(add(var_1(N, N), sin(var_1, N)), add(tan(var_2, N), var_0(N, N)))
# 132
# mult(cos(neg(var_2, N), N(N, N)), sqrt(add(var_1, var_0), N(N, N)))
# 133
# add(sin(add(var_1, C_0), N(N, N)), cosh(add(var_0, var_2), N(N, N)))
# 134
# sqrt(mult(sin(var_0, N), add(var_1, var_2)), N(N(N, N), N(N, N)))
# 135
# add(add(tanh(var_2, N), add(var_2, var_0)), tan(add(var_1, var_0), N(N, N)))
# 136
# mult(mult(neg(var_0, N), sin(var_2, N)), sqrt(exp(var_1, N), N(N, N)))
# 137
# add(mult(cosh(var_2, N), cosh(var_0, N)), add(exp(var_1, N), pow_2(var_1, N)))
# 138
# reverse(mult(add(var_2, var_0), add(var_1, C_0)), N(N(N, N), N(N, N)))
# 139
# add(mult(reverse(var_0, N), log(var_2, N)), pow_2(cos(var_1, N), N(N, N)))
# 140
# mult(reverse(tanh(var_2, N), N(N, N)), sinh(add(var_0, var_1), N(N, N)))
# 141
# add(add(mult(var_2, var_1), cosh(var_0, N)), sinh(C_0(N, N), N(N, N)))
# 142
# add(tan(neg(var_0, N), N(N, N)), tanh(add(var_2, var_1), N(N, N)))
# 143
# mult(add(mult(var_0, C_0), neg(var_1, N)), add(sqrt(var_2, N), C_1(N, N)))
# 144
# add(log(add(var_0, var_2), N(N, N)), log(add(var_1, C_0), N(N, N)))
# 145
# mult(sinh(mult(var_2, var_0), N(N, N)), log(sqrt(var_1, N), N(N, N)))
# 146
# mult(mult(pow_2(var_1, N), sinh(var_0, N)), cos(pow_2(var_2, N), N(N, N)))
# 147
# mult(sinh(add(var_1, var_0), N(N, N)), cosh(log(var_2, N), N(N, N)))
# 148
# mult(reverse(mult(var_2, var_0), N(N, N)), sin(gaussian(var_1, N), N(N, N)))
# 149
# cos(mult(sqrt(var_0, N), mult(var_1, var_2)), N(N(N, N), N(N, N)))
# 150
# add(add(var_0(N, N), sinh(var_2, N)), tan(mult(var_1, var_0), N(N, N)))
# 151
# add(neg(add(var_1, var_2), N(N, N)), log(pow_2(var_0, N), N(N, N)))
# 152
# mult(add(mult(var_2, var_2), add(var_0, C_0)), tan(add(var_2, var_1), N(N, N)))
# 153
# mult(add(C_0(N, N), add(var_1, C_1)), gaussian(add(var_2, var_0), N(N, N)))
# 154
# mult(mult(sqrt(var_2, N), tanh(var_0, N)), pow_2(tanh(var_1, N), N(N, N)))
# 155
# add(mult(pow_2(var_1, N), tan(var_0, N)), neg(pow_2(var_2, N), N(N, N)))
# 156
# mult(neg(add(var_2, C_0), N(N, N)), tan(add(var_0, var_1), N(N, N)))
# 157
# mult(cos(mult(var_0, var_2), N(N, N)), neg(log(var_1, N), N(N, N)))
# 158
# add(mult(sqrt(var_0, N), cosh(var_1, N)), gaussian(exp(var_2, N), N(N, N)))
# 159
# add(add(sqrt(var_1, N), add(var_2, var_0)), reverse(C_0(N, N), N(N, N)))
# 160
# mult(pow_2(gaussian(var_0, N), N(N, N)), sinh(add(var_2, var_1), N(N, N)))
# 161
# mult(sinh(mult(var_1, var_0), N(N, N)), cos(sqrt(var_2, N), N(N, N)))
# 162
# tan(mult(mult(var_2, var_0), sinh(var_1, N)), N(N(N, N), N(N, N)))
# 163
# mult(mult(add(var_2, var_1), cosh(var_0, N)), log(mult(var_1, C_0), N(N, N)))
# 164
# add(tan(reverse(var_1, N), N(N, N)), sqrt(add(var_2, var_0), N(N, N)))
# 165
# mult(add(tan(var_0, N), pow_2(var_1, N)), exp(neg(var_2, N), N(N, N)))
# 166
# add(add(add(var_1, var_2), sinh(var_2, N)), cosh(neg(var_0, N), N(N, N)))
# 167
# add(add(sinh(var_2, N), mult(var_0, C_0)), tanh(mult(var_1, var_1), N(N, N)))
# 168
# add(cosh(tan(var_2, N), N(N, N)), exp(add(var_1, var_0), N(N, N)))
# 169
# add(mult(exp(var_0, N), exp(var_2, N)), reverse(cos(var_1, N), N(N, N)))
# 170
# add(mult(var_2(N, N), reverse(var_0, N)), pow_2(mult(var_1, C_0), N(N, N)))
# 171
# add(mult(tanh(var_0, N), pow_2(var_2, N)), pow_2(log(var_1, N), N(N, N)))
# 172
# add(add(sinh(var_0, N), cosh(var_1, N)), reverse(cosh(var_2, N), N(N, N)))
# 173
# add(add(add(var_0, C_0), pow_2(var_2, N)), sinh(tan(var_1, N), N(N, N)))
# 174
# neg(mult(sqrt(var_2, N), add(var_0, var_1)), N(N(N, N), N(N, N)))
# 175
# add(add(sqrt(var_2, N), sqrt(var_1, N)), tanh(pow_2(var_0, N), N(N, N)))
# 176
# add(mult(tanh(var_0, N), sqrt(var_2, N)), sinh(gaussian(var_1, N), N(N, N)))
# 177
# add(mult(tan(var_0, N), add(var_2, C_0)), exp(reverse(var_1, N), N(N, N)))
# 178
# mult(sin(mult(var_0, var_1), N(N, N)), exp(mult(var_2, var_0), N(N, N)))
# 179
# mult(tanh(mult(var_0, var_2), N(N, N)), cosh(add(var_1, var_1), N(N, N)))
# 180
# add(sin(mult(var_0, var_1), N(N, N)), gaussian(sinh(var_2, N), N(N, N)))
# 181
# add(tan(mult(var_1, C_0), N(N, N)), cos(mult(var_0, var_2), N(N, N)))
# 182
# add(sinh(pow_2(var_2, N), N(N, N)), sqrt(add(var_0, var_1), N(N, N)))
# 183
# mult(add(cos(var_2, N), gaussian(var_0, N)), neg(mult(var_1, C_0), N(N, N)))
# 184
# mult(add(sin(var_2, N), sinh(var_1, N)), mult(sinh(var_2, N), tanh(var_0, N)))
# 185
# mult(tan(mult(var_2, var_1), N(N, N)), cos(neg(var_0, N), N(N, N)))
# 186
# add(gaussian(add(var_0, var_2), N(N, N)), cosh(sqrt(var_1, N), N(N, N)))
# 187
# add(gaussian(sinh(var_1, N), N(N, N)), cosh(mult(var_0, var_2), N(N, N)))
# 188
# add(mult(mult(var_1, C_0), sin(var_0, N)), reverse(exp(var_2, N), N(N, N)))
# 189
# add(gaussian(mult(var_2, var_1), N(N, N)), cosh(sqrt(var_0, N), N(N, N)))
# 190
# mult(add(pow_2(var_0, N), add(var_0, var_2)), cosh(pow_2(var_1, N), N(N, N)))
# 191
# mult(mult(pow_2(var_1, N), gaussian(var_0, N)), gaussian(exp(var_2, N), N(N, N)))
# 192
# mult(tan(pow_2(var_1, N), N(N, N)), neg(add(var_2, var_0), N(N, N)))
# 193
# mult(cos(var_2(N, N), N(N, N)), exp(add(var_0, var_1), N(N, N)))
# 194
# add(add(sin(var_0, N), cosh(var_2, N)), neg(log(var_1, N), N(N, N)))
# 195
# add(tanh(add(var_1, var_0), N(N, N)), tanh(sinh(var_2, N), N(N, N)))
# 196
# mult(mult(sqrt(var_2, N), sinh(var_1, N)), pow_2(reverse(var_0, N), N(N, N)))
# 197
# mult(mult(tan(var_1, N), add(var_2, C_0)), add(sin(var_0, N), mult(var_0, var_1)))
# 198
# mult(mult(sinh(var_2, N), sin(var_1, N)), mult(exp(var_1, N), add(var_0, C_0)))
# 199
# log(mult(add(var_2, var_1), tanh(var_0, N)), N(N(N, N), N(N, N)))
# 200
# add(mult(C_0(N, N), exp(var_0, N)), log(add(var_2, var_1), N(N, N)))
# 201
# mult(mult(sin(var_2, N), mult(var_0, C_0)), sin(neg(var_1, N), N(N, N)))
# 202
# mult(neg(add(var_1, var_0), N(N, N)), sinh(pow_2(var_2, N), N(N, N)))
# 203
# mult(add(sqrt(var_2, N), tanh(var_0, N)), exp(pow_2(var_1, N), N(N, N)))
# 204
# mult(sin(add(var_0, var_2), N(N, N)), gaussian(log(var_1, N), N(N, N)))
# 205
# add(mult(var_0(N, N), mult(var_1, var_2)), exp(mult(var_0, var_2), N(N, N)))
# 206
# add(exp(add(var_0, var_1), N(N, N)), sinh(mult(var_2, C_0), N(N, N)))
# 207
# add(pow_2(tanh(var_1, N), N(N, N)), pow_2(add(var_0, var_2), N(N, N)))
# 208
# add(sin(mult(var_0, var_2), N(N, N)), exp(tanh(var_1, N), N(N, N)))
# 209
# mult(reverse(add(var_1, var_0), N(N, N)), neg(tan(var_2, N), N(N, N)))
# 210
# mult(reverse(tan(var_2, N), N(N, N)), tan(add(var_0, var_1), N(N, N)))
# 211
# mult(mult(cos(var_0, N), tan(var_0, N)), add(add(var_2, var_1), var_0(N, N)))
# 212
# mult(add(sin(var_2, N), cosh(var_0, N)), gaussian(tanh(var_1, N), N(N, N)))
# 213
# mult(pow_2(add(var_2, var_1), N(N, N)), exp(cosh(var_0, N), N(N, N)))
# 214
# add(mult(add(var_0, var_2), log(var_2, N)), gaussian(mult(var_0, var_1), N(N, N)))
# 215
# mult(cosh(mult(var_2, var_0), N(N, N)), neg(add(var_1, var_2), N(N, N)))
# 216
# add(exp(var_0(N, N), N(N, N)), neg(add(var_2, var_1), N(N, N)))
# 217
# add(add(log(var_0, N), pow_2(var_2, N)), reverse(log(var_1, N), N(N, N)))
# 218
# add(mult(neg(var_2, N), add(var_1, var_0)), gaussian(sinh(var_1, N), N(N, N)))
# 219
# add(tanh(cosh(var_1, N), N(N, N)), sin(mult(var_0, var_2), N(N, N)))
# 220
# add(log(mult(var_2, C_0), N(N, N)), sin(mult(var_1, var_0), N(N, N)))
# 221
# mult(mult(cos(var_1, N), exp(var_2, N)), pow_2(sin(var_0, N), N(N, N)))
# 222
# mult(mult(sin(var_0, N), tan(var_1, N)), reverse(tanh(var_2, N), N(N, N)))
# 223
# add(reverse(mult(var_0, var_1), N(N, N)), reverse(sinh(var_2, N), N(N, N)))
# 224
# mult(add(var_1(N, N), sinh(var_0, N)), gaussian(pow_2(var_2, N), N(N, N)))
# 225
# add(log(add(var_2, var_0), N(N, N)), sqrt(sinh(var_1, N), N(N, N)))
# 226
# mult(mult(sin(var_0, N), C_0(N, N)), add(add(var_1, C_1), tanh(var_2, N)))
# 227
# mult(pow_2(mult(var_0, var_1), N(N, N)), cos(neg(var_2, N), N(N, N)))
# 228
# mult(sin(add(var_2, var_1), N(N, N)), pow_2(exp(var_0, N), N(N, N)))
# 229
# add(neg(mult(var_2, var_1), N(N, N)), sqrt(gaussian(var_0, N), N(N, N)))
# 230
# mult(sqrt(mult(var_1, var_2), N(N, N)), tanh(add(var_0, var_0), N(N, N)))
# 231
# add(add(tan(var_2, N), mult(var_1, var_0)), mult(sinh(var_1, N), add(var_1, C_0)))
# 232
# mult(mult(tan(var_0, N), neg(var_1, N)), sinh(sqrt(var_2, N), N(N, N)))
# 233
# add(pow_2(reverse(var_1, N), N(N, N)), cos(mult(var_2, var_0), N(N, N)))
# 234
# mult(tanh(mult(var_2, var_0), N(N, N)), reverse(pow_2(var_1, N), N(N, N)))
# 235
# gaussian(add(reverse(var_1, N), mult(var_0, var_2)), N(N(N, N), N(N, N)))
# 236
# mult(tan(mult(var_1, var_0), N(N, N)), tanh(reverse(var_2, N), N(N, N)))
# 237
# reverse(add(exp(var_1, N), mult(var_2, var_0)), N(N(N, N), N(N, N)))
# 238
# mult(cos(mult(var_0, var_2), N(N, N)), cos(sqrt(var_1, N), N(N, N)))
# 239
# add(tan(add(var_0, var_2), N(N, N)), cos(add(var_1, C_0), N(N, N)))
# 240
# add(exp(mult(var_1, var_0), N(N, N)), sin(pow_2(var_2, N), N(N, N)))
# 241
# add(add(var_2(N, N), var_0(N, N)), tan(neg(var_1, N), N(N, N)))
# 242
# mult(cos(add(var_0, var_2), N(N, N)), sqrt(mult(var_1, var_0), N(N, N)))
# 243
# mult(tanh(sqrt(var_1, N), N(N, N)), cos(mult(var_0, var_2), N(N, N)))
# 244
# mult(mult(log(var_0, N), sin(var_1, N)), reverse(gaussian(var_2, N), N(N, N)))
# 245
# add(add(reverse(var_1, N), tanh(var_2, N)), sin(reverse(var_0, N), N(N, N)))
# 246
# add(cosh(tanh(var_1, N), N(N, N)), cosh(mult(var_0, var_2), N(N, N)))
# 247
# mult(sinh(add(var_1, var_2), N(N, N)), sinh(pow_2(var_0, N), N(N, N)))
# 248
# pow_2(add(mult(var_2, C_0), add(var_1, var_0)), N(N(N, N), N(N, N)))
# 249
# add(add(sinh(var_2, N), sin(var_1, N)), cos(pow_2(var_0, N), N(N, N)))
# 250
# mult(tan(mult(var_2, C_0), N(N, N)), neg(mult(var_1, var_0), N(N, N)))
# 251
# add(add(sin(var_2, N), cosh(var_1, N)), add(log(var_1, N), cos(var_0, N)))
# 252
# add(cosh(tanh(var_1, N), N(N, N)), sinh(mult(var_2, var_0), N(N, N)))
# 253
# add(add(log(var_2, N), sinh(var_2, N)), reverse(mult(var_1, var_0), N(N, N)))
# 254
# mult(cosh(mult(var_1, var_2), N(N, N)), cosh(tanh(var_0, N), N(N, N)))
# 255
# add(mult(gaussian(var_0, N), mult(var_1, var_2)), mult(mult(var_1, var_1), pow_2(var_1, N)))
# 256
# add(add(mult(var_2, C_0), gaussian(var_1, N)), add(neg(var_2, N), tan(var_0, N)))
# 257
# mult(neg(sqrt(var_1, N), N(N, N)), reverse(add(var_0, var_2), N(N, N)))
# 258
# mult(sin(reverse(var_0, N), N(N, N)), tanh(mult(var_1, var_2), N(N, N)))
# 259
# add(cosh(neg(var_0, N), N(N, N)), cos(add(var_1, var_2), N(N, N)))
# 260
# mult(add(log(var_1, N), neg(var_2, N)), mult(exp(var_0, N), add(var_1, C_0)))
# 261
# mult(sqrt(add(var_1, var_0), N(N, N)), reverse(neg(var_2, N), N(N, N)))
# 262
# add(mult(add(var_2, var_0), add(var_2, C_0)), add(sqrt(var_1, N), cos(var_1, N)))
# 263
# add(sinh(mult(var_1, var_2), N(N, N)), sinh(sinh(var_0, N), N(N, N)))
# 264
# mult(neg(add(var_2, var_0), N(N, N)), gaussian(sin(var_1, N), N(N, N)))
# 265
# mult(tan(add(var_0, var_2), N(N, N)), tanh(neg(var_1, N), N(N, N)))
# 266
# add(mult(reverse(var_0, N), mult(var_2, C_0)), mult(add(var_1, C_1), tanh(var_2, N)))
# 267
# mult(cosh(neg(var_0, N), N(N, N)), sinh(mult(var_2, var_1), N(N, N)))
# 268
# add(mult(mult(var_1, C_0), sqrt(var_2, N)), gaussian(add(var_0, var_1), N(N, N)))
# 269
# add(add(neg(var_1, N), neg(var_0, N)), gaussian(sin(var_2, N), N(N, N)))
# 270
# add(exp(add(var_1, var_2), N(N, N)), reverse(sqrt(var_0, N), N(N, N)))
# 271
# add(pow_2(mult(var_1, var_0), N(N, N)), exp(var_2(N, N), N(N, N)))
# 272
# add(mult(add(var_0, C_0), add(var_1, var_2)), tanh(add(var_1, var_0), N(N, N)))
# 273
# add(neg(add(var_2, var_1), N(N, N)), cosh(sin(var_0, N), N(N, N)))
# 274
# mult(sin(mult(var_2, var_0), N(N, N)), cosh(cosh(var_1, N), N(N, N)))
# 275
# add(sin(mult(var_1, var_0), N(N, N)), log(gaussian(var_2, N), N(N, N)))
# 276
# add(mult(C_0(N, N), mult(var_1, var_0)), neg(gaussian(var_2, N), N(N, N)))
# 277
# mult(gaussian(mult(var_2, var_1), N(N, N)), cosh(neg(var_0, N), N(N, N)))
# 278
# mult(mult(mult(var_2, var_1), mult(var_2, var_0)), log(cos(var_1, N), N(N, N)))
# 279
# add(mult(log(var_0, N), pow_2(var_2, N)), cosh(reverse(var_1, N), N(N, N)))
# 280
# add(log(add(var_2, var_0), N(N, N)), tanh(mult(var_1, var_1), N(N, N)))
# 281
# mult(neg(pow_2(var_2, N), N(N, N)), sinh(mult(var_0, var_1), N(N, N)))
# 282
# add(tan(add(var_2, var_0), N(N, N)), pow_2(add(var_1, var_0), N(N, N)))
# 283
# mult(reverse(neg(var_1, N), N(N, N)), sqrt(mult(var_2, var_0), N(N, N)))
# 284
# mult(add(pow_2(var_0, N), exp(var_2, N)), cosh(mult(var_1, C_0), N(N, N)))
# 285
# add(exp(add(var_0, var_1), N(N, N)), reverse(add(var_2, C_0), N(N, N)))
# 286
# add(mult(exp(var_2, N), cos(var_0, N)), sinh(neg(var_1, N), N(N, N)))
# 287
# add(add(sin(var_0, N), reverse(var_2, N)), add(log(var_0, N), log(var_1, N)))
# 288
# add(mult(var_2(N, N), gaussian(var_0, N)), gaussian(cosh(var_1, N), N(N, N)))
# 289
# mult(mult(mult(var_0, C_0), reverse(var_1, N)), exp(var_2(N, N), N(N, N)))
# 290
# mult(add(var_0(N, N), cosh(var_2, N)), log(var_1(N, N), N(N, N)))
# 291
# add(neg(cos(var_1, N), N(N, N)), tan(add(var_2, var_0), N(N, N)))
# 292
# add(mult(cos(var_1, N), var_0(N, N)), sqrt(add(var_2, C_0), N(N, N)))
# 293
# add(exp(neg(var_2, N), N(N, N)), gaussian(mult(var_1, var_0), N(N, N)))
# 294
# mult(add(add(var_0, C_0), sqrt(var_1, N)), sinh(add(var_2, C_1), N(N, N)))
# 295
# add(reverse(tanh(var_1, N), N(N, N)), log(mult(var_2, var_0), N(N, N)))
# 296
# add(log(add(var_1, var_2), N(N, N)), sin(add(var_0, C_0), N(N, N)))
# 297
# mult(mult(cos(var_0, N), log(var_2, N)), log(sqrt(var_1, N), N(N, N)))
# 298
# mult(sqrt(add(var_1, var_0), N(N, N)), neg(log(var_2, N), N(N, N)))
# 299
# mult(neg(mult(var_0, var_2), N(N, N)), sinh(tan(var_1, N), N(N, N)))
# 300
# mult(mult(tan(var_0, N), tanh(var_2, N)), add(tanh(var_1, N), sqrt(var_0, N)))
# 301
# mult(tan(mult(var_2, var_0), N(N, N)), gaussian(reverse(var_1, N), N(N, N)))
# 302
# mult(cos(mult(var_1, var_2), N(N, N)), tanh(pow_2(var_0, N), N(N, N)))
# 303
# add(mult(cosh(var_1, N), var_0(N, N)), log(sin(var_2, N), N(N, N)))
# 304
# mult(log(add(var_2, var_1), N(N, N)), sin(var_0(N, N), N(N, N)))
# 305
# add(cosh(add(var_2, var_0), N(N, N)), sqrt(mult(var_1, C_0), N(N, N)))
# 306
# mult(reverse(mult(var_0, C_0), N(N, N)), tanh(add(var_2, var_1), N(N, N)))
# 307
# add(add(tanh(var_0, N), reverse(var_1, N)), neg(gaussian(var_2, N), N(N, N)))
# 308
# add(cos(add(var_0, var_2), N(N, N)), cos(reverse(var_1, N), N(N, N)))
# 309
# mult(mult(cos(var_0, N), var_0(N, N)), mult(tan(var_1, N), log(var_2, N)))
# 310
# add(neg(reverse(var_0, N), N(N, N)), sin(add(var_1, var_2), N(N, N)))
# 311
# mult(reverse(sqrt(var_0, N), N(N, N)), cos(mult(var_2, var_1), N(N, N)))
# 312
# add(mult(cosh(var_2, N), sinh(var_0, N)), sinh(var_1(N, N), N(N, N)))
# 313
# add(add(sqrt(var_0, N), cosh(var_2, N)), sinh(sinh(var_1, N), N(N, N)))
# 314
# mult(sin(mult(var_2, var_1), N(N, N)), log(neg(var_0, N), N(N, N)))
# 315
# add(mult(tanh(var_0, N), mult(var_0, var_2)), exp(reverse(var_1, N), N(N, N)))
# 316
# add(log(gaussian(var_2, N), N(N, N)), cosh(mult(var_0, var_1), N(N, N)))
# 317
# mult(mult(neg(var_1, N), pow_2(var_0, N)), mult(sin(var_2, N), mult(var_0, C_0)))
# 318
# add(add(neg(var_0, N), pow_2(var_0, N)), tan(add(var_1, var_2), N(N, N)))
# 319
# add(mult(tanh(var_1, N), sqrt(var_0, N)), mult(gaussian(var_2, N), mult(var_1, var_2)))
# 320
# add(mult(log(var_0, N), pow_2(var_1, N)), sinh(tanh(var_2, N), N(N, N)))
# 321
# mult(exp(tan(var_0, N), N(N, N)), tan(mult(var_2, var_1), N(N, N)))
# 322
# mult(mult(mult(var_0, C_0), mult(var_1, C_1)), cosh(neg(var_2, N), N(N, N)))
# 323
# mult(cosh(mult(var_0, var_2), N(N, N)), sinh(gaussian(var_1, N), N(N, N)))
# 324
# add(log(mult(var_0, var_2), N(N, N)), cos(gaussian(var_1, N), N(N, N)))
# 325
# mult(mult(log(var_2, N), add(var_1, var_2)), tanh(cosh(var_0, N), N(N, N)))
# 326
# mult(reverse(gaussian(var_0, N), N(N, N)), neg(mult(var_1, var_2), N(N, N)))
# 327
# mult(exp(mult(var_1, var_2), N(N, N)), gaussian(sin(var_0, N), N(N, N)))
# 328
# mult(sinh(sqrt(var_2, N), N(N, N)), sin(mult(var_0, var_1), N(N, N)))
# 329
# add(add(sin(var_2, N), tan(var_0, N)), mult(var_1(N, N), cos(var_2, N)))
# 330
# add(add(add(var_0, var_2), mult(var_1, var_0)), sinh(reverse(var_2, N), N(N, N)))
# 331
# add(gaussian(mult(var_2, var_1), N(N, N)), reverse(sin(var_0, N), N(N, N)))
# 332
# mult(add(neg(var_1, N), sqrt(var_0, N)), tan(var_2(N, N), N(N, N)))
# 333
# mult(add(var_0(N, N), sqrt(var_1, N)), reverse(pow_2(var_2, N), N(N, N)))
# 334
# mult(mult(sin(var_2, N), var_0(N, N)), sqrt(reverse(var_1, N), N(N, N)))
# 335
# add(mult(reverse(var_2, N), exp(var_1, N)), exp(tan(var_0, N), N(N, N)))
# 336
# add(add(cosh(var_0, N), gaussian(var_1, N)), exp(gaussian(var_2, N), N(N, N)))
# 337
# mult(mult(exp(var_1, N), sin(var_2, N)), reverse(pow_2(var_0, N), N(N, N)))
# 338
# add(neg(add(var_1, C_0), N(N, N)), cos(mult(var_0, var_2), N(N, N)))
# 339
# mult(mult(cos(var_2, N), reverse(var_0, N)), exp(pow_2(var_1, N), N(N, N)))
# 340
# add(sinh(reverse(var_1, N), N(N, N)), tan(mult(var_2, var_0), N(N, N)))
# 341
# mult(mult(neg(var_2, N), add(var_0, C_0)), reverse(exp(var_1, N), N(N, N)))
# 342
# mult(mult(add(var_0, var_0), add(var_1, var_0)), gaussian(cosh(var_2, N), N(N, N)))
# 343
# add(tanh(sin(var_0, N), N(N, N)), tanh(mult(var_1, var_2), N(N, N)))
# 344
# mult(mult(cos(var_0, N), tanh(var_2, N)), pow_2(add(var_0, var_1), N(N, N)))
# 345
# add(pow_2(sinh(var_2, N), N(N, N)), neg(mult(var_0, var_1), N(N, N)))
# 346
# mult(pow_2(add(var_1, var_0), N(N, N)), exp(tan(var_2, N), N(N, N)))
# 347
# add(mult(tanh(var_1, N), sqrt(var_0, N)), gaussian(sinh(var_2, N), N(N, N)))
# 348
# add(tanh(mult(var_0, var_1), N(N, N)), cosh(gaussian(var_2, N), N(N, N)))
# 349
# mult(mult(tanh(var_2, N), tanh(var_1, N)), tanh(sqrt(var_0, N), N(N, N)))
# 350
# add(tan(mult(var_2, var_0), N(N, N)), gaussian(add(var_1, var_2), N(N, N)))
# 351
# mult(tanh(neg(var_1, N), N(N, N)), cos(mult(var_2, var_0), N(N, N)))
# 352
# mult(mult(cos(var_2, N), gaussian(var_0, N)), mult(neg(var_1, N), cosh(var_1, N)))
# 353
# sinh(mult(sinh(var_1, N), add(var_0, var_2)), N(N(N, N), N(N, N)))
# 354
# mult(neg(add(var_1, var_2), N(N, N)), gaussian(pow_2(var_0, N), N(N, N)))
# 355
# add(log(reverse(var_0, N), N(N, N)), tan(add(var_2, var_1), N(N, N)))
# 356
# mult(add(cos(var_0, N), var_2(N, N)), cosh(sinh(var_1, N), N(N, N)))
# 357
# add(add(cosh(var_0, N), add(var_1, var_2)), pow_2(log(var_0, N), N(N, N)))
# 358
# add(reverse(exp(var_2, N), N(N, N)), exp(add(var_0, var_1), N(N, N)))
# 359
# mult(cosh(tanh(var_0, N), N(N, N)), log(mult(var_1, var_2), N(N, N)))
# 360
# add(add(cos(var_0, N), log(var_1, N)), log(tan(var_2, N), N(N, N)))
# 361
# mult(add(sinh(var_1, N), cos(var_2, N)), sinh(gaussian(var_0, N), N(N, N)))
# 362
# mult(mult(sin(var_1, N), gaussian(var_2, N)), gaussian(log(var_0, N), N(N, N)))
# 363
# add(add(cosh(var_0, N), sin(var_1, N)), tanh(log(var_2, N), N(N, N)))
# 364
# add(mult(add(var_2, var_0), tan(var_1, N)), neg(C_0(N, N), N(N, N)))
# 365
# mult(log(add(var_2, var_2), N(N, N)), log(mult(var_1, var_0), N(N, N)))
# 366
# mult(mult(mult(var_0, C_0), cos(var_1, N)), cos(neg(var_2, N), N(N, N)))
# 367
# add(neg(gaussian(var_0, N), N(N, N)), sinh(add(var_1, var_2), N(N, N)))
# 368
# add(mult(var_1(N, N), cos(var_2, N)), sqrt(sin(var_0, N), N(N, N)))
# 369
# add(log(var_0(N, N), N(N, N)), cos(mult(var_2, var_1), N(N, N)))
# 370
# add(tanh(add(var_0, var_1), N(N, N)), neg(mult(var_1, var_2), N(N, N)))
# 371
# mult(add(reverse(var_1, N), tanh(var_2, N)), sqrt(pow_2(var_0, N), N(N, N)))
# 372
# add(add(mult(var_1, var_2), add(var_1, var_2)), mult(C_0(N, N), mult(var_0, var_0)))
# 373
# add(reverse(mult(var_0, var_1), N(N, N)), log(add(var_2, C_0), N(N, N)))
# 374
# add(cosh(exp(var_0, N), N(N, N)), sinh(add(var_1, var_2), N(N, N)))
# 375
# mult(add(tan(var_2, N), gaussian(var_0, N)), tan(var_1(N, N), N(N, N)))
# 376
# add(mult(add(var_1, C_0), exp(var_2, N)), sqrt(exp(var_0, N), N(N, N)))
# 377
# mult(mult(reverse(var_0, N), mult(var_2, C_0)), reverse(mult(var_1, var_0), N(N, N)))
# 378
# add(gaussian(mult(var_0, var_1), N(N, N)), tanh(sqrt(var_2, N), N(N, N)))
# 379
# mult(add(pow_2(var_1, N), mult(var_2, C_0)), cos(mult(var_0, C_1), N(N, N)))
# 380
# add(add(neg(var_1, N), reverse(var_2, N)), tan(add(var_0, var_2), N(N, N)))
# 381
# mult(tan(neg(var_0, N), N(N, N)), cosh(add(var_2, var_1), N(N, N)))
# 382
# tan(mult(add(var_1, var_2), cos(var_0, N)), N(N(N, N), N(N, N)))
# 383
# mult(add(tanh(var_0, N), cos(var_1, N)), neg(cosh(var_2, N), N(N, N)))
# 384
# mult(mult(cos(var_0, N), cos(var_2, N)), sinh(neg(var_1, N), N(N, N)))
# 385
# mult(add(C_0(N, N), var_1(N, N)), mult(sinh(var_2, N), sqrt(var_0, N)))
# 386
# mult(add(tanh(var_1, N), log(var_2, N)), sqrt(sqrt(var_0, N), N(N, N)))
# 387
# add(sinh(cos(var_1, N), N(N, N)), reverse(mult(var_0, var_2), N(N, N)))
# 388
# add(log(add(var_2, var_1), N(N, N)), cosh(neg(var_0, N), N(N, N)))
# 389
# add(mult(sinh(var_2, N), cos(var_0, N)), sqrt(reverse(var_1, N), N(N, N)))
# 390
# add(pow_2(tan(var_0, N), N(N, N)), pow_2(mult(var_1, var_2), N(N, N)))
# 391
# mult(sqrt(add(var_2, var_0), N(N, N)), log(mult(var_1, var_2), N(N, N)))
# 392
# add(cos(var_1(N, N), N(N, N)), sin(mult(var_0, var_2), N(N, N)))
# 393
# add(mult(var_2(N, N), add(var_1, var_0)), add(exp(var_2, N), sin(var_2, N)))
# 394
# mult(add(add(var_0, C_0), exp(var_1, N)), tanh(reverse(var_2, N), N(N, N)))
# 395
# mult(add(pow_2(var_0, N), mult(var_1, C_0)), reverse(log(var_2, N), N(N, N)))
# 396
# mult(sqrt(add(var_2, var_1), N(N, N)), sinh(cos(var_0, N), N(N, N)))
# 397
# mult(sqrt(sinh(var_1, N), N(N, N)), cos(add(var_2, var_0), N(N, N)))
# 398
# tan(mult(mult(var_0, var_2), tan(var_1, N)), N(N(N, N), N(N, N)))
# 399
# add(add(cosh(var_1, N), sin(var_2, N)), gaussian(tan(var_0, N), N(N, N)))
# 400
# add(mult(cosh(var_0, N), var_2(N, N)), tanh(add(var_1, C_0), N(N, N)))
# 401
# mult(sin(mult(var_1, var_0), N(N, N)), pow_2(sqrt(var_2, N), N(N, N)))
# 402
# cosh(add(add(var_1, var_0), add(var_2, C_0)), N(N(N, N), N(N, N)))
# 403
# mult(add(gaussian(var_1, N), neg(var_2, N)), mult(C_0(N, N), add(var_0, C_1)))
# 404
# add(neg(mult(var_2, var_2), N(N, N)), tanh(mult(var_0, var_1), N(N, N)))
# 405
# add(tanh(mult(var_0, var_2), N(N, N)), sinh(reverse(var_1, N), N(N, N)))
# 406
# add(mult(reverse(var_0, N), add(var_2, C_0)), pow_2(log(var_1, N), N(N, N)))
# 407
# mult(neg(add(var_1, var_2), N(N, N)), tanh(neg(var_0, N), N(N, N)))
# 408
# add(log(add(var_1, var_0), N(N, N)), pow_2(neg(var_2, N), N(N, N)))
# 409
# mult(reverse(mult(var_1, var_0), N(N, N)), exp(cosh(var_2, N), N(N, N)))
# 410
# add(mult(pow_2(var_1, N), neg(var_0, N)), tanh(cos(var_2, N), N(N, N)))
# 411
# add(add(gaussian(var_0, N), log(var_1, N)), tanh(neg(var_2, N), N(N, N)))
# 412
# mult(add(gaussian(var_2, N), reverse(var_1, N)), log(mult(var_1, var_0), N(N, N)))
# 413
# add(tan(mult(var_1, var_2), N(N, N)), sin(add(var_0, C_0), N(N, N)))
# 414
# mult(mult(add(var_2, C_0), reverse(var_0, N)), sqrt(var_1(N, N), N(N, N)))
# 415
# add(mult(gaussian(var_1, N), C_0(N, N)), tanh(add(var_0, var_2), N(N, N)))
# 416
# add(gaussian(cos(var_0, N), N(N, N)), tanh(add(var_2, var_1), N(N, N)))
# 417
# mult(sin(pow_2(var_1, N), N(N, N)), sinh(add(var_2, var_0), N(N, N)))
# 418
# add(cosh(add(var_1, var_2), N(N, N)), pow_2(exp(var_0, N), N(N, N)))
# 419
# add(mult(var_2(N, N), mult(var_0, var_1)), cos(mult(var_0, var_0), N(N, N)))
# 420
# add(pow_2(add(var_2, var_1), N(N, N)), neg(log(var_0, N), N(N, N)))
# 421
# add(cos(mult(var_0, var_1), N(N, N)), sinh(mult(var_2, var_0), N(N, N)))
# 422
# mult(reverse(sinh(var_1, N), N(N, N)), cosh(add(var_2, var_0), N(N, N)))
# 423
# add(sinh(add(var_2, var_0), N(N, N)), tan(neg(var_1, N), N(N, N)))
# 424
# add(mult(sin(var_1, N), exp(var_0, N)), cos(reverse(var_2, N), N(N, N)))
# 425
# add(reverse(mult(var_2, var_1), N(N, N)), sqrt(exp(var_0, N), N(N, N)))
# 426
# add(cosh(sqrt(var_2, N), N(N, N)), sqrt(mult(var_1, var_0), N(N, N)))
# 427
# mult(add(cosh(var_2, N), cos(var_2, N)), add(gaussian(var_1, N), cos(var_0, N)))
# 428
# mult(add(pow_2(var_2, N), pow_2(var_0, N)), gaussian(neg(var_1, N), N(N, N)))
# 429
# add(add(var_0(N, N), reverse(var_1, N)), mult(C_0(N, N), sqrt(var_2, N)))
# 430
# mult(add(add(var_1, var_0), gaussian(var_2, N)), sin(add(var_1, var_0), N(N, N)))
# 431
# mult(add(mult(var_2, C_0), tan(var_1, N)), pow_2(mult(var_0, var_0), N(N, N)))
# 432
# mult(reverse(add(var_0, C_0), N(N, N)), exp(mult(var_1, var_2), N(N, N)))
# 433
# add(mult(neg(var_1, N), mult(var_0, var_0)), neg(tan(var_2, N), N(N, N)))
# 434
# mult(mult(C_0(N, N), mult(var_2, var_1)), sinh(sin(var_0, N), N(N, N)))
# 435
# add(log(neg(var_0, N), N(N, N)), log(mult(var_2, var_1), N(N, N)))
# 436
# mult(sin(mult(var_1, var_2), N(N, N)), sinh(gaussian(var_0, N), N(N, N)))
# 437
# add(sinh(mult(var_0, var_2), N(N, N)), reverse(gaussian(var_1, N), N(N, N)))
# 438
# mult(add(add(var_0, C_0), tanh(var_1, N)), sinh(sqrt(var_2, N), N(N, N)))
# 439
# add(add(cos(var_2, N), exp(var_0, N)), sqrt(tanh(var_1, N), N(N, N)))
# 440
# mult(add(sqrt(var_2, N), pow_2(var_0, N)), pow_2(sin(var_1, N), N(N, N)))
# 441
# mult(log(sinh(var_0, N), N(N, N)), cosh(mult(var_1, var_2), N(N, N)))
# 442
# reverse(add(tanh(var_0, N), add(var_1, var_2)), N(N(N, N), N(N, N)))
# 443
# mult(log(mult(var_2, var_0), N(N, N)), sqrt(mult(var_1, C_0), N(N, N)))
# 444
# mult(sqrt(reverse(var_1, N), N(N, N)), sin(add(var_0, var_2), N(N, N)))
# 445
# add(pow_2(tan(var_0, N), N(N, N)), exp(mult(var_2, var_1), N(N, N)))
# 446
# add(mult(gaussian(var_2, N), cosh(var_1, N)), sinh(mult(var_1, var_0), N(N, N)))
# 447
# mult(pow_2(mult(var_2, var_1), N(N, N)), tanh(log(var_0, N), N(N, N)))
# 448
# log(add(add(var_1, var_2), mult(var_0, C_0)), N(N(N, N), N(N, N)))
# 449
# gaussian(add(var_1(N, N), add(var_2, var_0)), N(N(N, N), N(N, N)))
# 450
# add(sqrt(mult(var_2, var_1), N(N, N)), neg(add(var_0, C_0), N(N, N)))
# 451
# add(sqrt(mult(var_2, var_0), N(N, N)), sqrt(cosh(var_1, N), N(N, N)))
# 452
# add(log(add(var_1, var_0), N(N, N)), tan(var_2(N, N), N(N, N)))
# 453
# mult(neg(add(var_2, var_0), N(N, N)), exp(reverse(var_1, N), N(N, N)))
# 454
# mult(tan(var_2(N, N), N(N, N)), sinh(add(var_0, var_1), N(N, N)))
# 455
# mult(mult(cos(var_0, N), gaussian(var_2, N)), neg(gaussian(var_1, N), N(N, N)))
# 456
# mult(gaussian(mult(var_0, var_1), N(N, N)), reverse(gaussian(var_2, N), N(N, N)))
# 457
# mult(sin(mult(var_2, C_0), N(N, N)), sin(add(var_0, var_1), N(N, N)))
# 458
# mult(add(mult(var_0, var_0), add(var_0, var_1)), cosh(sinh(var_2, N), N(N, N)))
# 459
# add(log(mult(var_0, var_1), N(N, N)), cosh(var_2(N, N), N(N, N)))
# 460
# add(sinh(reverse(var_1, N), N(N, N)), reverse(add(var_2, var_0), N(N, N)))
# 461
# mult(sin(add(var_1, C_0), N(N, N)), tan(add(var_2, var_0), N(N, N)))
# 462
# add(tanh(mult(var_2, var_2), N(N, N)), cosh(mult(var_1, var_0), N(N, N)))
# 463
# add(mult(gaussian(var_0, N), neg(var_2, N)), gaussian(mult(var_1, C_0), N(N, N)))
# 464
# mult(neg(cos(var_0, N), N(N, N)), log(add(var_1, var_2), N(N, N)))
# 465
# mult(tan(add(var_0, var_2), N(N, N)), log(tanh(var_1, N), N(N, N)))
# 466
# add(add(gaussian(var_0, N), log(var_2, N)), log(tan(var_1, N), N(N, N)))
# 467
# add(sinh(reverse(var_2, N), N(N, N)), sin(mult(var_0, var_1), N(N, N)))
# 468
# add(pow_2(sin(var_1, N), N(N, N)), reverse(add(var_2, var_0), N(N, N)))
# 469
# add(gaussian(add(var_1, var_2), N(N, N)), tan(neg(var_0, N), N(N, N)))
# 470
# mult(tanh(var_2(N, N), N(N, N)), log(mult(var_0, var_1), N(N, N)))
# 471
# mult(add(C_0(N, N), mult(var_2, C_1)), tanh(mult(var_1, var_0), N(N, N)))
# 472
# mult(mult(reverse(var_1, N), reverse(var_1, N)), tan(add(var_2, var_0), N(N, N)))
# 473
# add(pow_2(cos(var_0, N), N(N, N)), log(mult(var_2, var_1), N(N, N)))
# 474
# mult(sin(mult(var_0, C_0), N(N, N)), neg(add(var_1, var_2), N(N, N)))
# 475
# add(exp(tanh(var_0, N), N(N, N)), cos(add(var_2, var_1), N(N, N)))
# 476
# add(add(tan(var_0, N), cosh(var_2, N)), exp(cosh(var_1, N), N(N, N)))
# 477
# mult(exp(add(var_1, C_0), N(N, N)), tanh(add(var_0, var_2), N(N, N)))
# 478
# mult(add(tanh(var_0, N), var_2(N, N)), log(cosh(var_1, N), N(N, N)))
# 479
# add(reverse(mult(var_2, var_1), N(N, N)), pow_2(tanh(var_0, N), N(N, N)))
# 480
# mult(mult(cosh(var_0, N), var_1(N, N)), cos(add(var_2, C_0), N(N, N)))
# 481
# add(add(add(var_0, C_0), tan(var_2, N)), cosh(add(var_1, C_1), N(N, N)))
# 482
# add(add(tanh(var_0, N), exp(var_1, N)), pow_2(gaussian(var_2, N), N(N, N)))
# 483
# mult(mult(sinh(var_2, N), log(var_1, N)), cos(sqrt(var_0, N), N(N, N)))
# 484
# add(neg(exp(var_2, N), N(N, N)), cos(add(var_1, var_0), N(N, N)))
# 485
# add(mult(mult(var_2, var_1), C_0(N, N)), tan(mult(var_0, var_0), N(N, N)))
# 486
# add(neg(cosh(var_0, N), N(N, N)), pow_2(mult(var_2, var_1), N(N, N)))
# 487
# mult(mult(tanh(var_0, N), add(var_2, C_0)), gaussian(mult(var_1, var_2), N(N, N)))
# 488
# add(add(add(var_2, var_0), sqrt(var_0, N)), log(neg(var_1, N), N(N, N)))
# 489
# mult(reverse(sin(var_0, N), N(N, N)), cos(add(var_2, var_1), N(N, N)))
# 490
# add(mult(add(var_2, var_1), var_0(N, N)), log(mult(var_2, C_0), N(N, N)))
# 491
# add(tan(mult(var_0, var_2), N(N, N)), reverse(gaussian(var_1, N), N(N, N)))
# 492
# add(exp(mult(var_2, var_1), N(N, N)), exp(add(var_2, var_0), N(N, N)))
# 493
# add(neg(cosh(var_1, N), N(N, N)), neg(mult(var_2, var_0), N(N, N)))
# 494
# add(mult(tan(var_2, N), cosh(var_0, N)), tanh(gaussian(var_1, N), N(N, N)))
# 495
# mult(neg(sin(var_2, N), N(N, N)), pow_2(mult(var_1, var_0), N(N, N)))
# 496
# mult(add(pow_2(var_1, N), reverse(var_2, N)), cosh(add(var_0, C_0), N(N, N)))
# 497
# mult(gaussian(reverse(var_2, N), N(N, N)), sinh(add(var_1, var_0), N(N, N)))
# 498
# add(sinh(mult(var_1, var_0), N(N, N)), sin(gaussian(var_2, N), N(N, N)))
# 499
# mult(mult(sqrt(var_0, N), reverse(var_1, N)), pow_2(add(var_2, var_0), N(N, N)))
# 500
# add(log(cos(var_0, N), N(N, N)), sqrt(add(var_1, var_2), N(N, N)))
# 501
# add(neg(mult(var_0, var_1), N(N, N)), tanh(sqrt(var_2, N), N(N, N)))
# 502
# add(cos(add(var_2, var_1), N(N, N)), pow_2(sqrt(var_0, N), N(N, N)))
# 503
# gaussian(add(pow_2(var_2, N), mult(var_1, var_0)), N(N(N, N), N(N, N)))
# 504
# mult(tan(add(var_1, var_0), N(N, N)), neg(mult(var_2, C_0), N(N, N)))
# 505
# mult(mult(mult(var_2, var_1), tan(var_0, N)), sinh(sin(var_1, N), N(N, N)))
# 506
# mult(log(mult(var_0, var_1), N(N, N)), gaussian(tan(var_2, N), N(N, N)))
# 507
# mult(sqrt(mult(var_0, var_1), N(N, N)), log(reverse(var_2, N), N(N, N)))
# 508
# mult(sqrt(add(var_0, var_1), N(N, N)), gaussian(reverse(var_2, N), N(N, N)))
# 509
# mult(gaussian(mult(var_2, var_0), N(N, N)), reverse(neg(var_1, N), N(N, N)))
# 510
# mult(add(log(var_2, N), cos(var_0, N)), gaussian(sqrt(var_1, N), N(N, N)))
# 511
# add(add(tan(var_0, N), reverse(var_2, N)), sqrt(gaussian(var_1, N), N(N, N)))
# 512
# mult(log(tanh(var_1, N), N(N, N)), gaussian(add(var_2, var_0), N(N, N)))
# 513
# mult(add(var_2(N, N), tanh(var_1, N)), sqrt(log(var_0, N), N(N, N)))
# 514
# add(add(sqrt(var_1, N), sqrt(var_2, N)), add(tanh(var_1, N), exp(var_0, N)))
# 515
# add(sinh(neg(var_1, N), N(N, N)), gaussian(add(var_2, var_0), N(N, N)))
# 516
# mult(mult(sqrt(var_0, N), sin(var_2, N)), neg(cosh(var_1, N), N(N, N)))
# 517
# mult(add(tanh(var_0, N), exp(var_1, N)), reverse(exp(var_2, N), N(N, N)))
# 518
# mult(mult(log(var_2, N), exp(var_1, N)), log(cos(var_0, N), N(N, N)))
# 519
# add(mult(reverse(var_0, N), sin(var_2, N)), add(tanh(var_2, N), mult(var_1, C_0)))
# 520
# add(sin(mult(var_2, C_0), N(N, N)), pow_2(add(var_0, var_1), N(N, N)))
# 521
# mult(cos(mult(var_2, var_0), N(N, N)), cosh(mult(var_1, C_0), N(N, N)))
# 522
# add(cos(mult(var_1, C_0), N(N, N)), cosh(add(var_2, var_0), N(N, N)))
# 523
# mult(mult(tanh(var_0, N), cos(var_1, N)), sinh(log(var_2, N), N(N, N)))
# 524
# sqrt(mult(tan(var_0, N), mult(var_1, var_2)), N(N(N, N), N(N, N)))
# 525
# add(add(cosh(var_0, N), cosh(var_1, N)), neg(mult(var_1, var_2), N(N, N)))
# 526
# mult(gaussian(neg(var_2, N), N(N, N)), cosh(mult(var_1, var_0), N(N, N)))
# 527
# mult(mult(sin(var_2, N), log(var_1, N)), reverse(exp(var_0, N), N(N, N)))
# 528
# add(mult(pow_2(var_0, N), tan(var_1, N)), neg(reverse(var_2, N), N(N, N)))
# 529
# add(cosh(mult(var_1, var_2), N(N, N)), tan(mult(var_0, var_2), N(N, N)))
# 530
# mult(mult(neg(var_0, N), neg(var_2, N)), cosh(gaussian(var_1, N), N(N, N)))
# 531
# add(mult(mult(var_0, C_0), cosh(var_2, N)), exp(mult(var_2, var_1), N(N, N)))
# 532
# mult(tanh(exp(var_0, N), N(N, N)), sinh(mult(var_1, var_2), N(N, N)))
# 533
# add(add(add(var_1, C_0), var_0(N, N)), log(cos(var_2, N), N(N, N)))
# 534
# mult(reverse(mult(var_1, C_0), N(N, N)), cos(mult(var_2, var_0), N(N, N)))
# 535
# add(sqrt(neg(var_0, N), N(N, N)), cos(add(var_1, var_2), N(N, N)))
# 536
# add(tan(add(var_2, var_1), N(N, N)), tanh(add(var_0, var_2), N(N, N)))
# 537
# mult(mult(tanh(var_0, N), sqrt(var_2, N)), exp(cosh(var_1, N), N(N, N)))
# 538
# add(log(add(var_1, var_0), N(N, N)), log(cos(var_2, N), N(N, N)))
# 539
# mult(log(mult(var_2, var_1), N(N, N)), exp(sinh(var_0, N), N(N, N)))
# 540
# add(mult(sqrt(var_1, N), C_0(N, N)), add(var_0(N, N), sinh(var_2, N)))
# 541
# add(mult(add(var_1, var_0), mult(var_0, C_0)), cos(add(var_2, C_1), N(N, N)))
# 542
# mult(pow_2(add(var_0, C_0), N(N, N)), tanh(add(var_2, var_1), N(N, N)))
# 543
# mult(sin(add(var_1, var_2), N(N, N)), cosh(reverse(var_0, N), N(N, N)))
# 544
# add(mult(add(var_0, C_0), tan(var_2, N)), mult(add(var_1, var_0), tanh(var_0, N)))
# 545
# mult(mult(add(var_1, var_2), tan(var_1, N)), cos(mult(var_0, C_0), N(N, N)))
# 546
# mult(gaussian(add(var_2, var_1), N(N, N)), sqrt(neg(var_0, N), N(N, N)))
# 547
# add(mult(exp(var_1, N), cosh(var_2, N)), reverse(pow_2(var_0, N), N(N, N)))
# 548
# mult(reverse(mult(var_0, var_1), N(N, N)), log(mult(var_2, var_2), N(N, N)))
# 549
# mult(mult(add(var_2, C_0), sinh(var_1, N)), sin(mult(var_0, C_1), N(N, N)))
# 550
# mult(tanh(mult(var_2, var_1), N(N, N)), sinh(var_0(N, N), N(N, N)))
# 551
# mult(gaussian(tan(var_0, N), N(N, N)), exp(mult(var_1, var_2), N(N, N)))
# 552
# mult(sqrt(add(var_1, var_2), N(N, N)), cosh(neg(var_0, N), N(N, N)))
# 553
# mult(tan(add(var_2, var_0), N(N, N)), neg(var_1(N, N), N(N, N)))
# 554
# add(add(cos(var_0, N), tan(var_1, N)), sqrt(log(var_2, N), N(N, N)))
# 555
# add(log(pow_2(var_1, N), N(N, N)), neg(add(var_2, var_0), N(N, N)))
# 556
# add(sqrt(mult(var_0, var_1), N(N, N)), sinh(pow_2(var_2, N), N(N, N)))
# 557
# add(sin(add(var_1, var_0), N(N, N)), tanh(sinh(var_2, N), N(N, N)))
# 558
# mult(add(neg(var_0, N), cosh(var_1, N)), sinh(sqrt(var_2, N), N(N, N)))
# 559
# mult(add(tanh(var_2, N), neg(var_0, N)), cosh(cos(var_1, N), N(N, N)))
# 560
# mult(add(gaussian(var_1, N), cosh(var_2, N)), sinh(gaussian(var_0, N), N(N, N)))
# 561
# add(add(log(var_0, N), sinh(var_1, N)), exp(tanh(var_2, N), N(N, N)))
# 562
# mult(mult(tan(var_2, N), tanh(var_0, N)), cos(gaussian(var_1, N), N(N, N)))
# 563
# add(tan(add(var_0, C_0), N(N, N)), pow_2(mult(var_1, var_2), N(N, N)))
# 564
# mult(add(cos(var_2, N), tanh(var_1, N)), neg(sqrt(var_0, N), N(N, N)))
# 565
# add(sqrt(add(var_1, var_2), N(N, N)), cosh(sin(var_0, N), N(N, N)))
# 566
# mult(add(neg(var_1, N), C_0(N, N)), cos(add(var_0, var_2), N(N, N)))
# 567
# add(tan(reverse(var_0, N), N(N, N)), neg(mult(var_2, var_1), N(N, N)))
# 568
# add(mult(tanh(var_0, N), add(var_2, C_0)), gaussian(pow_2(var_1, N), N(N, N)))
# 569
# add(mult(add(var_0, C_0), var_2(N, N)), add(add(var_2, C_1), add(var_2, var_1)))
# 570
# mult(add(tanh(var_2, N), cos(var_0, N)), sinh(cosh(var_1, N), N(N, N)))
# 571
# mult(neg(mult(var_0, var_1), N(N, N)), reverse(var_2(N, N), N(N, N)))
# 572
# mult(cosh(mult(var_0, var_2), N(N, N)), tanh(reverse(var_1, N), N(N, N)))
# 573
# mult(sqrt(neg(var_1, N), N(N, N)), exp(mult(var_0, var_2), N(N, N)))
# 574
# mult(mult(tan(var_2, N), gaussian(var_0, N)), reverse(pow_2(var_1, N), N(N, N)))
# 575
# add(mult(add(var_2, var_2), mult(var_0, var_2)), tanh(pow_2(var_1, N), N(N, N)))
# 576
# add(add(gaussian(var_0, N), mult(var_1, C_0)), tanh(pow_2(var_2, N), N(N, N)))
# 577
# mult(add(sinh(var_2, N), exp(var_0, N)), reverse(mult(var_1, C_0), N(N, N)))
# 578
# add(mult(neg(var_1, N), var_0(N, N)), sqrt(gaussian(var_2, N), N(N, N)))
# 579
# add(neg(sinh(var_0, N), N(N, N)), pow_2(add(var_2, var_1), N(N, N)))
# 580
# mult(gaussian(add(var_1, var_0), N(N, N)), neg(sin(var_2, N), N(N, N)))
# 581
# mult(tan(add(var_2, var_1), N(N, N)), exp(var_0(N, N), N(N, N)))
# 582
# add(cosh(neg(var_2, N), N(N, N)), tan(mult(var_1, var_0), N(N, N)))
# 583
# add(pow_2(cos(var_2, N), N(N, N)), cos(mult(var_0, var_1), N(N, N)))
# 584
# mult(tan(mult(var_0, var_2), N(N, N)), cos(reverse(var_1, N), N(N, N)))
# 585
# add(mult(reverse(var_1, N), cosh(var_0, N)), sqrt(neg(var_2, N), N(N, N)))
# 586
# mult(mult(tanh(var_1, N), var_0(N, N)), pow_2(log(var_2, N), N(N, N)))
# 587
# mult(gaussian(add(var_1, var_0), N(N, N)), cosh(neg(var_2, N), N(N, N)))
# 588
# mult(add(cos(var_2, N), cosh(var_2, N)), add(add(var_0, C_0), gaussian(var_1, N)))
# 589
# mult(add(add(var_1, var_0), mult(var_0, var_2)), cos(reverse(var_2, N), N(N, N)))
# 590
# mult(exp(add(var_2, var_0), N(N, N)), pow_2(log(var_1, N), N(N, N)))
# 591
# add(sqrt(mult(var_0, var_2), N(N, N)), sinh(exp(var_1, N), N(N, N)))
# 592
# add(sqrt(cosh(var_0, N), N(N, N)), tanh(add(var_1, var_2), N(N, N)))
# 593
# mult(mult(var_1(N, N), add(var_0, var_2)), tanh(cos(var_0, N), N(N, N)))
# 594
# add(sinh(neg(var_2, N), N(N, N)), tan(mult(var_0, var_1), N(N, N)))
# 595
# add(add(log(var_2, N), sinh(var_1, N)), mult(sinh(var_2, N), var_0(N, N)))
# 596
# add(sin(add(var_1, var_0), N(N, N)), log(mult(var_2, var_2), N(N, N)))
# 597
# mult(mult(add(var_1, var_0), log(var_2, N)), exp(mult(var_2, C_0), N(N, N)))
# 598
# add(mult(mult(var_0, var_1), tan(var_2, N)), sinh(cos(var_0, N), N(N, N)))
# 599
# mult(add(exp(var_2, N), pow_2(var_1, N)), pow_2(tanh(var_0, N), N(N, N)))
# 600
# add(mult(mult(var_0, var_2), reverse(var_1, N)), cos(sqrt(var_1, N), N(N, N)))
# 601
# add(pow_2(mult(var_2, var_0), N(N, N)), log(add(var_1, C_0), N(N, N)))
# 602
# mult(reverse(add(var_0, var_1), N(N, N)), gaussian(sinh(var_2, N), N(N, N)))
# 603
# add(tanh(mult(var_1, var_2), N(N, N)), sqrt(pow_2(var_0, N), N(N, N)))
# 604
# tanh(mult(mult(var_2, var_0), sinh(var_1, N)), N(N(N, N), N(N, N)))
# 605
# add(sin(mult(var_0, var_2), N(N, N)), sinh(cos(var_1, N), N(N, N)))
# 606
# mult(mult(reverse(var_1, N), exp(var_0, N)), add(sqrt(var_2, N), cosh(var_1, N)))
# 607
# mult(log(add(var_0, C_0), N(N, N)), sinh(add(var_1, var_2), N(N, N)))
# 608
# add(mult(sinh(var_0, N), gaussian(var_1, N)), neg(sinh(var_2, N), N(N, N)))
# 609
# add(tan(mult(var_1, var_2), N(N, N)), cos(gaussian(var_0, N), N(N, N)))
# 610
# add(neg(add(var_1, var_0), N(N, N)), cos(add(var_2, var_0), N(N, N)))
# 611
# mult(mult(log(var_1, N), sqrt(var_2, N)), tanh(var_0(N, N), N(N, N)))
# 612
# add(gaussian(mult(var_1, var_0), N(N, N)), exp(sinh(var_2, N), N(N, N)))
# 613
# add(exp(tan(var_0, N), N(N, N)), exp(add(var_1, var_2), N(N, N)))
# 614
# mult(cosh(gaussian(var_0, N), N(N, N)), sqrt(mult(var_1, var_2), N(N, N)))
# 615
# mult(reverse(add(var_0, var_1), N(N, N)), pow_2(cos(var_2, N), N(N, N)))
# 616
# mult(cosh(mult(var_2, var_1), N(N, N)), cosh(mult(var_0, C_0), N(N, N)))
# 617
# mult(pow_2(add(var_2, var_1), N(N, N)), cosh(gaussian(var_0, N), N(N, N)))
# 618
# add(neg(gaussian(var_0, N), N(N, N)), sinh(add(var_1, var_2), N(N, N)))
# 619
# exp(mult(add(var_0, var_1), sqrt(var_2, N)), N(N(N, N), N(N, N)))
# 620
# mult(sinh(var_0(N, N), N(N, N)), gaussian(mult(var_2, var_1), N(N, N)))
# 621
# add(sqrt(neg(var_0, N), N(N, N)), tanh(mult(var_1, var_2), N(N, N)))
# 622
# add(add(sin(var_2, N), tan(var_0, N)), pow_2(log(var_1, N), N(N, N)))
# 623
# add(add(sqrt(var_1, N), mult(var_0, C_0)), sqrt(sinh(var_2, N), N(N, N)))
# 624
# add(add(pow_2(var_1, N), cosh(var_0, N)), cosh(tan(var_2, N), N(N, N)))
# 625
# add(gaussian(add(var_2, var_0), N(N, N)), sqrt(sinh(var_1, N), N(N, N)))
# 626
# mult(cosh(add(var_0, var_2), N(N, N)), pow_2(neg(var_1, N), N(N, N)))
# 627
# add(reverse(add(var_0, var_1), N(N, N)), sinh(cos(var_2, N), N(N, N)))
# 628
# cos(mult(tan(var_2, N), add(var_1, var_0)), N(N(N, N), N(N, N)))
# 629
# mult(mult(add(var_0, C_0), neg(var_2, N)), mult(exp(var_2, N), add(var_1, C_1)))
# 630
# mult(gaussian(sqrt(var_0, N), N(N, N)), sqrt(add(var_2, var_1), N(N, N)))
# 631
# add(add(sqrt(var_0, N), mult(var_1, C_0)), reverse(cosh(var_2, N), N(N, N)))
# 632
# add(add(reverse(var_2, N), cos(var_0, N)), sqrt(cosh(var_1, N), N(N, N)))
# 633
# mult(mult(add(var_1, var_1), cosh(var_0, N)), reverse(add(var_2, C_0), N(N, N)))
# 634
# pow_2(add(add(var_1, C_0), mult(var_2, var_0)), N(N(N, N), N(N, N)))
# 635
# add(mult(add(var_2, var_1), gaussian(var_0, N)), add(sin(var_1, N), tan(var_0, N)))
# 636
# mult(cosh(mult(var_0, var_1), N(N, N)), reverse(cos(var_2, N), N(N, N)))
# 637
# mult(add(cos(var_1, N), sin(var_2, N)), log(cos(var_0, N), N(N, N)))
# 638
# mult(exp(add(var_0, var_2), N(N, N)), tan(sqrt(var_1, N), N(N, N)))
# 639
# mult(pow_2(log(var_1, N), N(N, N)), exp(mult(var_2, var_0), N(N, N)))
# 640
# mult(mult(sqrt(var_2, N), pow_2(var_0, N)), log(cos(var_1, N), N(N, N)))
# 641
# mult(reverse(add(var_0, var_2), N(N, N)), cosh(cosh(var_1, N), N(N, N)))
# 642
# add(mult(sqrt(var_2, N), pow_2(var_1, N)), cos(pow_2(var_0, N), N(N, N)))
# 643
# mult(mult(add(var_2, C_0), mult(var_2, var_1)), sinh(tan(var_0, N), N(N, N)))
# 644
# add(mult(mult(var_1, var_0), tanh(var_2, N)), tanh(C_0(N, N), N(N, N)))
# 645
# add(reverse(tanh(var_1, N), N(N, N)), log(mult(var_2, var_0), N(N, N)))
# 646
# add(sinh(cos(var_0, N), N(N, N)), neg(mult(var_2, var_1), N(N, N)))
# 647
# pow_2(mult(add(var_0, var_2), pow_2(var_1, N)), N(N(N, N), N(N, N)))
# 648
# mult(mult(sin(var_0, N), exp(var_1, N)), cosh(tan(var_2, N), N(N, N)))
# 649
# add(sinh(sqrt(var_2, N), N(N, N)), cosh(add(var_1, var_0), N(N, N)))
# 650
# mult(cos(reverse(var_2, N), N(N, N)), exp(mult(var_0, var_1), N(N, N)))
# 651
# mult(exp(mult(var_0, var_2), N(N, N)), cosh(log(var_1, N), N(N, N)))
# 652
# add(gaussian(add(var_1, var_2), N(N, N)), log(tanh(var_0, N), N(N, N)))
# 653
# add(reverse(add(var_0, C_0), N(N, N)), pow_2(add(var_2, var_1), N(N, N)))
# 654
# add(mult(mult(var_1, var_2), sin(var_2, N)), cosh(add(var_0, var_2), N(N, N)))
# 655
# mult(reverse(pow_2(var_2, N), N(N, N)), cosh(mult(var_0, var_1), N(N, N)))
# 656
# mult(add(tanh(var_2, N), mult(var_1, C_0)), add(neg(var_2, N), cos(var_0, N)))
# 657
# mult(add(add(var_2, var_2), add(var_1, var_0)), log(reverse(var_1, N), N(N, N)))
# 658
# mult(add(pow_2(var_2, N), pow_2(var_1, N)), cosh(var_0(N, N), N(N, N)))
# 659
# reverse(add(add(var_2, var_1), sin(var_0, N)), N(N(N, N), N(N, N)))
# 660
# mult(mult(neg(var_0, N), var_2(N, N)), log(cosh(var_1, N), N(N, N)))
# 661
# mult(cosh(add(var_0, var_1), N(N, N)), exp(mult(var_2, var_2), N(N, N)))
# 662
# add(mult(exp(var_0, N), exp(var_1, N)), cosh(log(var_2, N), N(N, N)))
# 663
# mult(cos(var_1(N, N), N(N, N)), tanh(add(var_2, var_0), N(N, N)))
# 664
# mult(mult(mult(var_0, C_0), cos(var_2, N)), tan(mult(var_1, C_1), N(N, N)))
# 665
# mult(cos(sqrt(var_1, N), N(N, N)), pow_2(mult(var_2, var_0), N(N, N)))
# 666
# mult(reverse(cosh(var_1, N), N(N, N)), log(add(var_0, var_2), N(N, N)))
# 667
# mult(log(mult(var_2, var_0), N(N, N)), cos(mult(var_1, C_0), N(N, N)))
# 668
# add(mult(tanh(var_1, N), sqrt(var_0, N)), sin(neg(var_2, N), N(N, N)))
# 669
# add(sinh(mult(var_2, var_1), N(N, N)), tanh(log(var_0, N), N(N, N)))
# 670
# mult(mult(cosh(var_0, N), cosh(var_1, N)), cosh(reverse(var_2, N), N(N, N)))
# 671
# add(add(gaussian(var_2, N), neg(var_0, N)), reverse(sqrt(var_1, N), N(N, N)))
# 672
# add(tanh(add(var_2, var_1), N(N, N)), reverse(mult(var_2, var_0), N(N, N)))
# 673
# gaussian(add(mult(var_1, var_2), sinh(var_0, N)), N(N(N, N), N(N, N)))
# 674
# add(tan(add(var_2, var_0), N(N, N)), log(tan(var_1, N), N(N, N)))
# 675
# mult(mult(add(var_1, C_0), sqrt(var_0, N)), cosh(sin(var_2, N), N(N, N)))
# 676
# mult(mult(mult(var_2, C_0), pow_2(var_0, N)), tanh(cosh(var_1, N), N(N, N)))
# 677
# mult(cos(add(var_1, var_2), N(N, N)), neg(tanh(var_0, N), N(N, N)))
# 678
# add(add(mult(var_2, C_0), gaussian(var_1, N)), cosh(add(var_0, var_1), N(N, N)))
# 679
# mult(mult(var_1(N, N), gaussian(var_0, N)), exp(mult(var_2, var_0), N(N, N)))
# 680
# mult(mult(add(var_2, var_1), C_0(N, N)), tan(mult(var_0, var_1), N(N, N)))
# 681
# add(cosh(add(var_0, C_0), N(N, N)), gaussian(mult(var_1, var_2), N(N, N)))
# 682
# add(mult(neg(var_0, N), reverse(var_2, N)), reverse(mult(var_1, C_0), N(N, N)))
# 683
# mult(tanh(mult(var_2, var_1), N(N, N)), reverse(var_0(N, N), N(N, N)))
# 684
# mult(tan(mult(var_1, C_0), N(N, N)), neg(add(var_2, var_0), N(N, N)))
# 685
# add(gaussian(mult(var_1, var_2), N(N, N)), exp(neg(var_0, N), N(N, N)))
# 686
# add(neg(exp(var_2, N), N(N, N)), sin(add(var_0, var_1), N(N, N)))
# 687
# exp(add(add(var_0, var_1), log(var_2, N)), N(N(N, N), N(N, N)))
# 688
# add(reverse(cosh(var_0, N), N(N, N)), gaussian(add(var_1, var_2), N(N, N)))
# 689
# add(mult(log(var_2, N), mult(var_0, C_0)), pow_2(tanh(var_1, N), N(N, N)))
# 690
# mult(neg(reverse(var_1, N), N(N, N)), sqrt(add(var_2, var_0), N(N, N)))
# 691
# add(cosh(log(var_0, N), N(N, N)), gaussian(mult(var_2, var_1), N(N, N)))
# 692
# mult(reverse(add(var_2, var_0), N(N, N)), cosh(gaussian(var_1, N), N(N, N)))
# 693
# add(pow_2(exp(var_2, N), N(N, N)), sin(mult(var_0, var_1), N(N, N)))
# 694
# mult(reverse(cosh(var_2, N), N(N, N)), cosh(mult(var_0, var_1), N(N, N)))
# 695
# add(mult(var_0(N, N), tan(var_1, N)), neg(sinh(var_2, N), N(N, N)))
# 696
# add(add(sin(var_0, N), tanh(var_1, N)), gaussian(gaussian(var_2, N), N(N, N)))
# 697
# mult(mult(sinh(var_2, N), C_0(N, N)), neg(mult(var_1, var_0), N(N, N)))
# 698
# mult(mult(pow_2(var_1, N), log(var_0, N)), exp(add(var_2, C_0), N(N, N)))
# 699
# add(mult(reverse(var_2, N), cos(var_1, N)), mult(C_0(N, N), var_0(N, N)))
# 700
# gaussian(mult(tanh(var_2, N), mult(var_1, var_0)), N(N(N, N), N(N, N)))
# 701
# mult(add(sinh(var_2, N), tan(var_2, N)), mult(mult(var_0, C_0), var_1(N, N)))
# 702
# add(tanh(mult(var_2, var_0), N(N, N)), sin(mult(var_1, C_0), N(N, N)))
# 703
# mult(tanh(var_0(N, N), N(N, N)), gaussian(add(var_1, var_2), N(N, N)))
# 704
# mult(mult(neg(var_2, N), neg(var_0, N)), gaussian(tanh(var_1, N), N(N, N)))
# 705
# add(add(tan(var_0, N), pow_2(var_2, N)), gaussian(cosh(var_1, N), N(N, N)))
# 706
# mult(mult(neg(var_0, N), exp(var_2, N)), tan(mult(var_1, var_1), N(N, N)))
# 707
# mult(sinh(mult(var_1, var_0), N(N, N)), pow_2(neg(var_2, N), N(N, N)))
# 708
# add(tanh(mult(var_0, var_1), N(N, N)), gaussian(reverse(var_2, N), N(N, N)))
# 709
# mult(gaussian(mult(var_2, var_1), N(N, N)), reverse(tan(var_0, N), N(N, N)))
# 710
# add(cos(mult(var_2, var_0), N(N, N)), reverse(exp(var_1, N), N(N, N)))
# 711
# add(cosh(sin(var_1, N), N(N, N)), cos(add(var_2, var_0), N(N, N)))
# 712
# add(mult(sin(var_1, N), neg(var_2, N)), cosh(mult(var_0, C_0), N(N, N)))
# 713
# mult(reverse(mult(var_2, var_0), N(N, N)), tan(reverse(var_1, N), N(N, N)))
# 714
# mult(add(C_0(N, N), add(var_0, var_2)), pow_2(log(var_1, N), N(N, N)))
# 715
# add(cosh(gaussian(var_0, N), N(N, N)), tan(add(var_1, var_2), N(N, N)))
# 716
# mult(tanh(add(var_0, var_2), N(N, N)), pow_2(tan(var_1, N), N(N, N)))
# 717
# mult(add(cosh(var_1, N), tanh(var_2, N)), sin(gaussian(var_0, N), N(N, N)))
# 718
# add(mult(cos(var_0, N), mult(var_2, C_0)), tanh(sinh(var_1, N), N(N, N)))
# 719
# mult(add(add(var_0, var_1), cosh(var_2, N)), neg(cosh(var_2, N), N(N, N)))
# 720
# add(sin(mult(var_1, var_0), N(N, N)), log(add(var_2, var_0), N(N, N)))
# 721
# mult(sinh(pow_2(var_2, N), N(N, N)), exp(add(var_0, var_1), N(N, N)))
# 722
# mult(log(add(var_1, var_2), N(N, N)), sin(pow_2(var_0, N), N(N, N)))
# 723
# mult(mult(mult(var_0, C_0), tanh(var_1, N)), cosh(sqrt(var_2, N), N(N, N)))
# 724
# mult(gaussian(cos(var_0, N), N(N, N)), sinh(add(var_1, var_2), N(N, N)))
# 725
# mult(mult(tanh(var_1, N), tan(var_0, N)), cos(var_2(N, N), N(N, N)))
# 726
# add(add(sqrt(var_1, N), add(var_2, var_2)), pow_2(add(var_0, var_2), N(N, N)))
# 727
# add(neg(add(var_0, var_1), N(N, N)), sinh(add(var_2, C_0), N(N, N)))
# 728
# mult(mult(gaussian(var_0, N), neg(var_2, N)), sinh(cosh(var_1, N), N(N, N)))
# 729
# add(cosh(add(var_1, var_2), N(N, N)), pow_2(exp(var_0, N), N(N, N)))
# 730
# add(mult(sin(var_0, N), add(var_1, C_0)), cos(pow_2(var_2, N), N(N, N)))
# 731
# mult(sinh(mult(var_0, C_0), N(N, N)), sinh(add(var_2, var_1), N(N, N)))
# 732
# add(sinh(exp(var_0, N), N(N, N)), neg(add(var_2, var_1), N(N, N)))
# 733
# add(add(add(var_1, var_2), tanh(var_2, N)), mult(tanh(var_0, N), tanh(var_2, N)))
# 734
# add(add(add(var_2, C_0), add(var_2, C_1)), cosh(mult(var_0, var_1), N(N, N)))
# 735
# mult(gaussian(add(var_0, var_1), N(N, N)), exp(mult(var_2, C_0), N(N, N)))
# 736
# mult(tan(mult(var_0, var_1), N(N, N)), gaussian(tan(var_2, N), N(N, N)))
# 737
# add(add(mult(var_1, C_0), var_2(N, N)), exp(cos(var_0, N), N(N, N)))
# 738
# mult(add(tanh(var_0, N), tan(var_2, N)), sqrt(tanh(var_1, N), N(N, N)))
# 739
# mult(add(add(var_0, var_2), add(var_2, var_2)), mult(tan(var_0, N), tan(var_1, N)))
# 740
# cos(add(log(var_1, N), add(var_2, var_0)), N(N(N, N), N(N, N)))
# 741
# mult(sin(mult(var_0, var_1), N(N, N)), gaussian(var_2(N, N), N(N, N)))
# 742
# mult(reverse(tan(var_2, N), N(N, N)), pow_2(add(var_0, var_1), N(N, N)))
# 743
# add(add(tanh(var_2, N), neg(var_1, N)), pow_2(reverse(var_0, N), N(N, N)))
# 744
# mult(pow_2(add(var_0, var_1), N(N, N)), log(tan(var_2, N), N(N, N)))
# 745
# add(add(tan(var_2, N), cosh(var_0, N)), cosh(cos(var_1, N), N(N, N)))
# 746
# mult(gaussian(mult(var_0, C_0), N(N, N)), neg(add(var_2, var_1), N(N, N)))

# %%
import torch
import torch.nn as nn
from collections import defaultdict

class FormulaTokenizer:
    def __init__(self):
        self.token_to_id = defaultdict(lambda: self.token_to_id["[UNK]"])  # Default to [UNK] for unknown tokens
        self.token_to_id["[PAD]"] = 0
        self.token_to_id["[START]"] = 1
        self.token_to_id["[END]"] = 2
        self.token_to_id["[UNK]"] = 3
        self.id_to_token = {v: k for k, v in self.token_to_id.items()}

    def tokenize(self, formula):
        tokens = formula.replace("(", " ( ").replace(")", " ) ").replace(",", " , ").split()
        return tokens

    def encode(self, formula):
        tokens = self.tokenize(formula)
        token_ids = [self.token_to_id[token] for token in tokens]
        return [self.token_to_id["[START]"]] + token_ids + [self.token_to_id["[END]"]]

    def decode(self, token_ids):
        tokens = [self.id_to_token[token_id] for token_id in token_ids if token_id in self.id_to_token]
        return " ".join(tokens)

    def build_vocab(self, formulas):
        for formula in formulas:
            tokens = self.tokenize(formula)
            for token in tokens:
                self.token_to_id[token]  # Populate vocabulary
        self.id_to_token = {v: k for k, v in self.token_to_id.items()}


# Embedding model
class FormulaEmbeddingModel(nn.Module):
    def __init__(self, vocab_size, embedding_dim):
        super().__init__()
        self.embedding = nn.Embedding(vocab_size, embedding_dim)

    def forward(self, token_ids):
        return self.embedding(token_ids)

# Generate embeddings for formulas in the train dataset
def generate_embeddings(train_data, embedding_dim=128, max_length=50):
    # Initialize tokenizer and build vocabulary
    tokenizer = FormulaTokenizer()
    all_formulas = [item["formula_human_readable"] for item in train_data]
    tokenizer.build_vocab(all_formulas)

    # Initialize the embedding model
    vocab_size = len(tokenizer.token_to_id)
    embedding_model = FormulaEmbeddingModel(vocab_size, embedding_dim)

    # Tokenize and pad formulas
    tokenized_data = []
    for item in train_data:
        formula = item["formula_human_readable"]
        encoded_formula = tokenizer.encode(formula)

        # Pad or truncate to max_length
        if len(encoded_formula) < max_length:
            encoded_formula += [tokenizer.token_to_id["[PAD]"]] * (max_length - len(encoded_formula))
        else:
            encoded_formula = encoded_formula[:max_length]

        tokenized_data.append(torch.tensor(encoded_formula, dtype=torch.long))

    # Stack tokenized data
    tokenized_tensor = torch.stack(tokenized_data)

    # Generate embeddings
    with torch.no_grad():  # Disable gradients for inference
        embeddings = embedding_model(tokenized_tensor)

    return embeddings, tokenizer, embedding_model

# Call the function with train data
embedding_dim = 128
max_length = 50
embeddings, tokenizer, embedding_model = generate_embeddings(train, embedding_dim, max_length)

# Display embeddings
print(f"Generated embeddings shape: {embeddings.shape}")
# Out:
# Generated embeddings shape: torch.Size([747, 50, 128])

# %%
# Precompute embeddings for train and val
def precompute_embeddings(data, tokenizer, embedding_dim=128, max_length=50):
    vocab_size = len(tokenizer.token_to_id)
    embedding_model = FormulaEmbeddingModel(vocab_size, embedding_dim)

    precomputed = []
    for idx, item in enumerate(data):
        if "formula_human_readable" in item:
            formula = item["formula_human_readable"]
            encoded_formula = tokenizer.encode(formula)

            # Debug: Check if any index exceeds vocab_size
            if any(token_id >= vocab_size for token_id in encoded_formula):
                print(f"Error: Token ID out of range in formula: {formula}")
                continue  # Skip problematic formula

            # Pad or truncate to max_length
            if len(encoded_formula) < max_length:
                encoded_formula += [tokenizer.token_to_id["[PAD]"]] * (max_length - len(encoded_formula))
            else:
                encoded_formula = encoded_formula[:max_length]

            # Convert to tensor and pass through embedding model
            with torch.no_grad():
                token_ids = torch.tensor(encoded_formula, dtype=torch.long).unsqueeze(0)  # Batch size 1
                embedding = embedding_model(token_ids).squeeze(0)  # Remove batch dimension

            precomputed.append((torch.tensor(item["points"]["var_0"], dtype=torch.float32), embedding))

    return precomputed


# Precompute embeddings for train and val datasets
train_precomputed = precompute_embeddings(train, tokenizer, embedding_dim=128, max_length=50)
val_precomputed = precompute_embeddings(val, tokenizer, embedding_dim=128, max_length=50)

# %%
import torch
from torch.utils.data import Dataset, DataLoader
import torch.nn as nn
import torch.optim as optim
import random
import math

# Diffusion Model
class DiffusionModel(nn.Module):
    def __init__(self, embedding_dim, vocab_size):
        super().__init__()
        self.embedding_dim = embedding_dim
        self.vocab_size = vocab_size
        self.model = nn.Sequential(
            nn.Linear(embedding_dim + 1, 256),  # Time embedding added
            nn.ReLU(),
            nn.Linear(256, 256),
            nn.ReLU(),
            nn.Linear(256, embedding_dim)
        )

    def forward(self, x, t):
        """
        Forward pass for the diffusion model.
        Args:
            - x: Noisy embeddings [batch_size, seq_length, embedding_dim]
            - t: Timestep tensor [batch_size]
        Returns:
            - Predicted noise [batch_size, seq_length, embedding_dim]
        """
        # Expand time embeddings to match [batch_size, seq_length, 1]
        t_emb = t.unsqueeze(-1).unsqueeze(-1).repeat(1, x.size(1), 1)  # [batch_size, seq_length, 1]

        # Concatenate time embeddings with input embeddings along the last dimension
        x_t = torch.cat((x, t_emb), dim=-1)  # [batch_size, seq_length, embedding_dim + 1]

        return self.model(x_t)

# Noise Scheduler
def noise_schedule(timesteps, beta_start=1e-4, beta_end=2e-2):
    """
    Creates the noise schedule for the diffusion process.
    Returns:
        - betas: Tensor of size (timesteps,)
        - alpha_cumprod: Cumulative product of (1 - beta_t)
    """
    betas = torch.linspace(beta_start, beta_end, timesteps)
    alphas = 1.0 - betas
    alpha_cumprod = torch.cumprod(alphas, dim=0)
    return betas, alpha_cumprod

# Diffusion Process Utilities
class Diffusion:
    def __init__(self, model, betas, alpha_cumprod, timesteps):
        self.model = model
        self.betas = betas
        self.alpha_cumprod = alpha_cumprod
        self.timesteps = timesteps

    def add_noise(self, x, t):
        """
        Adds Gaussian noise to the input embeddings for the given timestep t.
        Args:
            - x: Original embeddings [batch_size, embedding_dim]
            - t: Timestep [batch_size]
        Returns:
            - x_t: Noisy embeddings [batch_size, embedding_dim]
            - noise: Noise added [batch_size, embedding_dim]
        """
        noise = torch.randn_like(x)  # Shape: [batch_size, seq_length, embedding_dim]
    
        # Expand alpha values to match [batch_size, 1, 1] for broadcasting
        sqrt_alpha_cumprod = self.alpha_cumprod[t].sqrt().view(-1, 1, 1)  # [batch_size, 1, 1]
        sqrt_one_minus_alpha_cumprod = (1 - self.alpha_cumprod[t]).sqrt().view(-1, 1, 1)  # [batch_size, 1, 1]
        
        # Apply noise
        x_t = sqrt_alpha_cumprod * x + sqrt_one_minus_alpha_cumprod * noise  # Broadcasting ensures correct shape
        return x_t, noise
    
    def loss(self, x, t, noise):
        """
        Calculates the loss by predicting the noise added to the embeddings.
        Args:
            - x: Original embeddings
            - t: Timestep
            - noise: Ground truth noise
        Returns:
            - MSE loss
        """
        noisy_x, _ = self.add_noise(x, t)
        pred_noise = self.model(noisy_x, t)
        return nn.MSELoss()(pred_noise, noise)

# Dataset Class for Precomputed Embeddings
class DiffusionDatasetWithEmbeddings(Dataset):
    def __init__(self, precomputed_data):
        self.data = precomputed_data

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        points, embedding = self.data[idx]
        return points, embedding
def train_diffusion_with_embeddings(train_data, val_data, embedding_dim=128, timesteps=1000, epochs=10, batch_size=32):
    # Prepare datasets and dataloaders
    train_dataset = DiffusionDatasetWithEmbeddings(train_data)
    val_dataset = DiffusionDatasetWithEmbeddings(val_data)
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

    # Model and optimizer
    model = DiffusionModel(embedding_dim, embedding_dim)
    print(f"Number of parameters in model: {sum(p.numel() for p in model.parameters())}")
    optimizer = optim.Adam(model.parameters(), lr=1e-3)

    # Diffusion process
    betas, alpha_cumprod = noise_schedule(timesteps)
    diffusion = Diffusion(model, betas, alpha_cumprod, timesteps)

    # Training loop
    for epoch in range(epochs):
        model.train()
        total_loss = 0
        for batch_idx, (points, embeddings) in enumerate(train_loader):
            print(f"Batch {batch_idx + 1}/{len(train_loader)}")
            print(f"Points Shape: {points.shape}, Embeddings Shape: {embeddings.shape}")

            # Add random noise to embeddings
            t = torch.randint(0, timesteps, (points.size(0),), dtype=torch.long)
            print(f"Random Timesteps: {t}")

            noisy_embeddings, noise = diffusion.add_noise(embeddings, t)

            # Predict the noise
            pred_noise = model(noisy_embeddings, t)
            loss = nn.MSELoss()(pred_noise, noise)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            total_loss += loss.item()

        avg_loss = total_loss / len(train_loader)
        print(f"Epoch {epoch + 1}, Loss: {avg_loss}")

        # Validation
        model.eval()
        with torch.no_grad():
            val_loss = 0
            for points, embeddings in val_loader:
                t = torch.randint(0, timesteps, (points.size(0),), dtype=torch.long)
                noisy_embeddings, noise = diffusion.add_noise(embeddings, t)
                pred_noise = model(noisy_embeddings, t)
                loss = nn.MSELoss()(pred_noise, noise)
                val_loss += loss.item()

            val_loss = val_loss / len(val_loader)
            print(f"Validation Loss: {val_loss}")

        # Save model checkpoint
        torch.save(model.state_dict(), f"diffusion_model_epoch_{epoch + 1}.pth")

    return model


# Train the diffusion model using precomputed embeddings
trained_model = train_diffusion_with_embeddings(train_precomputed, val_precomputed, embedding_dim=128, timesteps=1000, epochs=10, batch_size=32)
# Out:
# Number of parameters in model: 131968
# Batch 1/24
# Points Shape: torch.Size([32, 100]), Embeddings Shape: torch.Size([32, 50, 128])
# Random Timesteps: tensor([984, 504,  32, 979, 880, 750, 232, 321, 825, 819, 822, 647,  60, 249,
#         840, 176, 494, 640, 449, 105, 548, 557, 142, 516, 804, 296, 513,  25,
#         672, 264, 147,  26])
# Batch 2/24
# Points Shape: torch.Size([32, 100]), Embeddings Shape: torch.Size([32, 50, 128])
# Random Timesteps: tensor([388, 864, 865, 935, 186, 792, 572, 225, 182, 717, 757, 315, 334, 239,
#          43, 586, 278, 300, 469, 333, 316, 981, 512, 388, 940, 179, 249,  34,
#          51, 311, 956,  23])
# Batch 3/24
# Points Shape: torch.Size([32, 100]), Embeddings Shape: torch.Size([32, 50, 128])
# Random Timesteps: tensor([574, 466, 394, 587, 793, 482, 174, 344, 277, 864, 907, 694, 454, 204,
#         889, 512, 695, 335, 886, 443, 267, 646, 996, 449, 209, 611, 451, 516,
#         989, 803, 945, 317])
# Batch 4/24
# Points Shape: torch.Size([32, 100]), Embeddings Shape: torch.Size([32, 50, 128])
# Random Timesteps: tensor([215, 689, 814, 639, 846, 623, 176, 393, 372, 406, 609, 538, 887, 202,
#          88, 753, 569, 383, 576, 222,  26, 431, 761, 507, 120, 653, 775, 502,
#         548,  92, 769, 260])
# Batch 5/24
# Points Shape: torch.Size([32, 100]), Embeddings Shape: torch.Size([32, 50, 128])
# Random Timesteps: tensor([754, 197, 584, 369, 123, 141, 145, 317, 343, 349, 344, 319, 911, 377,
#         512, 738, 667, 158, 644, 946, 196, 217, 481, 594, 886, 396, 714, 759,
#         454, 467,  78, 833])
# Batch 6/24
# Points Shape: torch.Size([32, 100]), Embeddings Shape: torch.Size([32, 50, 128])
# Random Timesteps: tensor([772, 825, 735, 248, 797, 182, 591, 945, 963, 156, 373, 728, 576, 264,
#         512, 365, 533, 778, 284, 494, 301, 328, 717, 733, 984, 666, 748, 490,
#         979, 757, 788, 967])
# Batch 7/24
# Points Shape: torch.Size([32, 100]), Embeddings Shape: torch.Size([32, 50, 128])
# Random Timesteps: tensor([562,  13, 360, 614,  48, 522, 413, 526, 886, 800, 879, 809,  94,  66,
#         406, 472, 500, 732, 650,  23, 949, 129, 961,  89, 601, 716, 741, 705,
#         532, 325, 956, 398])
# Batch 8/24
# Points Shape: torch.Size([32, 100]), Embeddings Shape: torch.Size([32, 50, 128])
# Random Timesteps: tensor([514, 800,  55, 607, 328, 819, 615, 954, 173, 406, 143, 201, 550, 136,
#         265, 200, 208, 750, 212, 747, 801, 247, 207, 709, 424, 551, 524, 587,
#          92, 362, 929, 645])
# Batch 9/24
# Points Shape: torch.Size([32, 100]), Embeddings Shape: torch.Size([32, 50, 128])
# Random Timesteps: tensor([668, 261, 536, 590,  97, 299, 237, 615, 785, 377, 425, 722, 845, 822,
#         124, 396, 508,  80, 498, 607, 277, 161, 644, 360, 185, 964, 878, 995,
#         320, 982, 325, 898])
# Batch 10/24
# Points Shape: torch.Size([32, 100]), Embeddings Shape: torch.Size([32, 50, 128])
# Random Timesteps: tensor([164, 863, 443, 255, 473, 229, 567, 691, 607, 277, 360, 109, 445, 731,
#         649, 191, 446, 505, 266,  28, 922, 927, 845, 231, 464,  71, 793, 369,
#         748, 395, 439, 945])
# Batch 11/24
# Points Shape: torch.Size([32, 100]), Embeddings Shape: torch.Size([32, 50, 128])
# Random Timesteps: tensor([105, 100, 589, 614, 893, 859,  86, 746, 280, 467, 986, 645, 598, 747,
#         379, 652,  53, 259, 910, 198, 546, 910,  76, 823, 726, 166, 840, 771,
#         441, 731, 127, 226])
# Batch 12/24
# Points Shape: torch.Size([32, 100]), Embeddings Shape: torch.Size([32, 50, 128])
# Random Timesteps: tensor