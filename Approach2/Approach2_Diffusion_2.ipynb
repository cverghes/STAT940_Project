# %%
import os
import json

# Define the paths to the folders
folders = ["data_symbolic_regression/test", "data_symbolic_regression/train", "data_symbolic_regression/val"]

# Dictionary to hold the data from each folder
data = {folder: [] for folder in folders}

# Iterate through each folder and read JSON files
for folder in folders:
    if os.path.exists(folder):
        for file_name in os.listdir(folder):
            if file_name.endswith(".json"):
                file_path = os.path.join(folder, file_name)
                try:
                    with open(file_path, "r") as file:
                        content = json.load(file)
                        data[folder].append(content)
                except Exception as e:
                    print(f"Error reading {file_path}: {e}")
    else:
        print(f"Folder {folder} does not exist.")

# Example: Accessing data
for folder, files in data.items():
    print(f"Folder: {folder}, Number of files: {len(files)}")
# Out:
# Folder: data_symbolic_regression/test, Number of files: 161
# Folder: data_symbolic_regression/train, Number of files: 747
# Folder: data_symbolic_regression/val, Number of files: 160

# %%
if data["data_symbolic_regression/test"]:
    # Access the first item in the test folder
    test = data["data_symbolic_regression/test"]

if data["data_symbolic_regression/train"]:
    # Access the first item in the test folder
    train = data["data_symbolic_regression/train"]

if data["data_symbolic_regression/val"]:
    # Access the first item in the test folder
    val = data["data_symbolic_regression/val"]

# %%
len(train)
for i in range(len(train)):
    print(i)
    print(train[i]["formula_human_readable"])
# Out:
# 0
# ((cos(var_1)+(var_2*C_0))*((var_0*var_0)*cos(var_2)))
# 1
# (((var_1+C_0)+tan(var_0))+tanh(exp(var_2)))
# 2
# (pow_2(cosh(var_2))+reverse((var_1*var_0)))
# 3
# ((gaussian(var_1)+(var_0+C_0))+tan((var_1*var_2)))
# 4
# (sqrt((var_2*var_0))+neg(cosh(var_1)))
# 5
# (((var_2+var_0)*sqrt(var_1))*tanh((var_1+var_2)))
# 6
# log(((var_0+C_0)*(var_1+var_2)))
# 7
# ((sin(var_1)+tanh(var_0))*sinh(sqrt(var_2)))
# 8
# (tanh(log(var_0))+tanh((var_2+var_1)))
# 9
# (sinh(tanh(var_0))+cos((var_1*var_2)))
# 10
# (log(sinh(var_0))+neg((var_2*var_1)))
# 11
# ((log(var_0)*sqrt(var_1))+sin(pow_2(var_2)))
# 12
# (((var_0*C_0)+sinh(var_1))*reverse(gaussian(var_2)))
# 13
# (tan(reverse(var_2))+exp((var_0+var_1)))
# 14
# (log((var_1+var_0))*sqrt((var_2+C_0)))
# 15
# ((gaussian(var_1)+(var_0*C_0))+sqrt(var_2))
# 16
# ((var_1*cos(var_2))*tanh(sqrt(var_0)))
# 17
# neg((tan(var_2)*(var_0*var_1)))
# 18
# ((tan(var_2)*sin(var_1))+cos(var_0))
# 19
# (((var_2*C_0)+tan(var_0))*sinh((var_0*var_1)))
# 20
# ((cos(var_0)+tanh(var_2))*sqrt(sin(var_1)))
# 21
# (sin((var_0+var_2))*pow_2(neg(var_1)))
# 22
# ((log(var_0)*var_2)*cosh((var_2*var_1)))
# 23
# (neg((var_1*var_0))*sin(sqrt(var_2)))
# 24
# (cosh(cosh(var_2))+exp((var_1+var_0)))
# 25
# (neg(cosh(var_0))+cosh((var_2*var_1)))
# 26
# (reverse(log(var_0))+cosh((var_2*var_1)))
# 27
# (tan((var_1*var_0))+sin((var_2+C_0)))
# 28
# (exp((var_0+var_2))+pow_2(sqrt(var_1)))
# 29
# ((cosh(var_2)+tan(var_1))+sqrt(tan(var_0)))
# 30
# (log((var_0+var_1))*pow_2((var_2+C_0)))
# 31
# ((cosh(var_2)*var_2)+((var_0+var_1)*sinh(var_0)))
# 32
# ((tan(var_0)*tanh(var_1))+cosh(cos(var_2)))
# 33
# (cosh((var_1*var_2))*log((var_0+var_2)))
# 34
# ((sqrt(var_1)+cos(var_2))*(log(var_0)+reverse(var_2)))
# 35
# (sqrt(sinh(var_0))*pow_2((var_2*var_1)))
# 36
# ((exp(var_1)*sqrt(var_2))*tanh(tan(var_0)))
# 37
# (((var_2+var_0)+gaussian(var_1))*log((var_2+C_0)))
# 38
# (reverse(sin(var_2))+pow_2((var_1+var_0)))
# 39
# ((exp(var_2)*tanh(var_1))*pow_2(cosh(var_0)))
# 40
# (sqrt(sqrt(var_2))*sinh((var_1+var_0)))
# 41
# ((sin(var_0)+tan(var_2))+(sin(var_1)+neg(var_1)))
# 42
# (((var_1*var_2)*reverse(var_2))+sqrt((var_0*C_0)))
# 43
# ((sin(var_1)+sqrt(var_0))*reverse(exp(var_2)))
# 44
# (reverse((var_1*var_0))+tan((var_2+C_0)))
# 45
# (reverse((var_2*var_1))*pow_2(gaussian(var_0)))
# 46
# (((var_1*C_0)*(var_0*var_1))+log(var_2))
# 47
# (((var_2+var_1)+log(var_0))+cosh(C_0))
# 48
# (reverse((var_0*var_1))+gaussian(var_2))
# 49
# ((pow_2(var_1)*gaussian(var_2))+cosh(tanh(var_0)))
# 50
# ((reverse(var_0)+tanh(var_1))*tan(gaussian(var_2)))
# 51
# ((exp(var_1)+reverse(var_0))*sin(var_2))
# 52
# ((C_0*cosh(var_2))+pow_2((var_1+var_0)))
# 53
# ((C_0+C_1)+((var_0+var_1)*var_2))
# 54
# (((var_1*C_0)+cos(var_0))+((var_2+C_1)+C_2))
# 55
# (pow_2(sin(var_0))+gaussian((var_2*var_1)))
# 56
# ((tan(var_1)*tan(var_2))+reverse(cosh(var_0)))
# 57
# (log((var_2*var_0))+pow_2(sinh(var_1)))
# 58
# ((neg(var_2)+tanh(var_0))*tanh(reverse(var_1)))
# 59
# (tan((var_2*C_0))+neg((var_0*var_1)))
# 60
# (neg((var_2*var_0))*cosh(gaussian(var_1)))
# 61
# ((pow_2(var_1)*(var_0*var_0))+exp((var_2+var_2)))
# 62
# (neg((var_1+var_2))*tanh(tan(var_0)))
# 63
# (exp(sin(var_2))+cosh((var_0+var_1)))
# 64
# (cosh((var_1+var_2))+sin((var_0+C_0)))
# 65
# ((tan(var_1)*sin(var_1))+(tan(var_0)+cos(var_2)))
# 66
# ((var_0*sinh(var_2))+(sqrt(var_1)*reverse(var_1)))
# 67
# ((exp(var_1)+(var_1*C_0))*(gaussian(var_2)+sinh(var_0)))
# 68
# (neg((var_0*C_0))+sin((var_2*var_1)))
# 69
# ((neg(var_0)+tanh(var_2))*sqrt(sin(var_1)))
# 70
# (((var_0+C_0)*(var_1+C_1))*pow_2(neg(var_2)))
# 71
# sinh((var_1+(var_2+var_0)))
# 72
# ((sin(var_2)*cosh(var_1))*neg(var_0))
# 73
# ((cos(var_1)*(var_0+var_1))+exp((var_2*C_0)))
# 74
# ((pow_2(var_1)*cosh(var_0))+log(cos(var_2)))
# 75
# ((pow_2(var_1)*log(var_0))*neg(var_2))
# 76
# ((sin(var_2)+(var_1+var_2))*sin((var_0+C_0)))
# 77
# (((var_2*C_0)*(var_0*var_1))+neg(reverse(var_2)))
# 78
# ((sqrt(var_0)+(var_2+C_0))+pow_2(sqrt(var_1)))
# 79
# (neg(tan(var_2))*exp((var_1*var_0)))
# 80
# (sqrt((var_2*var_1))+neg(cosh(var_0)))
# 81
# (cosh(reverse(var_1))+cosh((var_0+var_2)))
# 82
# ((tanh(var_2)*cos(var_2))+((var_1+C_0)+(var_0+C_1)))
# 83
# ((cos(var_0)+sqrt(var_2))+sin(sqrt(var_1)))
# 84
# (sinh(sqrt(var_2))*tanh((var_1+var_0)))
# 85
# (sinh(sqrt(var_2))*sinh((var_1+var_0)))
# 86
# (neg((var_2*C_0))+sin((var_1*var_0)))
# 87
# (neg(gaussian(var_1))+neg((var_0+var_2)))
# 88
# (reverse((var_0+var_1))+pow_2(gaussian(var_2)))
# 89
# ((sin(var_1)+cosh(var_0))+sinh(log(var_2)))
# 90
# (((var_0*C_0)+(var_2+var_1))+sqrt((var_1+var_2)))
# 91
# ((reverse(var_0)+sin(var_1))*sqrt((var_1*var_2)))
# 92
# (gaussian(cosh(var_2))+reverse((var_1*var_0)))
# 93
# (((var_0+C_0)+sqrt(var_1))+cos((var_2*C_1)))
# 94
# ((var_2*(var_1*C_0))+pow_2(cosh(var_0)))
# 95
# ((exp(var_0)*var_2)+reverse(neg(var_1)))
# 96
# ((sin(var_0)+gaussian(var_2))*cos(pow_2(var_1)))
# 97
# sqrt(((var_0+var_2)+reverse(var_1)))
# 98
# ((gaussian(var_1)+(var_2*C_0))*log(pow_2(var_0)))
# 99
# (((var_0+C_0)+sqrt(var_2))*gaussian(pow_2(var_1)))
# 100
# (gaussian(reverse(var_1))*gaussian((var_0*var_2)))
# 101
# (((var_0*var_1)+(var_1+C_0))*exp(reverse(var_2)))
# 102
# ((tanh(var_1)+pow_2(var_0))+tan(var_2))
# 103
# ((cosh(var_1)+sinh(var_1))+cos((var_2+var_0)))
# 104
# (tan((var_2*var_1))+sin(neg(var_0)))
# 105
# (neg((var_0*C_0))*neg((var_2*var_1)))
# 106
# (((var_0+C_0)+var_1)*(log(var_1)*tanh(var_2)))
# 107
# (pow_2((var_0+var_1))*reverse(sqrt(var_2)))
# 108
# (sin(pow_2(var_0))*sqrt((var_1*var_2)))
# 109
# (tanh(sin(var_0))*tanh((var_1+var_2)))
# 110
# ((cosh(var_0)+pow_2(var_1))*exp(neg(var_2)))
# 111
# (gaussian((var_2+var_1))*pow_2(cosh(var_0)))
# 112
# (log(sqrt(var_1))*tan((var_2+var_0)))
# 113
# (sinh((var_2+var_1))+sqrt(tan(var_0)))
# 114
# (((var_2+C_0)+sin(var_1))*gaussian(gaussian(var_0)))
# 115
# ((pow_2(var_2)*cosh(var_1))+log((var_0*C_0)))
# 116
# (exp(cosh(var_1))*exp((var_0*var_2)))
# 117
# (tan((var_0*var_1))*exp(var_2))
# 118
# (tanh(log(var_2))*sqrt((var_0*var_1)))
# 119
# ((tan(var_1)+log(var_2))+log(cosh(var_0)))
# 120
# (tanh((var_2+C_0))+sqrt((var_0+var_1)))
# 121
# (cosh((var_1+var_2))+gaussian((var_0+var_2)))
# 122
# (tanh(cosh(var_0))*reverse((var_2+var_1)))
# 123
# (sin((var_2+var_0))*reverse(log(var_1)))
# 124
# (gaussian((var_0+var_2))+sinh(log(var_1)))
# 125
# (sqrt(log(var_2))+sqrt((var_0+var_1)))
# 126
# (exp((var_2+var_1))+sinh(reverse(var_0)))
# 127
# (sin((var_0*var_2))*sinh(sinh(var_1)))
# 128
# ((reverse(var_1)*log(var_2))+sin((var_1+var_0)))
# 129
# ((sqrt(var_1)+(var_1*var_2))+(C_0+var_0))
# 130
# (sqrt((var_1+var_2))+gaussian(pow_2(var_0)))
# 131
# ((var_1+sin(var_1))*(tan(var_2)+var_0))
# 132
# (cos(neg(var_2))*sqrt((var_1+var_0)))
# 133
# (sin((var_1+C_0))+cosh((var_0+var_2)))
# 134
# sqrt((sin(var_0)*(var_1+var_2)))
# 135
# ((tanh(var_2)+(var_2+var_0))+tan((var_1+var_0)))
# 136
# ((neg(var_0)*sin(var_2))*sqrt(exp(var_1)))
# 137
# ((cosh(var_2)*cosh(var_0))+(exp(var_1)+pow_2(var_1)))
# 138
# reverse(((var_2+var_0)*(var_1+C_0)))
# 139
# ((reverse(var_0)*log(var_2))+pow_2(cos(var_1)))
# 140
# (reverse(tanh(var_2))*sinh((var_0+var_1)))
# 141
# (((var_2*var_1)+cosh(var_0))+sinh(C_0))
# 142
# (tan(neg(var_0))+tanh((var_2+var_1)))
# 143
# (((var_0*C_0)+neg(var_1))*(sqrt(var_2)+C_1))
# 144
# (log((var_0+var_2))+log((var_1+C_0)))
# 145
# (sinh((var_2*var_0))*log(sqrt(var_1)))
# 146
# ((pow_2(var_1)*sinh(var_0))*cos(pow_2(var_2)))
# 147
# (sinh((var_1+var_0))*cosh(log(var_2)))
# 148
# (reverse((var_2*var_0))*sin(gaussian(var_1)))
# 149
# cos((sqrt(var_0)*(var_1*var_2)))
# 150
# ((var_0+sinh(var_2))+tan((var_1*var_0)))
# 151
# (neg((var_1+var_2))+log(pow_2(var_0)))
# 152
# (((var_2*var_2)+(var_0+C_0))*tan((var_2+var_1)))
# 153
# ((C_0+(var_1+C_1))*gaussian((var_2+var_0)))
# 154
# ((sqrt(var_2)*tanh(var_0))*pow_2(tanh(var_1)))
# 155
# ((pow_2(var_1)*tan(var_0))+neg(pow_2(var_2)))
# 156
# (neg((var_2+C_0))*tan((var_0+var_1)))
# 157
# (cos((var_0*var_2))*neg(log(var_1)))
# 158
# ((sqrt(var_0)*cosh(var_1))+gaussian(exp(var_2)))
# 159
# ((sqrt(var_1)+(var_2+var_0))+reverse(C_0))
# 160
# (pow_2(gaussian(var_0))*sinh((var_2+var_1)))
# 161
# (sinh((var_1*var_0))*cos(sqrt(var_2)))
# 162
# tan(((var_2*var_0)*sinh(var_1)))
# 163
# (((var_2+var_1)*cosh(var_0))*log((var_1*C_0)))
# 164
# (tan(reverse(var_1))+sqrt((var_2+var_0)))
# 165
# ((tan(var_0)+pow_2(var_1))*exp(neg(var_2)))
# 166
# (((var_1+var_2)+sinh(var_2))+cosh(neg(var_0)))
# 167
# ((sinh(var_2)+(var_0*C_0))+tanh((var_1*var_1)))
# 168
# (cosh(tan(var_2))+exp((var_1+var_0)))
# 169
# ((exp(var_0)*exp(var_2))+reverse(cos(var_1)))
# 170
# ((var_2*reverse(var_0))+pow_2((var_1*C_0)))
# 171
# ((tanh(var_0)*pow_2(var_2))+pow_2(log(var_1)))
# 172
# ((sinh(var_0)+cosh(var_1))+reverse(cosh(var_2)))
# 173
# (((var_0+C_0)+pow_2(var_2))+sinh(tan(var_1)))
# 174
# neg((sqrt(var_2)*(var_0+var_1)))
# 175
# ((sqrt(var_2)+sqrt(var_1))+tanh(pow_2(var_0)))
# 176
# ((tanh(var_0)*sqrt(var_2))+sinh(gaussian(var_1)))
# 177
# ((tan(var_0)*(var_2+C_0))+exp(reverse(var_1)))
# 178
# (sin((var_0*var_1))*exp((var_2*var_0)))
# 179
# (tanh((var_0*var_2))*cosh((var_1+var_1)))
# 180
# (sin((var_0*var_1))+gaussian(sinh(var_2)))
# 181
# (tan((var_1*C_0))+cos((var_0*var_2)))
# 182
# (sinh(pow_2(var_2))+sqrt((var_0+var_1)))
# 183
# ((cos(var_2)+gaussian(var_0))*neg((var_1*C_0)))
# 184
# ((sin(var_2)+sinh(var_1))*(sinh(var_2)*tanh(var_0)))
# 185
# (tan((var_2*var_1))*cos(neg(var_0)))
# 186
# (gaussian((var_0+var_2))+cosh(sqrt(var_1)))
# 187
# (gaussian(sinh(var_1))+cosh((var_0*var_2)))
# 188
# (((var_1*C_0)*sin(var_0))+reverse(exp(var_2)))
# 189
# (gaussian((var_2*var_1))+cosh(sqrt(var_0)))
# 190
# ((pow_2(var_0)+(var_0+var_2))*cosh(pow_2(var_1)))
# 191
# ((pow_2(var_1)*gaussian(var_0))*gaussian(exp(var_2)))
# 192
# (tan(pow_2(var_1))*neg((var_2+var_0)))
# 193
# (cos(var_2)*exp((var_0+var_1)))
# 194
# ((sin(var_0)+cosh(var_2))+neg(log(var_1)))
# 195
# (tanh((var_1+var_0))+tanh(sinh(var_2)))
# 196
# ((sqrt(var_2)*sinh(var_1))*pow_2(reverse(var_0)))
# 197
# ((tan(var_1)*(var_2+C_0))*(sin(var_0)+(var_0*var_1)))
# 198
# ((sinh(var_2)*sin(var_1))*(exp(var_1)*(var_0+C_0)))
# 199
# log(((var_2+var_1)*tanh(var_0)))
# 200
# ((C_0*exp(var_0))+log((var_2+var_1)))
# 201
# ((sin(var_2)*(var_0*C_0))*sin(neg(var_1)))
# 202
# (neg((var_1+var_0))*sinh(pow_2(var_2)))
# 203
# ((sqrt(var_2)+tanh(var_0))*exp(pow_2(var_1)))
# 204
# (sin((var_0+var_2))*gaussian(log(var_1)))
# 205
# ((var_0*(var_1*var_2))+exp((var_0*var_2)))
# 206
# (exp((var_0+var_1))+sinh((var_2*C_0)))
# 207
# (pow_2(tanh(var_1))+pow_2((var_0+var_2)))
# 208
# (sin((var_0*var_2))+exp(tanh(var_1)))
# 209
# (reverse((var_1+var_0))*neg(tan(var_2)))
# 210
# (reverse(tan(var_2))*tan((var_0+var_1)))
# 211
# ((cos(var_0)*tan(var_0))*((var_2+var_1)+var_0))
# 212
# ((sin(var_2)+cosh(var_0))*gaussian(tanh(var_1)))
# 213
# (pow_2((var_2+var_1))*exp(cosh(var_0)))
# 214
# (((var_0+var_2)*log(var_2))+gaussian((var_0*var_1)))
# 215
# (cosh((var_2*var_0))*neg((var_1+var_2)))
# 216
# (exp(var_0)+neg((var_2+var_1)))
# 217
# ((log(var_0)+pow_2(var_2))+reverse(log(var_1)))
# 218
# ((neg(var_2)*(var_1+var_0))+gaussian(sinh(var_1)))
# 219
# (tanh(cosh(var_1))+sin((var_0*var_2)))
# 220
# (log((var_2*C_0))+sin((var_1*var_0)))
# 221
# ((cos(var_1)*exp(var_2))*pow_2(sin(var_0)))
# 222
# ((sin(var_0)*tan(var_1))*reverse(tanh(var_2)))
# 223
# (reverse((var_0*var_1))+reverse(sinh(var_2)))
# 224
# ((var_1+sinh(var_0))*gaussian(pow_2(var_2)))
# 225
# (log((var_2+var_0))+sqrt(sinh(var_1)))
# 226
# ((sin(var_0)*C_0)*((var_1+C_1)+tanh(var_2)))
# 227
# (pow_2((var_0*var_1))*cos(neg(var_2)))
# 228
# (sin((var_2+var_1))*pow_2(exp(var_0)))
# 229
# (neg((var_2*var_1))+sqrt(gaussian(var_0)))
# 230
# (sqrt((var_1*var_2))*tanh((var_0+var_0)))
# 231
# ((tan(var_2)+(var_1*var_0))+(sinh(var_1)*(var_1+C_0)))
# 232
# ((tan(var_0)*neg(var_1))*sinh(sqrt(var_2)))
# 233
# (pow_2(reverse(var_1))+cos((var_2*var_0)))
# 234
# (tanh((var_2*var_0))*reverse(pow_2(var_1)))
# 235
# gaussian((reverse(var_1)+(var_0*var_2)))
# 236
# (tan((var_1*var_0))*tanh(reverse(var_2)))
# 237
# reverse((exp(var_1)+(var_2*var_0)))
# 238
# (cos((var_0*var_2))*cos(sqrt(var_1)))
# 239
# (tan((var_0+var_2))+cos((var_1+C_0)))
# 240
# (exp((var_1*var_0))+sin(pow_2(var_2)))
# 241
# ((var_2+var_0)+tan(neg(var_1)))
# 242
# (cos((var_0+var_2))*sqrt((var_1*var_0)))
# 243
# (tanh(sqrt(var_1))*cos((var_0*var_2)))
# 244
# ((log(var_0)*sin(var_1))*reverse(gaussian(var_2)))
# 245
# ((reverse(var_1)+tanh(var_2))+sin(reverse(var_0)))
# 246
# (cosh(tanh(var_1))+cosh((var_0*var_2)))
# 247
# (sinh((var_1+var_2))*sinh(pow_2(var_0)))
# 248
# pow_2(((var_2*C_0)+(var_1+var_0)))
# 249
# ((sinh(var_2)+sin(var_1))+cos(pow_2(var_0)))
# 250
# (tan((var_2*C_0))*neg((var_1*var_0)))
# 251
# ((sin(var_2)+cosh(var_1))+(log(var_1)+cos(var_0)))
# 252
# (cosh(tanh(var_1))+sinh((var_2*var_0)))
# 253
# ((log(var_2)+sinh(var_2))+reverse((var_1*var_0)))
# 254
# (cosh((var_1*var_2))*cosh(tanh(var_0)))
# 255
# ((gaussian(var_0)*(var_1*var_2))+((var_1*var_1)*pow_2(var_1)))
# 256
# (((var_2*C_0)+gaussian(var_1))+(neg(var_2)+tan(var_0)))
# 257
# (neg(sqrt(var_1))*reverse((var_0+var_2)))
# 258
# (sin(reverse(var_0))*tanh((var_1*var_2)))
# 259
# (cosh(neg(var_0))+cos((var_1+var_2)))
# 260
# ((log(var_1)+neg(var_2))*(exp(var_0)*(var_1+C_0)))
# 261
# (sqrt((var_1+var_0))*reverse(neg(var_2)))
# 262
# (((var_2+var_0)*(var_2+C_0))+(sqrt(var_1)+cos(var_1)))
# 263
# (sinh((var_1*var_2))+sinh(sinh(var_0)))
# 264
# (neg((var_2+var_0))*gaussian(sin(var_1)))
# 265
# (tan((var_0+var_2))*tanh(neg(var_1)))
# 266
# ((reverse(var_0)*(var_2*C_0))+((var_1+C_1)*tanh(var_2)))
# 267
# (cosh(neg(var_0))*sinh((var_2*var_1)))
# 268
# (((var_1*C_0)*sqrt(var_2))+gaussian((var_0+var_1)))
# 269
# ((neg(var_1)+neg(var_0))+gaussian(sin(var_2)))
# 270
# (exp((var_1+var_2))+reverse(sqrt(var_0)))
# 271
# (pow_2((var_1*var_0))+exp(var_2))
# 272
# (((var_0+C_0)*(var_1+var_2))+tanh((var_1+var_0)))
# 273
# (neg((var_2+var_1))+cosh(sin(var_0)))
# 274
# (sin((var_2*var_0))*cosh(cosh(var_1)))
# 275
# (sin((var_1*var_0))+log(gaussian(var_2)))
# 276
# ((C_0*(var_1*var_0))+neg(gaussian(var_2)))
# 277
# (gaussian((var_2*var_1))*cosh(neg(var_0)))
# 278
# (((var_2*var_1)*(var_2*var_0))*log(cos(var_1)))
# 279
# ((log(var_0)*pow_2(var_2))+cosh(reverse(var_1)))
# 280
# (log((var_2+var_0))+tanh((var_1*var_1)))
# 281
# (neg(pow_2(var_2))*sinh((var_0*var_1)))
# 282
# (tan((var_2+var_0))+pow_2((var_1+var_0)))
# 283
# (reverse(neg(var_1))*sqrt((var_2*var_0)))
# 284
# ((pow_2(var_0)+exp(var_2))*cosh((var_1*C_0)))
# 285
# (exp((var_0+var_1))+reverse((var_2+C_0)))
# 286
# ((exp(var_2)*cos(var_0))+sinh(neg(var_1)))
# 287
# ((sin(var_0)+reverse(var_2))+(log(var_0)+log(var_1)))
# 288
# ((var_2*gaussian(var_0))+gaussian(cosh(var_1)))
# 289
# (((var_0*C_0)*reverse(var_1))*exp(var_2))
# 290
# ((var_0+cosh(var_2))*log(var_1))
# 291
# (neg(cos(var_1))+tan((var_2+var_0)))
# 292
# ((cos(var_1)*var_0)+sqrt((var_2+C_0)))
# 293
# (exp(neg(var_2))+gaussian((var_1*var_0)))
# 294
# (((var_0+C_0)+sqrt(var_1))*sinh((var_2+C_1)))
# 295
# (reverse(tanh(var_1))+log((var_2*var_0)))
# 296
# (log((var_1+var_2))+sin((var_0+C_0)))
# 297
# ((cos(var_0)*log(var_2))*log(sqrt(var_1)))
# 298
# (sqrt((var_1+var_0))*neg(log(var_2)))
# 299
# (neg((var_0*var_2))*sinh(tan(var_1)))
# 300
# ((tan(var_0)*tanh(var_2))*(tanh(var_1)+sqrt(var_0)))
# 301
# (tan((var_2*var_0))*gaussian(reverse(var_1)))
# 302
# (cos((var_1*var_2))*tanh(pow_2(var_0)))
# 303
# ((cosh(var_1)*var_0)+log(sin(var_2)))
# 304
# (log((var_2+var_1))*sin(var_0))
# 305
# (cosh((var_2+var_0))+sqrt((var_1*C_0)))
# 306
# (reverse((var_0*C_0))*tanh((var_2+var_1)))
# 307
# ((tanh(var_0)+reverse(var_1))+neg(gaussian(var_2)))
# 308
# (cos((var_0+var_2))+cos(reverse(var_1)))
# 309
# ((cos(var_0)*var_0)*(tan(var_1)*log(var_2)))
# 310
# (neg(reverse(var_0))+sin((var_1+var_2)))
# 311
# (reverse(sqrt(var_0))*cos((var_2*var_1)))
# 312
# ((cosh(var_2)*sinh(var_0))+sinh(var_1))
# 313
# ((sqrt(var_0)+cosh(var_2))+sinh(sinh(var_1)))
# 314
# (sin((var_2*var_1))*log(neg(var_0)))
# 315
# ((tanh(var_0)*(var_0*var_2))+exp(reverse(var_1)))
# 316
# (log(gaussian(var_2))+cosh((var_0*var_1)))
# 317
# ((neg(var_1)*pow_2(var_0))*(sin(var_2)*(var_0*C_0)))
# 318
# ((neg(var_0)+pow_2(var_0))+tan((var_1+var_2)))
# 319
# ((tanh(var_1)*sqrt(var_0))+(gaussian(var_2)*(var_1*var_2)))
# 320
# ((log(var_0)*pow_2(var_1))+sinh(tanh(var_2)))
# 321
# (exp(tan(var_0))*tan((var_2*var_1)))
# 322
# (((var_0*C_0)*(var_1*C_1))*cosh(neg(var_2)))
# 323
# (cosh((var_0*var_2))*sinh(gaussian(var_1)))
# 324
# (log((var_0*var_2))+cos(gaussian(var_1)))
# 325
# ((log(var_2)*(var_1+var_2))*tanh(cosh(var_0)))
# 326
# (reverse(gaussian(var_0))*neg((var_1*var_2)))
# 327
# (exp((var_1*var_2))*gaussian(sin(var_0)))
# 328
# (sinh(sqrt(var_2))*sin((var_0*var_1)))
# 329
# ((sin(var_2)+tan(var_0))+(var_1*cos(var_2)))
# 330
# (((var_0+var_2)+(var_1*var_0))+sinh(reverse(var_2)))
# 331
# (gaussian((var_2*var_1))+reverse(sin(var_0)))
# 332
# ((neg(var_1)+sqrt(var_0))*tan(var_2))
# 333
# ((var_0+sqrt(var_1))*reverse(pow_2(var_2)))
# 334
# ((sin(var_2)*var_0)*sqrt(reverse(var_1)))
# 335
# ((reverse(var_2)*exp(var_1))+exp(tan(var_0)))
# 336
# ((cosh(var_0)+gaussian(var_1))+exp(gaussian(var_2)))
# 337
# ((exp(var_1)*sin(var_2))*reverse(pow_2(var_0)))
# 338
# (neg((var_1+C_0))+cos((var_0*var_2)))
# 339
# ((cos(var_2)*reverse(var_0))*exp(pow_2(var_1)))
# 340
# (sinh(reverse(var_1))+tan((var_2*var_0)))
# 341
# ((neg(var_2)*(var_0+C_0))*reverse(exp(var_1)))
# 342
# (((var_0+var_0)*(var_1+var_0))*gaussian(cosh(var_2)))
# 343
# (tanh(sin(var_0))+tanh((var_1*var_2)))
# 344
# ((cos(var_0)*tanh(var_2))*pow_2((var_0+var_1)))
# 345
# (pow_2(sinh(var_2))+neg((var_0*var_1)))
# 346
# (pow_2((var_1+var_0))*exp(tan(var_2)))
# 347
# ((tanh(var_1)*sqrt(var_0))+gaussian(sinh(var_2)))
# 348
# (tanh((var_0*var_1))+cosh(gaussian(var_2)))
# 349
# ((tanh(var_2)*tanh(var_1))*tanh(sqrt(var_0)))
# 350
# (tan((var_2*var_0))+gaussian((var_1+var_2)))
# 351
# (tanh(neg(var_1))*cos((var_2*var_0)))
# 352
# ((cos(var_2)*gaussian(var_0))*(neg(var_1)*cosh(var_1)))
# 353
# sinh((sinh(var_1)*(var_0+var_2)))
# 354
# (neg((var_1+var_2))*gaussian(pow_2(var_0)))
# 355
# (log(reverse(var_0))+tan((var_2+var_1)))
# 356
# ((cos(var_0)+var_2)*cosh(sinh(var_1)))
# 357
# ((cosh(var_0)+(var_1+var_2))+pow_2(log(var_0)))
# 358
# (reverse(exp(var_2))+exp((var_0+var_1)))
# 359
# (cosh(tanh(var_0))*log((var_1*var_2)))
# 360
# ((cos(var_0)+log(var_1))+log(tan(var_2)))
# 361
# ((sinh(var_1)+cos(var_2))*sinh(gaussian(var_0)))
# 362
# ((sin(var_1)*gaussian(var_2))*gaussian(log(var_0)))
# 363
# ((cosh(var_0)+sin(var_1))+tanh(log(var_2)))
# 364
# (((var_2+var_0)*tan(var_1))+neg(C_0))
# 365
# (log((var_2+var_2))*log((var_1*var_0)))
# 366
# (((var_0*C_0)*cos(var_1))*cos(neg(var_2)))
# 367
# (neg(gaussian(var_0))+sinh((var_1+var_2)))
# 368
# ((var_1*cos(var_2))+sqrt(sin(var_0)))
# 369
# (log(var_0)+cos((var_2*var_1)))
# 370
# (tanh((var_0+var_1))+neg((var_1*var_2)))
# 371
# ((reverse(var_1)+tanh(var_2))*sqrt(pow_2(var_0)))
# 372
# (((var_1*var_2)+(var_1+var_2))+(C_0*(var_0*var_0)))
# 373
# (reverse((var_0*var_1))+log((var_2+C_0)))
# 374
# (cosh(exp(var_0))+sinh((var_1+var_2)))
# 375
# ((tan(var_2)+gaussian(var_0))*tan(var_1))
# 376
# (((var_1+C_0)*exp(var_2))+sqrt(exp(var_0)))
# 377
# ((reverse(var_0)*(var_2*C_0))*reverse((var_1*var_0)))
# 378
# (gaussian((var_0*var_1))+tanh(sqrt(var_2)))
# 379
# ((pow_2(var_1)+(var_2*C_0))*cos((var_0*C_1)))
# 380
# ((neg(var_1)+reverse(var_2))+tan((var_0+var_2)))
# 381
# (tan(neg(var_0))*cosh((var_2+var_1)))
# 382
# tan(((var_1+var_2)*cos(var_0)))
# 383
# ((tanh(var_0)+cos(var_1))*neg(cosh(var_2)))
# 384
# ((cos(var_0)*cos(var_2))*sinh(neg(var_1)))
# 385
# ((C_0+var_1)*(sinh(var_2)*sqrt(var_0)))
# 386
# ((tanh(var_1)+log(var_2))*sqrt(sqrt(var_0)))
# 387
# (sinh(cos(var_1))+reverse((var_0*var_2)))
# 388
# (log((var_2+var_1))+cosh(neg(var_0)))
# 389
# ((sinh(var_2)*cos(var_0))+sqrt(reverse(var_1)))
# 390
# (pow_2(tan(var_0))+pow_2((var_1*var_2)))
# 391
# (sqrt((var_2+var_0))*log((var_1*var_2)))
# 392
# (cos(var_1)+sin((var_0*var_2)))
# 393
# ((var_2*(var_1+var_0))+(exp(var_2)+sin(var_2)))
# 394
# (((var_0+C_0)+exp(var_1))*tanh(reverse(var_2)))
# 395
# ((pow_2(var_0)+(var_1*C_0))*reverse(log(var_2)))
# 396
# (sqrt((var_2+var_1))*sinh(cos(var_0)))
# 397
# (sqrt(sinh(var_1))*cos((var_2+var_0)))
# 398
# tan(((var_0*var_2)*tan(var_1)))
# 399
# ((cosh(var_1)+sin(var_2))+gaussian(tan(var_0)))
# 400
# ((cosh(var_0)*var_2)+tanh((var_1+C_0)))
# 401
# (sin((var_1*var_0))*pow_2(sqrt(var_2)))
# 402
# cosh(((var_1+var_0)+(var_2+C_0)))
# 403
# ((gaussian(var_1)+neg(var_2))*(C_0*(var_0+C_1)))
# 404
# (neg((var_2*var_2))+tanh((var_0*var_1)))
# 405
# (tanh((var_0*var_2))+sinh(reverse(var_1)))
# 406
# ((reverse(var_0)*(var_2+C_0))+pow_2(log(var_1)))
# 407
# (neg((var_1+var_2))*tanh(neg(var_0)))
# 408
# (log((var_1+var_0))+pow_2(neg(var_2)))
# 409
# (reverse((var_1*var_0))*exp(cosh(var_2)))
# 410
# ((pow_2(var_1)*neg(var_0))+tanh(cos(var_2)))
# 411
# ((gaussian(var_0)+log(var_1))+tanh(neg(var_2)))
# 412
# ((gaussian(var_2)+reverse(var_1))*log((var_1*var_0)))
# 413
# (tan((var_1*var_2))+sin((var_0+C_0)))
# 414
# (((var_2+C_0)*reverse(var_0))*sqrt(var_1))
# 415
# ((gaussian(var_1)*C_0)+tanh((var_0+var_2)))
# 416
# (gaussian(cos(var_0))+tanh((var_2+var_1)))
# 417
# (sin(pow_2(var_1))*sinh((var_2+var_0)))
# 418
# (cosh((var_1+var_2))+pow_2(exp(var_0)))
# 419
# ((var_2*(var_0*var_1))+cos((var_0*var_0)))
# 420
# (pow_2((var_2+var_1))+neg(log(var_0)))
# 421
# (cos((var_0*var_1))+sinh((var_2*var_0)))
# 422
# (reverse(sinh(var_1))*cosh((var_2+var_0)))
# 423
# (sinh((var_2+var_0))+tan(neg(var_1)))
# 424
# ((sin(var_1)*exp(var_0))+cos(reverse(var_2)))
# 425
# (reverse((var_2*var_1))+sqrt(exp(var_0)))
# 426
# (cosh(sqrt(var_2))+sqrt((var_1*var_0)))
# 427
# ((cosh(var_2)+cos(var_2))*(gaussian(var_1)+cos(var_0)))
# 428
# ((pow_2(var_2)+pow_2(var_0))*gaussian(neg(var_1)))
# 429
# ((var_0+reverse(var_1))+(C_0*sqrt(var_2)))
# 430
# (((var_1+var_0)+gaussian(var_2))*sin((var_1+var_0)))
# 431
# (((var_2*C_0)+tan(var_1))*pow_2((var_0*var_0)))
# 432
# (reverse((var_0+C_0))*exp((var_1*var_2)))
# 433
# ((neg(var_1)*(var_0*var_0))+neg(tan(var_2)))
# 434
# ((C_0*(var_2*var_1))*sinh(sin(var_0)))
# 435
# (log(neg(var_0))+log((var_2*var_1)))
# 436
# (sin((var_1*var_2))*sinh(gaussian(var_0)))
# 437
# (sinh((var_0*var_2))+reverse(gaussian(var_1)))
# 438
# (((var_0+C_0)+tanh(var_1))*sinh(sqrt(var_2)))
# 439
# ((cos(var_2)+exp(var_0))+sqrt(tanh(var_1)))
# 440
# ((sqrt(var_2)+pow_2(var_0))*pow_2(sin(var_1)))
# 441
# (log(sinh(var_0))*cosh((var_1*var_2)))
# 442
# reverse((tanh(var_0)+(var_1+var_2)))
# 443
# (log((var_2*var_0))*sqrt((var_1*C_0)))
# 444
# (sqrt(reverse(var_1))*sin((var_0+var_2)))
# 445
# (pow_2(tan(var_0))+exp((var_2*var_1)))
# 446
# ((gaussian(var_2)*cosh(var_1))+sinh((var_1*var_0)))
# 447
# (pow_2((var_2*var_1))*tanh(log(var_0)))
# 448
# log(((var_1+var_2)+(var_0*C_0)))
# 449
# gaussian((var_1+(var_2+var_0)))
# 450
# (sqrt((var_2*var_1))+neg((var_0+C_0)))
# 451
# (sqrt((var_2*var_0))+sqrt(cosh(var_1)))
# 452
# (log((var_1+var_0))+tan(var_2))
# 453
# (neg((var_2+var_0))*exp(reverse(var_1)))
# 454
# (tan(var_2)*sinh((var_0+var_1)))
# 455
# ((cos(var_0)*gaussian(var_2))*neg(gaussian(var_1)))
# 456
# (gaussian((var_0*var_1))*reverse(gaussian(var_2)))
# 457
# (sin((var_2*C_0))*sin((var_0+var_1)))
# 458
# (((var_0*var_0)+(var_0+var_1))*cosh(sinh(var_2)))
# 459
# (log((var_0*var_1))+cosh(var_2))
# 460
# (sinh(reverse(var_1))+reverse((var_2+var_0)))
# 461
# (sin((var_1+C_0))*tan((var_2+var_0)))
# 462
# (tanh((var_2*var_2))+cosh((var_1*var_0)))
# 463
# ((gaussian(var_0)*neg(var_2))+gaussian((var_1*C_0)))
# 464
# (neg(cos(var_0))*log((var_1+var_2)))
# 465
# (tan((var_0+var_2))*log(tanh(var_1)))
# 466
# ((gaussian(var_0)+log(var_2))+log(tan(var_1)))
# 467
# (sinh(reverse(var_2))+sin((var_0*var_1)))
# 468
# (pow_2(sin(var_1))+reverse((var_2+var_0)))
# 469
# (gaussian((var_1+var_2))+tan(neg(var_0)))
# 470
# (tanh(var_2)*log((var_0*var_1)))
# 471
# ((C_0+(var_2*C_1))*tanh((var_1*var_0)))
# 472
# ((reverse(var_1)*reverse(var_1))*tan((var_2+var_0)))
# 473
# (pow_2(cos(var_0))+log((var_2*var_1)))
# 474
# (sin((var_0*C_0))*neg((var_1+var_2)))
# 475
# (exp(tanh(var_0))+cos((var_2+var_1)))
# 476
# ((tan(var_0)+cosh(var_2))+exp(cosh(var_1)))
# 477
# (exp((var_1+C_0))*tanh((var_0+var_2)))
# 478
# ((tanh(var_0)+var_2)*log(cosh(var_1)))
# 479
# (reverse((var_2*var_1))+pow_2(tanh(var_0)))
# 480
# ((cosh(var_0)*var_1)*cos((var_2+C_0)))
# 481
# (((var_0+C_0)+tan(var_2))+cosh((var_1+C_1)))
# 482
# ((tanh(var_0)+exp(var_1))+pow_2(gaussian(var_2)))
# 483
# ((sinh(var_2)*log(var_1))*cos(sqrt(var_0)))
# 484
# (neg(exp(var_2))+cos((var_1+var_0)))
# 485
# (((var_2*var_1)*C_0)+tan((var_0*var_0)))
# 486
# (neg(cosh(var_0))+pow_2((var_2*var_1)))
# 487
# ((tanh(var_0)*(var_2+C_0))*gaussian((var_1*var_2)))
# 488
# (((var_2+var_0)+sqrt(var_0))+log(neg(var_1)))
# 489
# (reverse(sin(var_0))*cos((var_2+var_1)))
# 490
# (((var_2+var_1)*var_0)+log((var_2*C_0)))
# 491
# (tan((var_0*var_2))+reverse(gaussian(var_1)))
# 492
# (exp((var_2*var_1))+exp((var_2+var_0)))
# 493
# (neg(cosh(var_1))+neg((var_2*var_0)))
# 494
# ((tan(var_2)*cosh(var_0))+tanh(gaussian(var_1)))
# 495
# (neg(sin(var_2))*pow_2((var_1*var_0)))
# 496
# ((pow_2(var_1)+reverse(var_2))*cosh((var_0+C_0)))
# 497
# (gaussian(reverse(var_2))*sinh((var_1+var_0)))
# 498
# (sinh((var_1*var_0))+sin(gaussian(var_2)))
# 499
# ((sqrt(var_0)*reverse(var_1))*pow_2((var_2+var_0)))
# 500
# (log(cos(var_0))+sqrt((var_1+var_2)))
# 501
# (neg((var_0*var_1))+tanh(sqrt(var_2)))
# 502
# (cos((var_2+var_1))+pow_2(sqrt(var_0)))
# 503
# gaussian((pow_2(var_2)+(var_1*var_0)))
# 504
# (tan((var_1+var_0))*neg((var_2*C_0)))
# 505
# (((var_2*var_1)*tan(var_0))*sinh(sin(var_1)))
# 506
# (log((var_0*var_1))*gaussian(tan(var_2)))
# 507
# (sqrt((var_0*var_1))*log(reverse(var_2)))
# 508
# (sqrt((var_0+var_1))*gaussian(reverse(var_2)))
# 509
# (gaussian((var_2*var_0))*reverse(neg(var_1)))
# 510
# ((log(var_2)+cos(var_0))*gaussian(sqrt(var_1)))
# 511
# ((tan(var_0)+reverse(var_2))+sqrt(gaussian(var_1)))
# 512
# (log(tanh(var_1))*gaussian((var_2+var_0)))
# 513
# ((var_2+tanh(var_1))*sqrt(log(var_0)))
# 514
# ((sqrt(var_1)+sqrt(var_2))+(tanh(var_1)+exp(var_0)))
# 515
# (sinh(neg(var_1))+gaussian((var_2+var_0)))
# 516
# ((sqrt(var_0)*sin(var_2))*neg(cosh(var_1)))
# 517
# ((tanh(var_0)+exp(var_1))*reverse(exp(var_2)))
# 518
# ((log(var_2)*exp(var_1))*log(cos(var_0)))
# 519
# ((reverse(var_0)*sin(var_2))+(tanh(var_2)+(var_1*C_0)))
# 520
# (sin((var_2*C_0))+pow_2((var_0+var_1)))
# 521
# (cos((var_2*var_0))*cosh((var_1*C_0)))
# 522
# (cos((var_1*C_0))+cosh((var_2+var_0)))
# 523
# ((tanh(var_0)*cos(var_1))*sinh(log(var_2)))
# 524
# sqrt((tan(var_0)*(var_1*var_2)))
# 525
# ((cosh(var_0)+cosh(var_1))+neg((var_1*var_2)))
# 526
# (gaussian(neg(var_2))*cosh((var_1*var_0)))
# 527
# ((sin(var_2)*log(var_1))*reverse(exp(var_0)))
# 528
# ((pow_2(var_0)*tan(var_1))+neg(reverse(var_2)))
# 529
# (cosh((var_1*var_2))+tan((var_0*var_2)))
# 530
# ((neg(var_0)*neg(var_2))*cosh(gaussian(var_1)))
# 531
# (((var_0*C_0)*cosh(var_2))+exp((var_2*var_1)))
# 532
# (tanh(exp(var_0))*sinh((var_1*var_2)))
# 533
# (((var_1+C_0)+var_0)+log(cos(var_2)))
# 534
# (reverse((var_1*C_0))*cos((var_2*var_0)))
# 535
# (sqrt(neg(var_0))+cos((var_1+var_2)))
# 536
# (tan((var_2+var_1))+tanh((var_0+var_2)))
# 537
# ((tanh(var_0)*sqrt(var_2))*exp(cosh(var_1)))
# 538
# (log((var_1+var_0))+log(cos(var_2)))
# 539
# (log((var_2*var_1))*exp(sinh(var_0)))
# 540
# ((sqrt(var_1)*C_0)+(var_0+sinh(var_2)))
# 541
# (((var_1+var_0)*(var_0*C_0))+cos((var_2+C_1)))
# 542
# (pow_2((var_0+C_0))*tanh((var_2+var_1)))
# 543
# (sin((var_1+var_2))*cosh(reverse(var_0)))
# 544
# (((var_0+C_0)*tan(var_2))+((var_1+var_0)*tanh(var_0)))
# 545
# (((var_1+var_2)*tan(var_1))*cos((var_0*C_0)))
# 546
# (gaussian((var_2+var_1))*sqrt(neg(var_0)))
# 547
# ((exp(var_1)*cosh(var_2))+reverse(pow_2(var_0)))
# 548
# (reverse((var_0*var_1))*log((var_2*var_2)))
# 549
# (((var_2+C_0)*sinh(var_1))*sin((var_0*C_1)))
# 550
# (tanh((var_2*var_1))*sinh(var_0))
# 551
# (gaussian(tan(var_0))*exp((var_1*var_2)))
# 552
# (sqrt((var_1+var_2))*cosh(neg(var_0)))
# 553
# (tan((var_2+var_0))*neg(var_1))
# 554
# ((cos(var_0)+tan(var_1))+sqrt(log(var_2)))
# 555
# (log(pow_2(var_1))+neg((var_2+var_0)))
# 556
# (sqrt((var_0*var_1))+sinh(pow_2(var_2)))
# 557
# (sin((var_1+var_0))+tanh(sinh(var_2)))
# 558
# ((neg(var_0)+cosh(var_1))*sinh(sqrt(var_2)))
# 559
# ((tanh(var_2)+neg(var_0))*cosh(cos(var_1)))
# 560
# ((gaussian(var_1)+cosh(var_2))*sinh(gaussian(var_0)))
# 561
# ((log(var_0)+sinh(var_1))+exp(tanh(var_2)))
# 562
# ((tan(var_2)*tanh(var_0))*cos(gaussian(var_1)))
# 563
# (tan((var_0+C_0))+pow_2((var_1*var_2)))
# 564
# ((cos(var_2)+tanh(var_1))*neg(sqrt(var_0)))
# 565
# (sqrt((var_1+var_2))+cosh(sin(var_0)))
# 566
# ((neg(var_1)+C_0)*cos((var_0+var_2)))
# 567
# (tan(reverse(var_0))+neg((var_2*var_1)))
# 568
# ((tanh(var_0)*(var_2+C_0))+gaussian(pow_2(var_1)))
# 569
# (((var_0+C_0)*var_2)+((var_2+C_1)+(var_2+var_1)))
# 570
# ((tanh(var_2)+cos(var_0))*sinh(cosh(var_1)))
# 571
# (neg((var_0*var_1))*reverse(var_2))
# 572
# (cosh((var_0*var_2))*tanh(reverse(var_1)))
# 573
# (sqrt(neg(var_1))*exp((var_0*var_2)))
# 574
# ((tan(var_2)*gaussian(var_0))*reverse(pow_2(var_1)))
# 575
# (((var_2+var_2)*(var_0*var_2))+tanh(pow_2(var_1)))
# 576
# ((gaussian(var_0)+(var_1*C_0))+tanh(pow_2(var_2)))
# 577
# ((sinh(var_2)+exp(var_0))*reverse((var_1*C_0)))
# 578
# ((neg(var_1)*var_0)+sqrt(gaussian(var_2)))
# 579
# (neg(sinh(var_0))+pow_2((var_2+var_1)))
# 580
# (gaussian((var_1+var_0))*neg(sin(var_2)))
# 581
# (tan((var_2+var_1))*exp(var_0))
# 582
# (cosh(neg(var_2))+tan((var_1*var_0)))
# 583
# (pow_2(cos(var_2))+cos((var_0*var_1)))
# 584
# (tan((var_0*var_2))*cos(reverse(var_1)))
# 585
# ((reverse(var_1)*cosh(var_0))+sqrt(neg(var_2)))
# 586
# ((tanh(var_1)*var_0)*pow_2(log(var_2)))
# 587
# (gaussian((var_1+var_0))*cosh(neg(var_2)))
# 588
# ((cos(var_2)+cosh(var_2))*((var_0+C_0)+gaussian(var_1)))
# 589
# (((var_1+var_0)+(var_0*var_2))*cos(reverse(var_2)))
# 590
# (exp((var_2+var_0))*pow_2(log(var_1)))
# 591
# (sqrt((var_0*var_2))+sinh(exp(var_1)))
# 592
# (sqrt(cosh(var_0))+tanh((var_1+var_2)))
# 593
# ((var_1*(var_0+var_2))*tanh(cos(var_0)))
# 594
# (sinh(neg(var_2))+tan((var_0*var_1)))
# 595
# ((log(var_2)+sinh(var_1))+(sinh(var_2)*var_0))
# 596
# (sin((var_1+var_0))+log((var_2*var_2)))
# 597
# (((var_1+var_0)*log(var_2))*exp((var_2*C_0)))
# 598
# (((var_0*var_1)*tan(var_2))+sinh(cos(var_0)))
# 599
# ((exp(var_2)+pow_2(var_1))*pow_2(tanh(var_0)))
# 600
# (((var_0*var_2)*reverse(var_1))+cos(sqrt(var_1)))
# 601
# (pow_2((var_2*var_0))+log((var_1+C_0)))
# 602
# (reverse((var_0+var_1))*gaussian(sinh(var_2)))
# 603
# (tanh((var_1*var_2))+sqrt(pow_2(var_0)))
# 604
# tanh(((var_2*var_0)*sinh(var_1)))
# 605
# (sin((var_0*var_2))+sinh(cos(var_1)))
# 606
# ((reverse(var_1)*exp(var_0))*(sqrt(var_2)+cosh(var_1)))
# 607
# (log((var_0+C_0))*sinh((var_1+var_2)))
# 608
# ((sinh(var_0)*gaussian(var_1))+neg(sinh(var_2)))
# 609
# (tan((var_1*var_2))+cos(gaussian(var_0)))
# 610
# (neg((var_1+var_0))+cos((var_2+var_0)))
# 611
# ((log(var_1)*sqrt(var_2))*tanh(var_0))
# 612
# (gaussian((var_1*var_0))+exp(sinh(var_2)))
# 613
# (exp(tan(var_0))+exp((var_1+var_2)))
# 614
# (cosh(gaussian(var_0))*sqrt((var_1*var_2)))
# 615
# (reverse((var_0+var_1))*pow_2(cos(var_2)))
# 616
# (cosh((var_2*var_1))*cosh((var_0*C_0)))
# 617
# (pow_2((var_2+var_1))*cosh(gaussian(var_0)))
# 618
# (neg(gaussian(var_0))+sinh((var_1+var_2)))
# 619
# exp(((var_0+var_1)*sqrt(var_2)))
# 620
# (sinh(var_0)*gaussian((var_2*var_1)))
# 621
# (sqrt(neg(var_0))+tanh((var_1*var_2)))
# 622
# ((sin(var_2)+tan(var_0))+pow_2(log(var_1)))
# 623
# ((sqrt(var_1)+(var_0*C_0))+sqrt(sinh(var_2)))
# 624
# ((pow_2(var_1)+cosh(var_0))+cosh(tan(var_2)))
# 625
# (gaussian((var_2+var_0))+sqrt(sinh(var_1)))
# 626
# (cosh((var_0+var_2))*pow_2(neg(var_1)))
# 627
# (reverse((var_0+var_1))+sinh(cos(var_2)))
# 628
# cos((tan(var_2)*(var_1+var_0)))
# 629
# (((var_0+C_0)*neg(var_2))*(exp(var_2)*(var_1+C_1)))
# 630
# (gaussian(sqrt(var_0))*sqrt((var_2+var_1)))
# 631
# ((sqrt(var_0)+(var_1*C_0))+reverse(cosh(var_2)))
# 632
# ((reverse(var_2)+cos(var_0))+sqrt(cosh(var_1)))
# 633
# (((var_1+var_1)*cosh(var_0))*reverse((var_2+C_0)))
# 634
# pow_2(((var_1+C_0)+(var_2*var_0)))
# 635
# (((var_2+var_1)*gaussian(var_0))+(sin(var_1)+tan(var_0)))
# 636
# (cosh((var_0*var_1))*reverse(cos(var_2)))
# 637
# ((cos(var_1)+sin(var_2))*log(cos(var_0)))
# 638
# (exp((var_0+var_2))*tan(sqrt(var_1)))
# 639
# (pow_2(log(var_1))*exp((var_2*var_0)))
# 640
# ((sqrt(var_2)*pow_2(var_0))*log(cos(var_1)))
# 641
# (reverse((var_0+var_2))*cosh(cosh(var_1)))
# 642
# ((sqrt(var_2)*pow_2(var_1))+cos(pow_2(var_0)))
# 643
# (((var_2+C_0)*(var_2*var_1))*sinh(tan(var_0)))
# 644
# (((var_1*var_0)*tanh(var_2))+tanh(C_0))
# 645
# (reverse(tanh(var_1))+log((var_2*var_0)))
# 646
# (sinh(cos(var_0))+neg((var_2*var_1)))
# 647
# pow_2(((var_0+var_2)*pow_2(var_1)))
# 648
# ((sin(var_0)*exp(var_1))*cosh(tan(var_2)))
# 649
# (sinh(sqrt(var_2))+cosh((var_1+var_0)))
# 650
# (cos(reverse(var_2))*exp((var_0*var_1)))
# 651
# (exp((var_0*var_2))*cosh(log(var_1)))
# 652
# (gaussian((var_1+var_2))+log(tanh(var_0)))
# 653
# (reverse((var_0+C_0))+pow_2((var_2+var_1)))
# 654
# (((var_1*var_2)*sin(var_2))+cosh((var_0+var_2)))
# 655
# (reverse(pow_2(var_2))*cosh((var_0*var_1)))
# 656
# ((tanh(var_2)+(var_1*C_0))*(neg(var_2)+cos(var_0)))
# 657
# (((var_2+var_2)+(var_1+var_0))*log(reverse(var_1)))
# 658
# ((pow_2(var_2)+pow_2(var_1))*cosh(var_0))
# 659
# reverse(((var_2+var_1)+sin(var_0)))
# 660
# ((neg(var_0)*var_2)*log(cosh(var_1)))
# 661
# (cosh((var_0+var_1))*exp((var_2*var_2)))
# 662
# ((exp(var_0)*exp(var_1))+cosh(log(var_2)))
# 663
# (cos(var_1)*tanh((var_2+var_0)))
# 664
# (((var_0*C_0)*cos(var_2))*tan((var_1*C_1)))
# 665
# (cos(sqrt(var_1))*pow_2((var_2*var_0)))
# 666
# (reverse(cosh(var_1))*log((var_0+var_2)))
# 667
# (log((var_2*var_0))*cos((var_1*C_0)))
# 668
# ((tanh(var_1)*sqrt(var_0))+sin(neg(var_2)))
# 669
# (sinh((var_2*var_1))+tanh(log(var_0)))
# 670
# ((cosh(var_0)*cosh(var_1))*cosh(reverse(var_2)))
# 671
# ((gaussian(var_2)+neg(var_0))+reverse(sqrt(var_1)))
# 672
# (tanh((var_2+var_1))+reverse((var_2*var_0)))
# 673
# gaussian(((var_1*var_2)+sinh(var_0)))
# 674
# (tan((var_2+var_0))+log(tan(var_1)))
# 675
# (((var_1+C_0)*sqrt(var_0))*cosh(sin(var_2)))
# 676
# (((var_2*C_0)*pow_2(var_0))*tanh(cosh(var_1)))
# 677
# (cos((var_1+var_2))*neg(tanh(var_0)))
# 678
# (((var_2*C_0)+gaussian(var_1))+cosh((var_0+var_1)))
# 679
# ((var_1*gaussian(var_0))*exp((var_2*var_0)))
# 680
# (((var_2+var_1)*C_0)*tan((var_0*var_1)))
# 681
# (cosh((var_0+C_0))+gaussian((var_1*var_2)))
# 682
# ((neg(var_0)*reverse(var_2))+reverse((var_1*C_0)))
# 683
# (tanh((var_2*var_1))*reverse(var_0))
# 684
# (tan((var_1*C_0))*neg((var_2+var_0)))
# 685
# (gaussian((var_1*var_2))+exp(neg(var_0)))
# 686
# (neg(exp(var_2))+sin((var_0+var_1)))
# 687
# exp(((var_0+var_1)+log(var_2)))
# 688
# (reverse(cosh(var_0))+gaussian((var_1+var_2)))
# 689
# ((log(var_2)*(var_0*C_0))+pow_2(tanh(var_1)))
# 690
# (neg(reverse(var_1))*sqrt((var_2+var_0)))
# 691
# (cosh(log(var_0))+gaussian((var_2*var_1)))
# 692
# (reverse((var_2+var_0))*cosh(gaussian(var_1)))
# 693
# (pow_2(exp(var_2))+sin((var_0*var_1)))
# 694
# (reverse(cosh(var_2))*cosh((var_0*var_1)))
# 695
# ((var_0*tan(var_1))+neg(sinh(var_2)))
# 696
# ((sin(var_0)+tanh(var_1))+gaussian(gaussian(var_2)))
# 697
# ((sinh(var_2)*C_0)*neg((var_1*var_0)))
# 698
# ((pow_2(var_1)*log(var_0))*exp((var_2+C_0)))
# 699
# ((reverse(var_2)*cos(var_1))+(C_0*var_0))
# 700
# gaussian((tanh(var_2)*(var_1*var_0)))
# 701
# ((sinh(var_2)+tan(var_2))*((var_0*C_0)*var_1))
# 702
# (tanh((var_2*var_0))+sin((var_1*C_0)))
# 703
# (tanh(var_0)*gaussian((var_1+var_2)))
# 704
# ((neg(var_2)*neg(var_0))*gaussian(tanh(var_1)))
# 705
# ((tan(var_0)+pow_2(var_2))+gaussian(cosh(var_1)))
# 706
# ((neg(var_0)*exp(var_2))*tan((var_1*var_1)))
# 707
# (sinh((var_1*var_0))*pow_2(neg(var_2)))
# 708
# (tanh((var_0*var_1))+gaussian(reverse(var_2)))
# 709
# (gaussian((var_2*var_1))*reverse(tan(var_0)))
# 710
# (cos((var_2*var_0))+reverse(exp(var_1)))
# 711
# (cosh(sin(var_1))+cos((var_2+var_0)))
# 712
# ((sin(var_1)*neg(var_2))+cosh((var_0*C_0)))
# 713
# (reverse((var_2*var_0))*tan(reverse(var_1)))
# 714
# ((C_0+(var_0+var_2))*pow_2(log(var_1)))
# 715
# (cosh(gaussian(var_0))+tan((var_1+var_2)))
# 716
# (tanh((var_0+var_2))*pow_2(tan(var_1)))
# 717
# ((cosh(var_1)+tanh(var_2))*sin(gaussian(var_0)))
# 718
# ((cos(var_0)*(var_2*C_0))+tanh(sinh(var_1)))
# 719
# (((var_0+var_1)+cosh(var_2))*neg(cosh(var_2)))
# 720
# (sin((var_1*var_0))+log((var_2+var_0)))
# 721
# (sinh(pow_2(var_2))*exp((var_0+var_1)))
# 722
# (log((var_1+var_2))*sin(pow_2(var_0)))
# 723
# (((var_0*C_0)*tanh(var_1))*cosh(sqrt(var_2)))
# 724
# (gaussian(cos(var_0))*sinh((var_1+var_2)))
# 725
# ((tanh(var_1)*tan(var_0))*cos(var_2))
# 726
# ((sqrt(var_1)+(var_2+var_2))+pow_2((var_0+var_2)))
# 727
# (neg((var_0+var_1))+sinh((var_2+C_0)))
# 728
# ((gaussian(var_0)*neg(var_2))*sinh(cosh(var_1)))
# 729
# (cosh((var_1+var_2))+pow_2(exp(var_0)))
# 730
# ((sin(var_0)*(var_1+C_0))+cos(pow_2(var_2)))
# 731
# (sinh((var_0*C_0))*sinh((var_2+var_1)))
# 732
# (sinh(exp(var_0))+neg((var_2+var_1)))
# 733
# (((var_1+var_2)+tanh(var_2))+(tanh(var_0)*tanh(var_2)))
# 734
# (((var_2+C_0)+(var_2+C_1))+cosh((var_0*var_1)))
# 735
# (gaussian((var_0+var_1))*exp((var_2*C_0)))
# 736
# (tan((var_0*var_1))*gaussian(tan(var_2)))
# 737
# (((var_1*C_0)+var_2)+exp(cos(var_0)))
# 738
# ((tanh(var_0)+tan(var_2))*sqrt(tanh(var_1)))
# 739
# (((var_0+var_2)+(var_2+var_2))*(tan(var_0)*tan(var_1)))
# 740
# cos((log(var_1)+(var_2+var_0)))
# 741
# (sin((var_0*var_1))*gaussian(var_2))
# 742
# (reverse(tan(var_2))*pow_2((var_0+var_1)))
# 743
# ((tanh(var_2)+neg(var_1))+pow_2(reverse(var_0)))
# 744
# (pow_2((var_0+var_1))*log(tan(var_2)))
# 745
# ((tan(var_2)+cosh(var_0))+cosh(cos(var_1)))
# 746
# (gaussian((var_0*C_0))*neg((var_2+var_1)))

# %%
import re

def regex_tokenize_formula_with_tags(formula):
    """
    Tokenizes a formula using regex and replaces `(` and `)` with tags `[OPEN_PAREN]` and `[CLOSE_PAREN]`.
    Args:
        formula (str): A mathematical formula as a string.
    Returns:
        list: List of tokens with parenthesis replaced by tags.
    """
    # Replace parentheses with tags
    formula = formula.replace("(", " [OPEN_PAREN] ").replace(")", " [CLOSE_PAREN] ")

    # Define regex pattern
    pattern = r"""
        (var_\d+)          |  # Match variables like var_0, var_1
        (C_\d+)            |  # Match constants like C_0, C_1
        ([a-zA-Z_]+)       |  # Match functions like sqrt, sin, log
        (\[OPEN_PAREN\])   |  # Match custom open parenthesis tag
        (\[CLOSE_PAREN\])  |  # Match custom close parenthesis tag
        ([\+\-\*/\^])      |  # Match operators
        (\d+\.\d+|\d+)        # Match numbers (integers or decimals)
    """

    # Compile regex
    regex = re.compile(pattern, re.VERBOSE)

    # Tokenize using regex
    tokens = [match.group(0) for match in regex.finditer(formula)]
    return tokens

def tokenize_dataset(dataset):
    """
    Tokenizes the formula_human_readable field of each entry in the dataset.
    Args:
        dataset (list): List of dictionaries with the "formula_human_readable" field.
    Returns:
        list: List of tokenized formulas for the entire dataset.
    """
    tokenized_formulas = []

    for i, entry in enumerate(dataset):
        if "formula_human_readable" in entry:
            formula = entry["formula_human_readable"]
            tokens = regex_tokenize_formula_with_tags(formula)
            tokenized_formulas.append(tokens)
            print(f"Entry {i}: {tokens}")  # Debugging/logging

    return tokenized_formulas

# Tokenize the train dataset
tokenized_train_formulas = tokenize_dataset(train)

# Example output of tokenized formulas
print(f"Tokenized Formulas for Train Dataset: {tokenized_train_formulas}")
# Out:
# Entry 0: ['[OPEN_PAREN]', '[OPEN_PAREN]', 'cos', '[OPEN_PAREN]', 'var_1', '[CLOSE_PAREN]', '+', '[OPEN_PAREN]', 'var_2', '*', 'C_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '*', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_0', '*', 'var_0', '[CLOSE_PAREN]', '*', 'cos', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 1: ['[OPEN_PAREN]', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_1', '+', 'C_0', '[CLOSE_PAREN]', '+', 'tan', '[OPEN_PAREN]', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '+', 'tanh', '[OPEN_PAREN]', 'exp', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 2: ['[OPEN_PAREN]', 'pow_', '2', '[OPEN_PAREN]', 'cosh', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '+', 'reverse', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_1', '*', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 3: ['[OPEN_PAREN]', '[OPEN_PAREN]', 'gaussian', '[OPEN_PAREN]', 'var_1', '[CLOSE_PAREN]', '+', '[OPEN_PAREN]', 'var_0', '+', 'C_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '+', 'tan', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_1', '*', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 4: ['[OPEN_PAREN]', 'sqrt', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_2', '*', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '+', 'neg', '[OPEN_PAREN]', 'cosh', '[OPEN_PAREN]', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 5: ['[OPEN_PAREN]', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_2', '+', 'var_0', '[CLOSE_PAREN]', '*', 'sqrt', '[OPEN_PAREN]', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '*', 'tanh', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_1', '+', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 6: ['log', '[OPEN_PAREN]', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_0', '+', 'C_0', '[CLOSE_PAREN]', '*', '[OPEN_PAREN]', 'var_1', '+', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 7: ['[OPEN_PAREN]', '[OPEN_PAREN]', 'sin', '[OPEN_PAREN]', 'var_1', '[CLOSE_PAREN]', '+', 'tanh', '[OPEN_PAREN]', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '*', 'sinh', '[OPEN_PAREN]', 'sqrt', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 8: ['[OPEN_PAREN]', 'tanh', '[OPEN_PAREN]', 'log', '[OPEN_PAREN]', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '+', 'tanh', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_2', '+', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 9: ['[OPEN_PAREN]', 'sinh', '[OPEN_PAREN]', 'tanh', '[OPEN_PAREN]', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '+', 'cos', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_1', '*', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 10: ['[OPEN_PAREN]', 'log', '[OPEN_PAREN]', 'sinh', '[OPEN_PAREN]', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '+', 'neg', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_2', '*', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 11: ['[OPEN_PAREN]', '[OPEN_PAREN]', 'log', '[OPEN_PAREN]', 'var_0', '[CLOSE_PAREN]', '*', 'sqrt', '[OPEN_PAREN]', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '+', 'sin', '[OPEN_PAREN]', 'pow_', '2', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 12: ['[OPEN_PAREN]', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_0', '*', 'C_0', '[CLOSE_PAREN]', '+', 'sinh', '[OPEN_PAREN]', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '*', 'reverse', '[OPEN_PAREN]', 'gaussian', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 13: ['[OPEN_PAREN]', 'tan', '[OPEN_PAREN]', 'reverse', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '+', 'exp', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_0', '+', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 14: ['[OPEN_PAREN]', 'log', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_1', '+', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '*', 'sqrt', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_2', '+', 'C_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 15: ['[OPEN_PAREN]', '[OPEN_PAREN]', 'gaussian', '[OPEN_PAREN]', 'var_1', '[CLOSE_PAREN]', '+', '[OPEN_PAREN]', 'var_0', '*', 'C_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '+', 'sqrt', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 16: ['[OPEN_PAREN]', '[OPEN_PAREN]', 'var_1', '*', 'cos', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '*', 'tanh', '[OPEN_PAREN]', 'sqrt', '[OPEN_PAREN]', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 17: ['neg', '[OPEN_PAREN]', '[OPEN_PAREN]', 'tan', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '*', '[OPEN_PAREN]', 'var_0', '*', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 18: ['[OPEN_PAREN]', '[OPEN_PAREN]', 'tan', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '*', 'sin', '[OPEN_PAREN]', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '+', 'cos', '[OPEN_PAREN]', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 19: ['[OPEN_PAREN]', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_2', '*', 'C_0', '[CLOSE_PAREN]', '+', 'tan', '[OPEN_PAREN]', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '*', 'sinh', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_0', '*', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 20: ['[OPEN_PAREN]', '[OPEN_PAREN]', 'cos', '[OPEN_PAREN]', 'var_0', '[CLOSE_PAREN]', '+', 'tanh', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '*', 'sqrt', '[OPEN_PAREN]', 'sin', '[OPEN_PAREN]', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 21: ['[OPEN_PAREN]', 'sin', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_0', '+', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '*', 'pow_', '2', '[OPEN_PAREN]', 'neg', '[OPEN_PAREN]', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 22: ['[OPEN_PAREN]', '[OPEN_PAREN]', 'log', '[OPEN_PAREN]', 'var_0', '[CLOSE_PAREN]', '*', 'var_2', '[CLOSE_PAREN]', '*', 'cosh', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_2', '*', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 23: ['[OPEN_PAREN]', 'neg', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_1', '*', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '*', 'sin', '[OPEN_PAREN]', 'sqrt', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 24: ['[OPEN_PAREN]', 'cosh', '[OPEN_PAREN]', 'cosh', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '+', 'exp', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_1', '+', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 25: ['[OPEN_PAREN]', 'neg', '[OPEN_PAREN]', 'cosh', '[OPEN_PAREN]', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '+', 'cosh', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_2', '*', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 26: ['[OPEN_PAREN]', 'reverse', '[OPEN_PAREN]', 'log', '[OPEN_PAREN]', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '+', 'cosh', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_2', '*', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 27: ['[OPEN_PAREN]', 'tan', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_1', '*', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '+', 'sin', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_2', '+', 'C_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 28: ['[OPEN_PAREN]', 'exp', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_0', '+', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '+', 'pow_', '2', '[OPEN_PAREN]', 'sqrt', '[OPEN_PAREN]', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 29: ['[OPEN_PAREN]', '[OPEN_PAREN]', 'cosh', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '+', 'tan', '[OPEN_PAREN]', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '+', 'sqrt', '[OPEN_PAREN]', 'tan', '[OPEN_PAREN]', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 30: ['[OPEN_PAREN]', 'log', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_0', '+', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '*', 'pow_', '2', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_2', '+', 'C_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 31: ['[OPEN_PAREN]', '[OPEN_PAREN]', 'cosh', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '*', 'var_2', '[CLOSE_PAREN]', '+', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_0', '+', 'var_1', '[CLOSE_PAREN]', '*', 'sinh', '[OPEN_PAREN]', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 32: ['[OPEN_PAREN]', '[OPEN_PAREN]', 'tan', '[OPEN_PAREN]', 'var_0', '[CLOSE_PAREN]', '*', 'tanh', '[OPEN_PAREN]', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '+', 'cosh', '[OPEN_PAREN]', 'cos', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 33: ['[OPEN_PAREN]', 'cosh', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_1', '*', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '*', 'log', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_0', '+', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 34: ['[OPEN_PAREN]', '[OPEN_PAREN]', 'sqrt', '[OPEN_PAREN]', 'var_1', '[CLOSE_PAREN]', '+', 'cos', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '*', '[OPEN_PAREN]', 'log', '[OPEN_PAREN]', 'var_0', '[CLOSE_PAREN]', '+', 'reverse', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 35: ['[OPEN_PAREN]', 'sqrt', '[OPEN_PAREN]', 'sinh', '[OPEN_PAREN]', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '*', 'pow_', '2', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_2', '*', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 36: ['[OPEN_PAREN]', '[OPEN_PAREN]', 'exp', '[OPEN_PAREN]', 'var_1', '[CLOSE_PAREN]', '*', 'sqrt', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '*', 'tanh', '[OPEN_PAREN]', 'tan', '[OPEN_PAREN]', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 37: ['[OPEN_PAREN]', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_2', '+', 'var_0', '[CLOSE_PAREN]', '+', 'gaussian', '[OPEN_PAREN]', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '*', 'log', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_2', '+', 'C_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 38: ['[OPEN_PAREN]', 'reverse', '[OPEN_PAREN]', 'sin', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '+', 'pow_', '2', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_1', '+', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 39: ['[OPEN_PAREN]', '[OPEN_PAREN]', 'exp', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '*', 'tanh', '[OPEN_PAREN]', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '*', 'pow_', '2', '[OPEN_PAREN]', 'cosh', '[OPEN_PAREN]', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 40: ['[OPEN_PAREN]', 'sqrt', '[OPEN_PAREN]', 'sqrt', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '*', 'sinh', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_1', '+', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 41: ['[OPEN_PAREN]', '[OPEN_PAREN]', 'sin', '[OPEN_PAREN]', 'var_0', '[CLOSE_PAREN]', '+', 'tan', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '+', '[OPEN_PAREN]', 'sin', '[OPEN_PAREN]', 'var_1', '[CLOSE_PAREN]', '+', 'neg', '[OPEN_PAREN]', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 42: ['[OPEN_PAREN]', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_1', '*', 'var_2', '[CLOSE_PAREN]', '*', 'reverse', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '+', 'sqrt', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_0', '*', 'C_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 43: ['[OPEN_PAREN]', '[OPEN_PAREN]', 'sin', '[OPEN_PAREN]', 'var_1', '[CLOSE_PAREN]', '+', 'sqrt', '[OPEN_PAREN]', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '*', 'reverse', '[OPEN_PAREN]', 'exp', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 44: ['[OPEN_PAREN]', 'reverse', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_1', '*', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '+', 'tan', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_2', '+', 'C_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 45: ['[OPEN_PAREN]', 'reverse', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_2', '*', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '*', 'pow_', '2', '[OPEN_PAREN]', 'gaussian', '[OPEN_PAREN]', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 46: ['[OPEN_PAREN]', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_1', '*', 'C_0', '[CLOSE_PAREN]', '*', '[OPEN_PAREN]', 'var_0', '*', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '+', 'log', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 47: ['[OPEN_PAREN]', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_2', '+', 'var_1', '[CLOSE_PAREN]', '+', 'log', '[OPEN_PAREN]', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '+', 'cosh', '[OPEN_PAREN]', 'C_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 48: ['[OPEN_PAREN]', 'reverse', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_0', '*', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '+', 'gaussian', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 49: ['[OPEN_PAREN]', '[OPEN_PAREN]', 'pow_', '2', '[OPEN_PAREN]', 'var_1', '[CLOSE_PAREN]', '*', 'gaussian', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '+', 'cosh', '[OPEN_PAREN]', 'tanh', '[OPEN_PAREN]', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 50: ['[OPEN_PAREN]', '[OPEN_PAREN]', 'reverse', '[OPEN_PAREN]', 'var_0', '[CLOSE_PAREN]', '+', 'tanh', '[OPEN_PAREN]', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '*', 'tan', '[OPEN_PAREN]', 'gaussian', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 51: ['[OPEN_PAREN]', '[OPEN_PAREN]', 'exp', '[OPEN_PAREN]', 'var_1', '[CLOSE_PAREN]', '+', 'reverse', '[OPEN_PAREN]', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '*', 'sin', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 52: ['[OPEN_PAREN]', '[OPEN_PAREN]', 'C_0', '*', 'cosh', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '+', 'pow_', '2', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_1', '+', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 53: ['[OPEN_PAREN]', '[OPEN_PAREN]', 'C_0', '+', 'C_1', '[CLOSE_PAREN]', '+', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_0', '+', 'var_1', '[CLOSE_PAREN]', '*', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 54: ['[OPEN_PAREN]', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_1', '*', 'C_0', '[CLOSE_PAREN]', '+', 'cos', '[OPEN_PAREN]', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '+', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_2', '+', 'C_1', '[CLOSE_PAREN]', '+', 'C_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 55: ['[OPEN_PAREN]', 'pow_', '2', '[OPEN_PAREN]', 'sin', '[OPEN_PAREN]', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '+', 'gaussian', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_2', '*', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 56: ['[OPEN_PAREN]', '[OPEN_PAREN]', 'tan', '[OPEN_PAREN]', 'var_1', '[CLOSE_PAREN]', '*', 'tan', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '+', 'reverse', '[OPEN_PAREN]', 'cosh', '[OPEN_PAREN]', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 57: ['[OPEN_PAREN]', 'log', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_2', '*', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '+', 'pow_', '2', '[OPEN_PAREN]', 'sinh', '[OPEN_PAREN]', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 58: ['[OPEN_PAREN]', '[OPEN_PAREN]', 'neg', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '+', 'tanh', '[OPEN_PAREN]', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '*', 'tanh', '[OPEN_PAREN]', 'reverse', '[OPEN_PAREN]', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 59: ['[OPEN_PAREN]', 'tan', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_2', '*', 'C_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '+', 'neg', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_0', '*', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 60: ['[OPEN_PAREN]', 'neg', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_2', '*', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '*', 'cosh', '[OPEN_PAREN]', 'gaussian', '[OPEN_PAREN]', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 61: ['[OPEN_PAREN]', '[OPEN_PAREN]', 'pow_', '2', '[OPEN_PAREN]', 'var_1', '[CLOSE_PAREN]', '*', '[OPEN_PAREN]', 'var_0', '*', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '+', 'exp', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_2', '+', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 62: ['[OPEN_PAREN]', 'neg', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_1', '+', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '*', 'tanh', '[OPEN_PAREN]', 'tan', '[OPEN_PAREN]', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 63: ['[OPEN_PAREN]', 'exp', '[OPEN_PAREN]', 'sin', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '+', 'cosh', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_0', '+', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 64: ['[OPEN_PAREN]', 'cosh', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_1', '+', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '+', 'sin', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_0', '+', 'C_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 65: ['[OPEN_PAREN]', '[OPEN_PAREN]', 'tan', '[OPEN_PAREN]', 'var_1', '[CLOSE_PAREN]', '*', 'sin', '[OPEN_PAREN]', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '+', '[OPEN_PAREN]', 'tan', '[OPEN_PAREN]', 'var_0', '[CLOSE_PAREN]', '+', 'cos', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 66: ['[OPEN_PAREN]', '[OPEN_PAREN]', 'var_0', '*', 'sinh', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '+', '[OPEN_PAREN]', 'sqrt', '[OPEN_PAREN]', 'var_1', '[CLOSE_PAREN]', '*', 'reverse', '[OPEN_PAREN]', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 67: ['[OPEN_PAREN]', '[OPEN_PAREN]', 'exp', '[OPEN_PAREN]', 'var_1', '[CLOSE_PAREN]', '+', '[OPEN_PAREN]', 'var_1', '*', 'C_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '*', '[OPEN_PAREN]', 'gaussian', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '+', 'sinh', '[OPEN_PAREN]', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 68: ['[OPEN_PAREN]', 'neg', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_0', '*', 'C_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '+', 'sin', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_2', '*', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 69: ['[OPEN_PAREN]', '[OPEN_PAREN]', 'neg', '[OPEN_PAREN]', 'var_0', '[CLOSE_PAREN]', '+', 'tanh', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '*', 'sqrt', '[OPEN_PAREN]', 'sin', '[OPEN_PAREN]', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 70: ['[OPEN_PAREN]', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_0', '+', 'C_0', '[CLOSE_PAREN]', '*', '[OPEN_PAREN]', 'var_1', '+', 'C_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '*', 'pow_', '2', '[OPEN_PAREN]', 'neg', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 71: ['sinh', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_1', '+', '[OPEN_PAREN]', 'var_2', '+', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 72: ['[OPEN_PAREN]', '[OPEN_PAREN]', 'sin', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '*', 'cosh', '[OPEN_PAREN]', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '*', 'neg', '[OPEN_PAREN]', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 73: ['[OPEN_PAREN]', '[OPEN_PAREN]', 'cos', '[OPEN_PAREN]', 'var_1', '[CLOSE_PAREN]', '*', '[OPEN_PAREN]', 'var_0', '+', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '+', 'exp', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_2', '*', 'C_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 74: ['[OPEN_PAREN]', '[OPEN_PAREN]', 'pow_', '2', '[OPEN_PAREN]', 'var_1', '[CLOSE_PAREN]', '*', 'cosh', '[OPEN_PAREN]', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '+', 'log', '[OPEN_PAREN]', 'cos', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 75: ['[OPEN_PAREN]', '[OPEN_PAREN]', 'pow_', '2', '[OPEN_PAREN]', 'var_1', '[CLOSE_PAREN]', '*', 'log', '[OPEN_PAREN]', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '*', 'neg', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 76: ['[OPEN_PAREN]', '[OPEN_PAREN]', 'sin', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '+', '[OPEN_PAREN]', 'var_1', '+', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '*', 'sin', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_0', '+', 'C_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 77: ['[OPEN_PAREN]', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_2', '*', 'C_0', '[CLOSE_PAREN]', '*', '[OPEN_PAREN]', 'var_0', '*', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '+', 'neg', '[OPEN_PAREN]', 'reverse', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 78: ['[OPEN_PAREN]', '[OPEN_PAREN]', 'sqrt', '[OPEN_PAREN]', 'var_0', '[CLOSE_PAREN]', '+', '[OPEN_PAREN]', 'var_2', '+', 'C_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '+', 'pow_', '2', '[OPEN_PAREN]', 'sqrt', '[OPEN_PAREN]', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 79: ['[OPEN_PAREN]', 'neg', '[OPEN_PAREN]', 'tan', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '*', 'exp', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_1', '*', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 80: ['[OPEN_PAREN]', 'sqrt', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_2', '*', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '+', 'neg', '[OPEN_PAREN]', 'cosh', '[OPEN_PAREN]', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 81: ['[OPEN_PAREN]', 'cosh', '[OPEN_PAREN]', 'reverse', '[OPEN_PAREN]', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '+', 'cosh', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_0', '+', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 82: ['[OPEN_PAREN]', '[OPEN_PAREN]', 'tanh', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '*', 'cos', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '+', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_1', '+', 'C_0', '[CLOSE_PAREN]', '+', '[OPEN_PAREN]', 'var_0', '+', 'C_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 83: ['[OPEN_PAREN]', '[OPEN_PAREN]', 'cos', '[OPEN_PAREN]', 'var_0', '[CLOSE_PAREN]', '+', 'sqrt', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '+', 'sin', '[OPEN_PAREN]', 'sqrt', '[OPEN_PAREN]', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 84: ['[OPEN_PAREN]', 'sinh', '[OPEN_PAREN]', 'sqrt', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '*', 'tanh', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_1', '+', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 85: ['[OPEN_PAREN]', 'sinh', '[OPEN_PAREN]', 'sqrt', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '*', 'sinh', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_1', '+', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 86: ['[OPEN_PAREN]', 'neg', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_2', '*', 'C_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '+', 'sin', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_1', '*', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 87: ['[OPEN_PAREN]', 'neg', '[OPEN_PAREN]', 'gaussian', '[OPEN_PAREN]', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '+', 'neg', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_0', '+', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 88: ['[OPEN_PAREN]', 'reverse', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_0', '+', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '+', 'pow_', '2', '[OPEN_PAREN]', 'gaussian', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 89: ['[OPEN_PAREN]', '[OPEN_PAREN]', 'sin', '[OPEN_PAREN]', 'var_1', '[CLOSE_PAREN]', '+', 'cosh', '[OPEN_PAREN]', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '+', 'sinh', '[OPEN_PAREN]', 'log', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 90: ['[OPEN_PAREN]', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_0', '*', 'C_0', '[CLOSE_PAREN]', '+', '[OPEN_PAREN]', 'var_2', '+', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '+', 'sqrt', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_1', '+', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 91: ['[OPEN_PAREN]', '[OPEN_PAREN]', 'reverse', '[OPEN_PAREN]', 'var_0', '[CLOSE_PAREN]', '+', 'sin', '[OPEN_PAREN]', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '*', 'sqrt', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_1', '*', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 92: ['[OPEN_PAREN]', 'gaussian', '[OPEN_PAREN]', 'cosh', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '+', 'reverse', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_1', '*', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 93: ['[OPEN_PAREN]', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_0', '+', 'C_0', '[CLOSE_PAREN]', '+', 'sqrt', '[OPEN_PAREN]', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '+', 'cos', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_2', '*', 'C_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 94: ['[OPEN_PAREN]', '[OPEN_PAREN]', 'var_2', '*', '[OPEN_PAREN]', 'var_1', '*', 'C_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '+', 'pow_', '2', '[OPEN_PAREN]', 'cosh', '[OPEN_PAREN]', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 95: ['[OPEN_PAREN]', '[OPEN_PAREN]', 'exp', '[OPEN_PAREN]', 'var_0', '[CLOSE_PAREN]', '*', 'var_2', '[CLOSE_PAREN]', '+', 'reverse', '[OPEN_PAREN]', 'neg', '[OPEN_PAREN]', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 96: ['[OPEN_PAREN]', '[OPEN_PAREN]', 'sin', '[OPEN_PAREN]', 'var_0', '[CLOSE_PAREN]', '+', 'gaussian', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '*', 'cos', '[OPEN_PAREN]', 'pow_', '2', '[OPEN_PAREN]', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 97: ['sqrt', '[OPEN_PAREN]', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_0', '+', 'var_2', '[CLOSE_PAREN]', '+', 'reverse', '[OPEN_PAREN]', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 98: ['[OPEN_PAREN]', '[OPEN_PAREN]', 'gaussian', '[OPEN_PAREN]', 'var_1', '[CLOSE_PAREN]', '+', '[OPEN_PAREN]', 'var_2', '*', 'C_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '*', 'log', '[OPEN_PAREN]', 'pow_', '2', '[OPEN_PAREN]', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 99: ['[OPEN_PAREN]', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_0', '+', 'C_0', '[CLOSE_PAREN]', '+', 'sqrt', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '*', 'gaussian', '[OPEN_PAREN]', 'pow_', '2', '[OPEN_PAREN]', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 100: ['[OPEN_PAREN]', 'gaussian', '[OPEN_PAREN]', 'reverse', '[OPEN_PAREN]', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '*', 'gaussian', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_0', '*', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 101: ['[OPEN_PAREN]', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_0', '*', 'var_1', '[CLOSE_PAREN]', '+', '[OPEN_PAREN]', 'var_1', '+', 'C_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '*', 'exp', '[OPEN_PAREN]', 'reverse', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 102: ['[OPEN_PAREN]', '[OPEN_PAREN]', 'tanh', '[OPEN_PAREN]', 'var_1', '[CLOSE_PAREN]', '+', 'pow_', '2', '[OPEN_PAREN]', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '+', 'tan', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 103: ['[OPEN_PAREN]', '[OPEN_PAREN]', 'cosh', '[OPEN_PAREN]', 'var_1', '[CLOSE_PAREN]', '+', 'sinh', '[OPEN_PAREN]', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '+', 'cos', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_2', '+', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 104: ['[OPEN_PAREN]', 'tan', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_2', '*', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '+', 'sin', '[OPEN_PAREN]', 'neg', '[OPEN_PAREN]', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 105: ['[OPEN_PAREN]', 'neg', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_0', '*', 'C_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '*', 'neg', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_2', '*', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 106: ['[OPEN_PAREN]', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_0', '+', 'C_0', '[CLOSE_PAREN]', '+', 'var_1', '[CLOSE_PAREN]', '*', '[OPEN_PAREN]', 'log', '[OPEN_PAREN]', 'var_1', '[CLOSE_PAREN]', '*', 'tanh', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 107: ['[OPEN_PAREN]', 'pow_', '2', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_0', '+', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '*', 'reverse', '[OPEN_PAREN]', 'sqrt', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 108: ['[OPEN_PAREN]', 'sin', '[OPEN_PAREN]', 'pow_', '2', '[OPEN_PAREN]', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '*', 'sqrt', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_1', '*', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 109: ['[OPEN_PAREN]', 'tanh', '[OPEN_PAREN]', 'sin', '[OPEN_PAREN]', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '*', 'tanh', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_1', '+', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 110: ['[OPEN_PAREN]', '[OPEN_PAREN]', 'cosh', '[OPEN_PAREN]', 'var_0', '[CLOSE_PAREN]', '+', 'pow_', '2', '[OPEN_PAREN]', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '*', 'exp', '[OPEN_PAREN]', 'neg', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 111: ['[OPEN_PAREN]', 'gaussian', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_2', '+', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '*', 'pow_', '2', '[OPEN_PAREN]', 'cosh', '[OPEN_PAREN]', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 112: ['[OPEN_PAREN]', 'log', '[OPEN_PAREN]', 'sqrt', '[OPEN_PAREN]', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '*', 'tan', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_2', '+', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 113: ['[OPEN_PAREN]', 'sinh', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_2', '+', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '+', 'sqrt', '[OPEN_PAREN]', 'tan', '[OPEN_PAREN]', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 114: ['[OPEN_PAREN]', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_2', '+', 'C_0', '[CLOSE_PAREN]', '+', 'sin', '[OPEN_PAREN]', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '*', 'gaussian', '[OPEN_PAREN]', 'gaussian', '[OPEN_PAREN]', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 115: ['[OPEN_PAREN]', '[OPEN_PAREN]', 'pow_', '2', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '*', 'cosh', '[OPEN_PAREN]', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '+', 'log', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_0', '*', 'C_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 116: ['[OPEN_PAREN]', 'exp', '[OPEN_PAREN]', 'cosh', '[OPEN_PAREN]', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '*', 'exp', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_0', '*', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 117: ['[OPEN_PAREN]', 'tan', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_0', '*', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '*', 'exp', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 118: ['[OPEN_PAREN]', 'tanh', '[OPEN_PAREN]', 'log', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '*', 'sqrt', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_0', '*', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 119: ['[OPEN_PAREN]', '[OPEN_PAREN]', 'tan', '[OPEN_PAREN]', 'var_1', '[CLOSE_PAREN]', '+', 'log', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '+', 'log', '[OPEN_PAREN]', 'cosh', '[OPEN_PAREN]', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 120: ['[OPEN_PAREN]', 'tanh', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_2', '+', 'C_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '+', 'sqrt', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_0', '+', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 121: ['[OPEN_PAREN]', 'cosh', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_1', '+', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '+', 'gaussian', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_0', '+', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 122: ['[OPEN_PAREN]', 'tanh', '[OPEN_PAREN]', 'cosh', '[OPEN_PAREN]', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '*', 'reverse', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_2', '+', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 123: ['[OPEN_PAREN]', 'sin', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_2', '+', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '*', 'reverse', '[OPEN_PAREN]', 'log', '[OPEN_PAREN]', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 124: ['[OPEN_PAREN]', 'gaussian', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_0', '+', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '+', 'sinh', '[OPEN_PAREN]', 'log', '[OPEN_PAREN]', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 125: ['[OPEN_PAREN]', 'sqrt', '[OPEN_PAREN]', 'log', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '+', 'sqrt', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_0', '+', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 126: ['[OPEN_PAREN]', 'exp', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_2', '+', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '+', 'sinh', '[OPEN_PAREN]', 'reverse', '[OPEN_PAREN]', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 127: ['[OPEN_PAREN]', 'sin', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_0', '*', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '*', 'sinh', '[OPEN_PAREN]', 'sinh', '[OPEN_PAREN]', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 128: ['[OPEN_PAREN]', '[OPEN_PAREN]', 'reverse', '[OPEN_PAREN]', 'var_1', '[CLOSE_PAREN]', '*', 'log', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '+', 'sin', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_1', '+', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 129: ['[OPEN_PAREN]', '[OPEN_PAREN]', 'sqrt', '[OPEN_PAREN]', 'var_1', '[CLOSE_PAREN]', '+', '[OPEN_PAREN]', 'var_1', '*', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '+', '[OPEN_PAREN]', 'C_0', '+', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 130: ['[OPEN_PAREN]', 'sqrt', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_1', '+', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '+', 'gaussian', '[OPEN_PAREN]', 'pow_', '2', '[OPEN_PAREN]', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 131: ['[OPEN_PAREN]', '[OPEN_PAREN]', 'var_1', '+', 'sin', '[OPEN_PAREN]', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '*', '[OPEN_PAREN]', 'tan', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '+', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 132: ['[OPEN_PAREN]', 'cos', '[OPEN_PAREN]', 'neg', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '*', 'sqrt', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_1', '+', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 133: ['[OPEN_PAREN]', 'sin', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_1', '+', 'C_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '+', 'cosh', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_0', '+', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 134: ['sqrt', '[OPEN_PAREN]', '[OPEN_PAREN]', 'sin', '[OPEN_PAREN]', 'var_0', '[CLOSE_PAREN]', '*', '[OPEN_PAREN]', 'var_1', '+', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 135: ['[OPEN_PAREN]', '[OPEN_PAREN]', 'tanh', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '+', '[OPEN_PAREN]', 'var_2', '+', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '+', 'tan', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_1', '+', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 136: ['[OPEN_PAREN]', '[OPEN_PAREN]', 'neg', '[OPEN_PAREN]', 'var_0', '[CLOSE_PAREN]', '*', 'sin', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '*', 'sqrt', '[OPEN_PAREN]', 'exp', '[OPEN_PAREN]', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 137: ['[OPEN_PAREN]', '[OPEN_PAREN]', 'cosh', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '*', 'cosh', '[OPEN_PAREN]', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '+', '[OPEN_PAREN]', 'exp', '[OPEN_PAREN]', 'var_1', '[CLOSE_PAREN]', '+', 'pow_', '2', '[OPEN_PAREN]', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 138: ['reverse', '[OPEN_PAREN]', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_2', '+', 'var_0', '[CLOSE_PAREN]', '*', '[OPEN_PAREN]', 'var_1', '+', 'C_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 139: ['[OPEN_PAREN]', '[OPEN_PAREN]', 'reverse', '[OPEN_PAREN]', 'var_0', '[CLOSE_PAREN]', '*', 'log', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '+', 'pow_', '2', '[OPEN_PAREN]', 'cos', '[OPEN_PAREN]', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 140: ['[OPEN_PAREN]', 'reverse', '[OPEN_PAREN]', 'tanh', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '*', 'sinh', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_0', '+', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 141: ['[OPEN_PAREN]', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_2', '*', 'var_1', '[CLOSE_PAREN]', '+', 'cosh', '[OPEN_PAREN]', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '+', 'sinh', '[OPEN_PAREN]', 'C_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 142: ['[OPEN_PAREN]', 'tan', '[OPEN_PAREN]', 'neg', '[OPEN_PAREN]', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '+', 'tanh', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_2', '+', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 143: ['[OPEN_PAREN]', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_0', '*', 'C_0', '[CLOSE_PAREN]', '+', 'neg', '[OPEN_PAREN]', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '*', '[OPEN_PAREN]', 'sqrt', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '+', 'C_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 144: ['[OPEN_PAREN]', 'log', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_0', '+', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '+', 'log', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_1', '+', 'C_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 145: ['[OPEN_PAREN]', 'sinh', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_2', '*', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '*', 'log', '[OPEN_PAREN]', 'sqrt', '[OPEN_PAREN]', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 146: ['[OPEN_PAREN]', '[OPEN_PAREN]', 'pow_', '2', '[OPEN_PAREN]', 'var_1', '[CLOSE_PAREN]', '*', 'sinh', '[OPEN_PAREN]', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '*', 'cos', '[OPEN_PAREN]', 'pow_', '2', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 147: ['[OPEN_PAREN]', 'sinh', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_1', '+', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '*', 'cosh', '[OPEN_PAREN]', 'log', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 148: ['[OPEN_PAREN]', 'reverse', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_2', '*', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '*', 'sin', '[OPEN_PAREN]', 'gaussian', '[OPEN_PAREN]', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 149: ['cos', '[OPEN_PAREN]', '[OPEN_PAREN]', 'sqrt', '[OPEN_PAREN]', 'var_0', '[CLOSE_PAREN]', '*', '[OPEN_PAREN]', 'var_1', '*', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 150: ['[OPEN_PAREN]', '[OPEN_PAREN]', 'var_0', '+', 'sinh', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '+', 'tan', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_1', '*', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 151: ['[OPEN_PAREN]', 'neg', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_1', '+', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '+', 'log', '[OPEN_PAREN]', 'pow_', '2', '[OPEN_PAREN]', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 152: ['[OPEN_PAREN]', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_2', '*', 'var_2', '[CLOSE_PAREN]', '+', '[OPEN_PAREN]', 'var_0', '+', 'C_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '*', 'tan', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_2', '+', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 153: ['[OPEN_PAREN]', '[OPEN_PAREN]', 'C_0', '+', '[OPEN_PAREN]', 'var_1', '+', 'C_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '*', 'gaussian', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_2', '+', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 154: ['[OPEN_PAREN]', '[OPEN_PAREN]', 'sqrt', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '*', 'tanh', '[OPEN_PAREN]', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '*', 'pow_', '2', '[OPEN_PAREN]', 'tanh', '[OPEN_PAREN]', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 155: ['[OPEN_PAREN]', '[OPEN_PAREN]', 'pow_', '2', '[OPEN_PAREN]', 'var_1', '[CLOSE_PAREN]', '*', 'tan', '[OPEN_PAREN]', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '+', 'neg', '[OPEN_PAREN]', 'pow_', '2', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 156: ['[OPEN_PAREN]', 'neg', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_2', '+', 'C_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '*', 'tan', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_0', '+', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 157: ['[OPEN_PAREN]', 'cos', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_0', '*', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '*', 'neg', '[OPEN_PAREN]', 'log', '[OPEN_PAREN]', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 158: ['[OPEN_PAREN]', '[OPEN_PAREN]', 'sqrt', '[OPEN_PAREN]', 'var_0', '[CLOSE_PAREN]', '*', 'cosh', '[OPEN_PAREN]', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '+', 'gaussian', '[OPEN_PAREN]', 'exp', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 159: ['[OPEN_PAREN]', '[OPEN_PAREN]', 'sqrt', '[OPEN_PAREN]', 'var_1', '[CLOSE_PAREN]', '+', '[OPEN_PAREN]', 'var_2', '+', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '+', 'reverse', '[OPEN_PAREN]', 'C_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 160: ['[OPEN_PAREN]', 'pow_', '2', '[OPEN_PAREN]', 'gaussian', '[OPEN_PAREN]', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '*', 'sinh', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_2', '+', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 161: ['[OPEN_PAREN]', 'sinh', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_1', '*', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '*', 'cos', '[OPEN_PAREN]', 'sqrt', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 162: ['tan', '[OPEN_PAREN]', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_2', '*', 'var_0', '[CLOSE_PAREN]', '*', 'sinh', '[OPEN_PAREN]', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 163: ['[OPEN_PAREN]', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_2', '+', 'var_1', '[CLOSE_PAREN]', '*', 'cosh', '[OPEN_PAREN]', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '*', 'log', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_1', '*', 'C_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 164: ['[OPEN_PAREN]', 'tan', '[OPEN_PAREN]', 'reverse', '[OPEN_PAREN]', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '+', 'sqrt', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_2', '+', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 165: ['[OPEN_PAREN]', '[OPEN_PAREN]', 'tan', '[OPEN_PAREN]', 'var_0', '[CLOSE_PAREN]', '+', 'pow_', '2', '[OPEN_PAREN]', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '*', 'exp', '[OPEN_PAREN]', 'neg', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 166: ['[OPEN_PAREN]', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_1', '+', 'var_2', '[CLOSE_PAREN]', '+', 'sinh', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '+', 'cosh', '[OPEN_PAREN]', 'neg', '[OPEN_PAREN]', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 167: ['[OPEN_PAREN]', '[OPEN_PAREN]', 'sinh', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '+', '[OPEN_PAREN]', 'var_0', '*', 'C_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '+', 'tanh', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_1', '*', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 168: ['[OPEN_PAREN]', 'cosh', '[OPEN_PAREN]', 'tan', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '+', 'exp', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_1', '+', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 169: ['[OPEN_PAREN]', '[OPEN_PAREN]', 'exp', '[OPEN_PAREN]', 'var_0', '[CLOSE_PAREN]', '*', 'exp', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '+', 'reverse', '[OPEN_PAREN]', 'cos', '[OPEN_PAREN]', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 170: ['[OPEN_PAREN]', '[OPEN_PAREN]', 'var_2', '*', 'reverse', '[OPEN_PAREN]', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '+', 'pow_', '2', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_1', '*', 'C_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 171: ['[OPEN_PAREN]', '[OPEN_PAREN]', 'tanh', '[OPEN_PAREN]', 'var_0', '[CLOSE_PAREN]', '*', 'pow_', '2', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '+', 'pow_', '2', '[OPEN_PAREN]', 'log', '[OPEN_PAREN]', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 172: ['[OPEN_PAREN]', '[OPEN_PAREN]', 'sinh', '[OPEN_PAREN]', 'var_0', '[CLOSE_PAREN]', '+', 'cosh', '[OPEN_PAREN]', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '+', 'reverse', '[OPEN_PAREN]', 'cosh', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 173: ['[OPEN_PAREN]', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_0', '+', 'C_0', '[CLOSE_PAREN]', '+', 'pow_', '2', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '+', 'sinh', '[OPEN_PAREN]', 'tan', '[OPEN_PAREN]', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 174: ['neg', '[OPEN_PAREN]', '[OPEN_PAREN]', 'sqrt', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '*', '[OPEN_PAREN]', 'var_0', '+', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 175: ['[OPEN_PAREN]', '[OPEN_PAREN]', 'sqrt', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '+', 'sqrt', '[OPEN_PAREN]', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '+', 'tanh', '[OPEN_PAREN]', 'pow_', '2', '[OPEN_PAREN]', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 176: ['[OPEN_PAREN]', '[OPEN_PAREN]', 'tanh', '[OPEN_PAREN]', 'var_0', '[CLOSE_PAREN]', '*', 'sqrt', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '+', 'sinh', '[OPEN_PAREN]', 'gaussian', '[OPEN_PAREN]', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 177: ['[OPEN_PAREN]', '[OPEN_PAREN]', 'tan', '[OPEN_PAREN]', 'var_0', '[CLOSE_PAREN]', '*', '[OPEN_PAREN]', 'var_2', '+', 'C_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '+', 'exp', '[OPEN_PAREN]', 'reverse', '[OPEN_PAREN]', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 178: ['[OPEN_PAREN]', 'sin', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_0', '*', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '*', 'exp', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_2', '*', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 179: ['[OPEN_PAREN]', 'tanh', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_0', '*', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '*', 'cosh', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_1', '+', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 180: ['[OPEN_PAREN]', 'sin', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_0', '*', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '+', 'gaussian', '[OPEN_PAREN]', 'sinh', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 181: ['[OPEN_PAREN]', 'tan', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_1', '*', 'C_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '+', 'cos', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_0', '*', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 182: ['[OPEN_PAREN]', 'sinh', '[OPEN_PAREN]', 'pow_', '2', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '+', 'sqrt', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_0', '+', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 183: ['[OPEN_PAREN]', '[OPEN_PAREN]', 'cos', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '+', 'gaussian', '[OPEN_PAREN]', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '*', 'neg', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_1', '*', 'C_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 184: ['[OPEN_PAREN]', '[OPEN_PAREN]', 'sin', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '+', 'sinh', '[OPEN_PAREN]', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '*', '[OPEN_PAREN]', 'sinh', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '*', 'tanh', '[OPEN_PAREN]', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 185: ['[OPEN_PAREN]', 'tan', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_2', '*', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '*', 'cos', '[OPEN_PAREN]', 'neg', '[OPEN_PAREN]', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# ...
# Entry 701: ['[OPEN_PAREN]', '[OPEN_PAREN]', 'sinh', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '+', 'tan', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '*', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_0', '*', 'C_0', '[CLOSE_PAREN]', '*', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 702: ['[OPEN_PAREN]', 'tanh', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_2', '*', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '+', 'sin', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_1', '*', 'C_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 703: ['[OPEN_PAREN]', 'tanh', '[OPEN_PAREN]', 'var_0', '[CLOSE_PAREN]', '*', 'gaussian', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_1', '+', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 704: ['[OPEN_PAREN]', '[OPEN_PAREN]', 'neg', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '*', 'neg', '[OPEN_PAREN]', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '*', 'gaussian', '[OPEN_PAREN]', 'tanh', '[OPEN_PAREN]', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 705: ['[OPEN_PAREN]', '[OPEN_PAREN]', 'tan', '[OPEN_PAREN]', 'var_0', '[CLOSE_PAREN]', '+', 'pow_', '2', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '+', 'gaussian', '[OPEN_PAREN]', 'cosh', '[OPEN_PAREN]', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 706: ['[OPEN_PAREN]', '[OPEN_PAREN]', 'neg', '[OPEN_PAREN]', 'var_0', '[CLOSE_PAREN]', '*', 'exp', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '*', 'tan', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_1', '*', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 707: ['[OPEN_PAREN]', 'sinh', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_1', '*', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '*', 'pow_', '2', '[OPEN_PAREN]', 'neg', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 708: ['[OPEN_PAREN]', 'tanh', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_0', '*', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '+', 'gaussian', '[OPEN_PAREN]', 'reverse', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 709: ['[OPEN_PAREN]', 'gaussian', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_2', '*', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '*', 'reverse', '[OPEN_PAREN]', 'tan', '[OPEN_PAREN]', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 710: ['[OPEN_PAREN]', 'cos', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_2', '*', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '+', 'reverse', '[OPEN_PAREN]', 'exp', '[OPEN_PAREN]', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 711: ['[OPEN_PAREN]', 'cosh', '[OPEN_PAREN]', 'sin', '[OPEN_PAREN]', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '+', 'cos', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_2', '+', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 712: ['[OPEN_PAREN]', '[OPEN_PAREN]', 'sin', '[OPEN_PAREN]', 'var_1', '[CLOSE_PAREN]', '*', 'neg', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '+', 'cosh', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_0', '*', 'C_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 713: ['[OPEN_PAREN]', 'reverse', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_2', '*', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '*', 'tan', '[OPEN_PAREN]', 'reverse', '[OPEN_PAREN]', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 714: ['[OPEN_PAREN]', '[OPEN_PAREN]', 'C_0', '+', '[OPEN_PAREN]', 'var_0', '+', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '*', 'pow_', '2', '[OPEN_PAREN]', 'log', '[OPEN_PAREN]', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 715: ['[OPEN_PAREN]', 'cosh', '[OPEN_PAREN]', 'gaussian', '[OPEN_PAREN]', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '+', 'tan', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_1', '+', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 716: ['[OPEN_PAREN]', 'tanh', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_0', '+', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '*', 'pow_', '2', '[OPEN_PAREN]', 'tan', '[OPEN_PAREN]', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 717: ['[OPEN_PAREN]', '[OPEN_PAREN]', 'cosh', '[OPEN_PAREN]', 'var_1', '[CLOSE_PAREN]', '+', 'tanh', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '*', 'sin', '[OPEN_PAREN]', 'gaussian', '[OPEN_PAREN]', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 718: ['[OPEN_PAREN]', '[OPEN_PAREN]', 'cos', '[OPEN_PAREN]', 'var_0', '[CLOSE_PAREN]', '*', '[OPEN_PAREN]', 'var_2', '*', 'C_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '+', 'tanh', '[OPEN_PAREN]', 'sinh', '[OPEN_PAREN]', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 719: ['[OPEN_PAREN]', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_0', '+', 'var_1', '[CLOSE_PAREN]', '+', 'cosh', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '*', 'neg', '[OPEN_PAREN]', 'cosh', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 720: ['[OPEN_PAREN]', 'sin', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_1', '*', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '+', 'log', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_2', '+', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 721: ['[OPEN_PAREN]', 'sinh', '[OPEN_PAREN]', 'pow_', '2', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '*', 'exp', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_0', '+', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 722: ['[OPEN_PAREN]', 'log', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_1', '+', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '*', 'sin', '[OPEN_PAREN]', 'pow_', '2', '[OPEN_PAREN]', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 723: ['[OPEN_PAREN]', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_0', '*', 'C_0', '[CLOSE_PAREN]', '*', 'tanh', '[OPEN_PAREN]', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '*', 'cosh', '[OPEN_PAREN]', 'sqrt', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 724: ['[OPEN_PAREN]', 'gaussian', '[OPEN_PAREN]', 'cos', '[OPEN_PAREN]', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '*', 'sinh', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_1', '+', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 725: ['[OPEN_PAREN]', '[OPEN_PAREN]', 'tanh', '[OPEN_PAREN]', 'var_1', '[CLOSE_PAREN]', '*', 'tan', '[OPEN_PAREN]', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '*', 'cos', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 726: ['[OPEN_PAREN]', '[OPEN_PAREN]', 'sqrt', '[OPEN_PAREN]', 'var_1', '[CLOSE_PAREN]', '+', '[OPEN_PAREN]', 'var_2', '+', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '+', 'pow_', '2', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_0', '+', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 727: ['[OPEN_PAREN]', 'neg', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_0', '+', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '+', 'sinh', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_2', '+', 'C_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 728: ['[OPEN_PAREN]', '[OPEN_PAREN]', 'gaussian', '[OPEN_PAREN]', 'var_0', '[CLOSE_PAREN]', '*', 'neg', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '*', 'sinh', '[OPEN_PAREN]', 'cosh', '[OPEN_PAREN]', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 729: ['[OPEN_PAREN]', 'cosh', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_1', '+', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '+', 'pow_', '2', '[OPEN_PAREN]', 'exp', '[OPEN_PAREN]', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 730: ['[OPEN_PAREN]', '[OPEN_PAREN]', 'sin', '[OPEN_PAREN]', 'var_0', '[CLOSE_PAREN]', '*', '[OPEN_PAREN]', 'var_1', '+', 'C_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '+', 'cos', '[OPEN_PAREN]', 'pow_', '2', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 731: ['[OPEN_PAREN]', 'sinh', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_0', '*', 'C_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '*', 'sinh', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_2', '+', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 732: ['[OPEN_PAREN]', 'sinh', '[OPEN_PAREN]', 'exp', '[OPEN_PAREN]', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '+', 'neg', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_2', '+', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 733: ['[OPEN_PAREN]', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_1', '+', 'var_2', '[CLOSE_PAREN]', '+', 'tanh', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '+', '[OPEN_PAREN]', 'tanh', '[OPEN_PAREN]', 'var_0', '[CLOSE_PAREN]', '*', 'tanh', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 734: ['[OPEN_PAREN]', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_2', '+', 'C_0', '[CLOSE_PAREN]', '+', '[OPEN_PAREN]', 'var_2', '+', 'C_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '+', 'cosh', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_0', '*', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 735: ['[OPEN_PAREN]', 'gaussian', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_0', '+', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '*', 'exp', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_2', '*', 'C_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 736: ['[OPEN_PAREN]', 'tan', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_0', '*', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '*', 'gaussian', '[OPEN_PAREN]', 'tan', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 737: ['[OPEN_PAREN]', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_1', '*', 'C_0', '[CLOSE_PAREN]', '+', 'var_2', '[CLOSE_PAREN]', '+', 'exp', '[OPEN_PAREN]', 'cos', '[OPEN_PAREN]', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 738: ['[OPEN_PAREN]', '[OPEN_PAREN]', 'tanh', '[OPEN_PAREN]', 'var_0', '[CLOSE_PAREN]', '+', 'tan', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '*', 'sqrt', '[OPEN_PAREN]', 'tanh', '[OPEN_PAREN]', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 739: ['[OPEN_PAREN]', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_0', '+', 'var_2', '[CLOSE_PAREN]', '+', '[OPEN_PAREN]', 'var_2', '+', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '*', '[OPEN_PAREN]', 'tan', '[OPEN_PAREN]', 'var_0', '[CLOSE_PAREN]', '*', 'tan', '[OPEN_PAREN]', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 740: ['cos', '[OPEN_PAREN]', '[OPEN_PAREN]', 'log', '[OPEN_PAREN]', 'var_1', '[CLOSE_PAREN]', '+', '[OPEN_PAREN]', 'var_2', '+', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 741: ['[OPEN_PAREN]', 'sin', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_0', '*', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '*', 'gaussian', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 742: ['[OPEN_PAREN]', 'reverse', '[OPEN_PAREN]', 'tan', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '*', 'pow_', '2', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_0', '+', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 743: ['[OPEN_PAREN]', '[OPEN_PAREN]', 'tanh', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '+', 'neg', '[OPEN_PAREN]', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '+', 'pow_', '2', '[OPEN_PAREN]', 'reverse', '[OPEN_PAREN]', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 744: ['[OPEN_PAREN]', 'pow_', '2', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_0', '+', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '*', 'log', '[OPEN_PAREN]', 'tan', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 745: ['[OPEN_PAREN]', '[OPEN_PAREN]', 'tan', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '+', 'cosh', '[OPEN_PAREN]', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '+', 'cosh', '[OPEN_PAREN]', 'cos', '[OPEN_PAREN]', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Entry 746: ['[OPEN_PAREN]', 'gaussian', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_0', '*', 'C_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '*', 'neg', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_2', '+', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]']
# Tokenized Formulas for Train Dataset: [['[OPEN_PAREN]', '[OPEN_PAREN]', 'cos', '[OPEN_PAREN]', 'var_1', '[CLOSE_PAREN]', '+', '[OPEN_PAREN]', 'var_2', '*', 'C_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '*', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_0', '*', 'var_0', '[CLOSE_PAREN]', '*', 'cos', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]'], ['[OPEN_PAREN]', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_1', '+', 'C_0', '[CLOSE_PAREN]', '+', 'tan', '[OPEN_PAREN]', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '+', 'tanh', '[OPEN_PAREN]', 'exp', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]'], ['[OPEN_PAREN]', 'pow_', '2', '[OPEN_PAREN]', 'cosh', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '+', 'reverse', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_1', '*', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]'], ['[OPEN_PAREN]', '[OPEN_PAREN]', 'gaussian', '[OPEN_PAREN]', 'var_1', '[CLOSE_PAREN]', '+', '[OPEN_PAREN]', 'var_0', '+', 'C_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '+', 'tan', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_1', '*', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]'], ['[OPEN_PAREN]', 'sqrt', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_2', '*', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '+', 'neg', '[OPEN_PAREN]', 'cosh', '[OPEN_PAREN]', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]'], ['[OPEN_PAREN]', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_2', '+', 'var_0', '[CLOSE_PAREN]', '*', 'sqrt', '[OPEN_PAREN]', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '*', 'tanh', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_1', '+', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]'], ['log', '[OPEN_PAREN]', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_0', '+', 'C_0', '[CLOSE_PAREN]', '*', '[OPEN_PAREN]', 'var_1', '+', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]'], ['[OPEN_PAREN]', '[OPEN_PAREN]', 'sin', '[OPEN_PAREN]', 'var_1', '[CLOSE_PAREN]', '+', 'tanh', '[OPEN_PAREN]', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '*', 'sinh', '[OPEN_PAREN]', 'sqrt', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]'], ['[OPEN_PAREN]', 'tanh', '[OPEN_PAREN]', 'log', '[OPEN_PAREN]', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '+', 'tanh', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_2', '+', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]'], ['[OPEN_PAREN]', 'sinh', '[OPEN_PAREN]', 'tanh', '[OPEN_PAREN]', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '+', 'cos', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_1', '*', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]'], ['[OPEN_PAREN]', 'log', '[OPEN_PAREN]', 'sinh', '[OPEN_PAREN]', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '+', 'neg', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_2', '*', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]'], ['[OPEN_PAREN]', '[OPEN_PAREN]', 'log', '[OPEN_PAREN]', 'var_0', '[CLOSE_PAREN]', '*', 'sqrt', '[OPEN_PAREN]', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '+', 'sin', '[OPEN_PAREN]', 'pow_', '2', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]'], ['[OPEN_PAREN]', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_0', '*', 'C_0', '[CLOSE_PAREN]', '+', 'sinh', '[OPEN_PAREN]', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '*', 'reverse', '[OPEN_PAREN]', 'gaussian', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]'], ['[OPEN_PAREN]', 'tan', '[OPEN_PAREN]', 'reverse', '[OPEN_PAREN]', 'var_2', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '+', 'exp', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_0', '+', 'var_1', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]'], ['[OPEN_PAREN]', 'log', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_1', '+', 'var_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '*', 'sqrt', '[OPEN_PAREN]', '[OPEN_PAREN]', 'var_2', '+', 'C_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '[CLOSE_PAREN]'], ['[OPEN_PAREN]', '[OPEN_PAREN]', 'gaussian', '[OPEN_PAREN]', 'var_1', '[CLOSE_PAREN]', '+', '[OPEN_PAREN]', 'var_0', '*', 'C_0', '[CLOSE_PAREN]', '[CLOSE_PAREN]', '+', 'sqrt', '[OPEN_PAREN]' ...

# %%
import torch
import torch.nn as nn
from collections import defaultdict
import re


class FormulaTokenizer:
    def __init__(self):
        self.token_to_id = defaultdict(lambda: self.token_to_id["[UNK]"])  # Default to [UNK] for unknown tokens
        self.token_to_id["[PAD]"] = 0
        self.token_to_id["[UNK]"] = 1
        self.token_to_id["[OPEN_PAREN]"] = 2
        self.token_to_id["[CLOSE_PAREN]"] = 3
        self.id_to_token = {v: k for k, v in self.token_to_id.items()}

    def build_vocab(self, tokenized_formulas):
        """
        Builds vocabulary from the tokenized formulas.
        Args:
            tokenized_formulas (list of lists): Each inner list contains tokens of a formula.
        """
        for formula in tokenized_formulas:
            for token in formula:
                if token not in self.token_to_id:
                    new_id = len(self.token_to_id)
                    self.token_to_id[token] = new_id
                    self.id_to_token[new_id] = token

    def encode(self, tokens, max_length):
        """
        Encodes a list of tokens into token IDs, with padding/truncation to max_length.
        Args:
            tokens (list): List of tokens.
            max_length (int): Maximum length of the sequence.
        Returns:
            list: List of token IDs padded/truncated to max_length.
        """
        token_ids = [self.token_to_id[token] for token in tokens]
        if len(token_ids) < max_length:
            token_ids += [self.token_to_id["[PAD]"]] * (max_length - len(token_ids))
        else:
            token_ids = token_ids[:max_length]
        return token_ids

    def decode(self, token_ids):
        """
        Decodes a list of token IDs back into tokens.
        Args:
            token_ids (list): List of token IDs.
        Returns:
            list: List of tokens.
        """
        return [self.id_to_token[token_id] for token_id in token_ids]

class FormulaEmbeddingModel(nn.Module):
    def __init__(self, vocab_size, embedding_dim):
        """
        Embedding model for formulas.
        Args:
            vocab_size (int): Size of the vocabulary.
            embedding_dim (int): Dimension of the embedding vectors.
        """
        super().__init__()
        self.embedding = nn.Embedding(vocab_size, embedding_dim)

    def forward(self, token_ids):
        """
        Forward pass to get embeddings for the token IDs.
        Args:
            token_ids (Tensor): Tensor of token IDs (batch_size, max_length).
        Returns:
            Tensor: Embedding tensor (batch_size, max_length, embedding_dim).
        """
        return self.embedding(token_ids)

# Tokenize dataset with updated tokenization
tokenized_train_formulas = [
    regex_tokenize_formula_with_tags(entry["formula_human_readable"])
    for entry in train
    if "formula_human_readable" in entry
]

# Prepare tokenized formulas and build vocabulary
tokenizer = FormulaTokenizer()
tokenizer.build_vocab(tokenized_train_formulas)

# Example parameters
embedding_dim = 128
max_length = 50

# Convert tokenized formulas into token IDs
encoded_formulas = [
    tokenizer.encode(tokens, max_length=max_length)
    for tokens in tokenized_train_formulas
]
encoded_formulas_tensor = torch.tensor(encoded_formulas, dtype=torch.long)  # Convert to tensor

# Initialize embedding model
vocab_size = len(tokenizer.token_to_id)
embedding_model = FormulaEmbeddingModel(vocab_size, embedding_dim)

# Generate embeddings for the formulas
with torch.no_grad():
    formula_embeddings = embedding_model(encoded_formulas_tensor)  # (batch_size, max_length, embedding_dim)

print(f"Formula Embeddings Shape: {formula_embeddings.shape}")
# Out:
# Formula Embeddings Shape: torch.Size([747, 50, 128])

# %%
# Print each token in the vocabulary with its corresponding embedding
def print_vocab_embeddings(tokenizer, embedding_model):
    vocab_size = len(tokenizer.token_to_id)
    token_to_id = tokenizer.token_to_id

    # Iterate over each token in the vocabulary
    for token, token_id in token_to_id.items():
        # Generate the embedding for the token
        token_tensor = torch.tensor([token_id], dtype=torch.long)  # Create a tensor for the token ID
        with torch.no_grad():  # Disable gradients for inference
            embedding = embedding_model.embedding(token_tensor).squeeze(0)  # Retrieve embedding
        
        # Print token and its embedding
        print(f"Token: {token}, Embedding: {embedding.tolist()}")

# Call the function to print embeddings for all tokens
# %%
from sklearn.preprocessing import MinMaxScaler
import pandas as pd
normalized_train = []
normalized_val = []
for i in train:
    scaler = MinMaxScaler()
    data = pd.DataFrame.from_dict(i["points"])
    normalized_data = scaler.fit_transform(data)
    normalized_train.append(pd.DataFrame(normalized_data, columns=data.columns))
for i in val:
    data = pd.DataFrame.from_dict(i["points"])
    normalized_data = scaler.fit_transform(data)
    normalized_val = pd.DataFrame(normalized_data, columns=data.columns)

# %%
len(normalized_val)
# Out:
# 100

# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset
import numpy as np
import pandas as pd

# Define Formula Embedding Model
class FormulaEmbeddingModel(nn.Module):
    def __init__(self, vocab_size, embedding_dim):
        super().__init__()
        self.embedding = nn.Embedding(vocab_size, embedding_dim)

    def forward(self, token_ids):
        return self.embedding(token_ids)

# Define Dataset Class for Precomputed Embeddings
class DiffusionDatasetWithTargets(Dataset):
    def __init__(self, precomputed_data):
        self.data = precomputed_data

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        return self.data[idx]

# Precompute embeddings for training and validation

def precompute_embeddings_with_targets(data, normalized_data, tokenizer, vocab_size, embedding_dim, max_length):
    embedding_model = FormulaEmbeddingModel(vocab_size, embedding_dim)
    precomputed = []

    for item, norm_item in zip(data, normalized_data):
        # Tokenize and encode formula
        tokens = tokenizer(item['formula_human_readable'])
        token_ids = torch.tensor(tokens, dtype=torch.long)

        # Pad or truncate to max_length
        if len(token_ids) < max_length:
            token_ids = torch.cat(
                [token_ids, torch.full((max_length - len(token_ids),), tokenizer['[PAD]'], dtype=torch.long)]
            )
        else:
            token_ids = token_ids[:max_length]

        # Generate embedding
        with torch.no_grad():
            embedding = embedding_model(token_ids.unsqueeze(0)).squeeze(0)

        # Use normalized data directly
        normalized_points = norm_item.drop(columns=['target']).to_dict(orient='list')
        normalized_target = norm_item['target'].values

        precomputed.append((normalized_points, embedding, normalized_target))

    return precomputed

# Diffusion Model
class DiffusionModel(nn.Module):
    def __init__(self, embedding_dim, hidden_dim):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(embedding_dim + 1, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, embedding_dim)
        )

    def forward(self, x, t):
        t_emb = t.view(-1, 1).expand_as(x)  # Broadcast t to match x shape
        x_t = torch.cat([x, t_emb], dim=-1)
        return self.net(x_t)

# Noise Scheduler
class NoiseScheduler:
    def __init__(self, timesteps, beta_start=1e-4, beta_end=2e-2):
        self.timesteps = timesteps
        self.betas = torch.linspace(beta_start, beta_end, timesteps)
        self.alphas = 1.0 - self.betas
        self.alpha_cumprod = torch.cumprod(self.alphas, dim=0)

    def add_noise(self, x, t):
        noise = torch.randn_like(x)
        sqrt_alpha_cumprod = self.alpha_cumprod[t].sqrt()
        sqrt_one_minus_alpha_cumprod = (1 - self.alpha_cumprod[t]).sqrt()
        x_t = sqrt_alpha_cumprod * x + sqrt_one_minus_alpha_cumprod * noise
        return x_t, noise
# Out:
# Number of parameters in model: 329344
# Batch 1/24
# Points Shape: [torch.Size([32, 100]), torch.Size([32, 100]), torch.Size([32, 100]), torch.Size([32, 100])], Embeddings Shape: torch.Size([32, 50, 128])
# Random Timesteps: tensor([724, 850,  79, 441, 213, 545, 632,  21, 609, 304,  10, 976, 762, 613,
#          87,   5, 710, 368, 533, 661, 358, 398, 618, 302, 552, 511, 994, 307,
#          92, 999, 260, 948])
# Batch 2/24
# Points Shape: [torch.Size([32, 100]), torch.Size([32, 100]), torch.Size([32, 100]), torch.Size([32, 100])], Embeddings Shape: torch.Size([32, 50, 128])
# Random Timesteps: tensor
24
# Points Shape: [torch.Size([32, 100]), torch.Size([32, 100]), torch.Size([32, 100]), torch.Size([32, 100])], Embeddings Shape: torch.Size([32, 50, 128])
# Random Timesteps: tensor([554,  82, 407, 999, 692, 880, 871, 150, 375, 876, 991, 761, 415, 966,
#          38, 507, 562, 341, 211, 161, 986, 276, 432,  36, 610, 465, 126, 402,
#         741, 513, 926, 930])
# Batch 18/24
# Points Shape: [torch.Size([32, 100]), torch.Size([32, 100]), torch.Size([32, 100]), torch.Size([32, 100])], Embeddings Shape: torch.Size([32, 50, 128])
# Random Timesteps: tensor([950, 342, 640, 535, 228, 379, 971, 123, 114, 943, 818, 504,   9, 622,
#         566, 313, 355, 481, 323, 183, 153, 562, 568,  41,  81,  74, 869, 274,
#         653, 216, 700, 573])
# Batch 19/24
# Points Shape: [torch.Size([32, 100]), torch.Size([32, 100]), torch.Size([32, 100]), torch.Size([32, 100])], Embeddings Shape: torch.Size([32, 50, 128])
# Random Timesteps: tensor([850,   6, 742, 403, 290, 759,  48, 843, 272, 790, 931, 419, 840, 873,
#         420,  66, 695,  22, 628,   6, 910, 466,  66, 441, 649, 103, 218, 665,
#         186, 637, 802, 942])
# Batch 20/24
# Points Shape: [torch.Size([32, 100]), torch.Size([32, 100]), torch.Size([32, 100]), torch.Size([32, 100])], Embeddings Shape: torch.Size([32, 50, 128])
# Random Timesteps: tensor([722,  45, 559, 841, 504, 704,  48,  21, 834, 189, 415, 770,   9, 287,
#         988, 800,  76, 525, 687, 772,  25, 681,  31, 209, 158, 168, 998, 434,
#         478, 573, 980, 672])
# Batch 21/24
# Points Shape: [torch.Size([32, 100]), torch.Size([32, 100]), torch.Size([32, 100]), torch.Size([32, 100])], Embeddings Shape: torch.Size([32, 50, 128])
# Random Timesteps: tensor([261, 583, 179, 986, 318, 317, 166, 301, 718, 636, 726, 300, 828, 925,
#         936, 416,  77, 670,  29, 540, 633, 163, 422, 714, 797, 746, 399, 941,
#           1, 776, 824, 259])
# Batch 22/24
# Points Shape: [torch.Size([32, 100]), torch.Size([32, 100]), torch.Size([32, 100]), torch.Size([32, 100])], Embeddings Shape: torch.Size([32, 50, 128])
# Random Timesteps: tensor([362, 311,  76, 212, 242, 984, 279, 943, 684, 288,  74, 332, 178, 669,
#         492, 763, 949, 676, 386, 627, 980, 756, 654, 456, 179, 624, 928,  25,
#           8, 610, 975, 290])
# Batch 23/24
# Points Shape: [torch.Size([32, 100]), torch.Size([32, 100]), torch.Size([32, 100]), torch.Size([32, 100])], Embeddings Shape: torch.Size([32, 50, 128])
# Random Timesteps: tensor([561, 123, 506, 769, 299, 593, 999, 122,  68, 535, 568, 378, 723, 665,
#          37, 439, 735, 737, 733, 792, 272, 456,  33, 924, 820, 504, 674, 462,
#          15, 713, 709, 198])
# Batch 24/24
# Points Shape: [torch.Size([11, 100]), torch.Size([11, 100]), torch.Size([11, 100]), torch.Size([11, 100])], Embeddings Shape: torch.Size([11, 50, 128])
# Random Timesteps: tensor([724, 871, 106, 595, 955,  18, 965, 328, 199, 536, 773])
# Epoch 30, Loss: 0.7418699388702711
# Validation Loss: 0.8088206291198731

# %%
# Dummy Data
train_data = [
        {
            "formula_human_readable": "var_0 + var_1",
            "points": {
                "var_0": [0.1, 0.2, 0.3],
                "var_1": [0.4, 0.5, 0.6],
                "target": [0.5, 0.7, 0.9]
            },
        },
        {
            "formula_human_readable": "var_0 * var_1",
            "points": {
                "var_0": [0.2, 0.4, 0.6],
                "var_1": [0.1, 0.3, 0.5],
                "target": [0.02, 0.12, 0.3]
            },
        },
    ]


vocab_size = len(tokenizer)
embedding_dim = 128
max_length = 10

    # Precompute embeddings
precomputed_train = precompute_embeddings_with_targets(train_data, normalized_train, tokenizer_func, vocab_size, embedding_dim, max_length)

    # Initialize diffusion model and noise scheduler
hidden_dim = 256
diffusion_model = DiffusionModel(embedding_dim, hidden_dim)
timesteps = 1000
scheduler = NoiseScheduler(timesteps)

    # Training setup
optimizer = torch.optim.Adam(diffusion_model.parameters(), lr=1e-3)
criterion = nn.MSELoss()

    # Training loop
for epoch in range(10):  # Number of epochs
        total_loss = 0
        for points, embedding, target in precomputed_train:
            t = torch.randint(0, timesteps, (1,))  # Random timestep

            # Add noise to embeddings and targets
            x_t, noise = scheduler.add_noise(embedding, t)
            target_t, target_noise = scheduler.add_noise(torch.tensor(target, dtype=torch.float32), t)

            # Predict noise
            pred_noise = diffusion_model(x_t, t)

            # Compute loss
            loss = criterion(pred_noise, target_noise)
            total_loss += loss.item()
# Backpropagation
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

        # Print epoch loss
        print(f"Epoch {epoch + 1}, Loss: {total_loss / len(precomputed_train):.4f}")

# %%
def generate_formula_from_points(model, diffusion, tokenizer, test_points, timesteps=1000, embedding_dim=128):
    """
    Generate a formula from input points using the trained diffusion model.
    Args:
        - model: Trained diffusion model.
        - diffusion: Diffusion process instance.
        - tokenizer: Tokenizer for decoding formula embeddings.
        - test_points: Tensor of points [batch_size, num_points, num_vars].
        - timesteps: Number of timesteps in the diffusion process.
        - embedding_dim: Dimension of the formula embeddings.
    Returns:
        - Generated formula (decoded from the embedding).
    """
    model.eval()
    with torch.no_grad():
        # Initialize random noisy embedding
        batch_size, num_points, num_vars = test_points.shape
        noisy_embedding = torch.randn(batch_size, embedding_dim)  # Shape: [batch_size, embedding_dim]

        # Reverse diffusion process
        for t in reversed(range(timesteps)):
            # Prepare timestep tensor
            t_tensor = torch.tensor([t] * batch_size, dtype=torch.long)  # Shape: [batch_size]

            # Predict noise and denoise
            pred_noise = model(noisy_embedding.unsqueeze(1), t_tensor)  # Add sequence dimension if needed
            alpha_t = diffusion.alpha_cumprod[t].sqrt()
            beta_t = (1 - diffusion.alpha_cumprod[t]).sqrt()
            noisy_embedding = (noisy_embedding - beta_t * pred_noise.squeeze(1)) / alpha_t

        # Decode the final embedding
        final_embedding = noisy_embedding.squeeze(0)  # Remove batch dimension if needed
        print(f"Final Embedding Shape: {final_embedding.shape}")  # Debugging shape
        print(f"Final Embedding Values: {final_embedding}")

        # Handle possible single-dimensional embedding
        if final_embedding.dim() == 1:
            final_embedding = final_embedding.unsqueeze(0)

        # Generate tokens (ensure this produces a sequence of token IDs)
        generated_tokens = torch.argmax(final_embedding, dim=-1)  # Token indices (sequence)
        print(f"Generated Tokens: {generated_tokens}")

        # Ensure `generated_tokens` is converted to a list
        if isinstance(generated_tokens, torch.Tensor):
            generated_tokens = generated_tokens.tolist()
        if not isinstance(generated_tokens, list):
            raise ValueError("Generated tokens are not converted to a list correctly")

        # Decode tokens into formula
        formula = tokenizer.decode(generated_tokens)

    return formula

# %%
# Initialize the diffusion process
timesteps = 1000
betas, alpha_cumprod = noise_schedule(timesteps)
diffusion = Diffusion(
    model=trained_model,
    betas=betas,
    alpha_cumprod=alpha_cumprod,
    timesteps=timesteps
)

# Prepare test points dynamically based on available variables
test_sample = test[0]  # Assume you want to generate a formula for the first test sample

# Extract all variables from the test sample's points
test_points = torch.tensor(
    [test_sample["points"][var_name] for var_name in test_sample["points"].keys()],
    dtype=torch.float32
).permute(1, 0)  # Shape: [num_points, num_vars]


# Add a batch dimension
test_points = test_points.unsqueeze(0)  # Shape: [batch_size=1, num_points, num_vars]
# Generate the formula using the trained model
generated_formula = generate_formula_from_points(
    model=trained_model,
    diffusion=diffusion,
    tokenizer=tokenizer,
    test_points=test_points,
    timesteps=timesteps,
    embedding_dim=128
)

print("Generated Formula:", generated_formula)
# Out:
# tensor([[[-0.7995, -4.5013,  0.3758,  1.4940],
#          [ 2.0476,  0.7573, -4.2495, -1.5227],
#          [-2.0467,  3.4944,  3.7023,  5.3250],
#          [-3.9617,  3.5842,  1.2609,  6.7068],
#          [ 1.0098, -4.4722, -2.1025,  0.9404],
#          [-2.4049,  2.1883,  2.5770,  4.2106],
#          [-1.4915, -4.6379,  2.0217,  4.0208],
#          [ 1.8481, -1.7090,  3.6834, -0.5564],
#          [ 2.1821, -2.2918,  0.5333, -2.4133],
#          [-0.0689, -2.5810, -3.8520,  2.6486],
#          [-4.4660,  1.8132, -4.1209,  7.2646],
#          [-1.8492, -4.6484,  1.6990,  4.2383],
#          [ 4.9174,  3.6242, -0.8887, -5.5131],
#          [-0.5731,  4.1466, -3.1705,  3.4813],
#          [-1.6938, -0.9856,  4.6556,  3.9295],
#          [-2.1024,  4.2126, -3.3647,  5.4208],
#          [-4.3650,  1.8480, -2.4453,  8.1548],
#          [ 1.0649, -0.9851,  0.1692, -3.1668],
#          [ 3.0727,  0.5860, -1.5146, -4.4722],
#          [-1.8288,  0.4510, -1.5192,  1.9894],
#          [-4.2670,  1.9117, -1.0972,  6.0042],
#          [-1.3416, -0.0701,  2.5734, -0.0830],
#          [-3.1274, -3.8262, -0.4479,  4.5800],
#          [ 2.4554,  2.4162,  1.2116, -1.9561],
#          [-2.8091,  0.4047,  4.0686,  4.1781],
#          [-3.8981,  2.4864, -0.0262,  2.3018],
#          [-2.3295, -0.8959,  0.8707,  2.9840],
#          [-0.8321, -2.2908,  1.1895,  2.1570],
#          [ 0.2301, -0.4168, -4.3702,  0.3063],
#          [-4.0560, -0.0968,  2.8326,  3.7777],
#          [ 3.4755, -3.6037,  1.7060, -2.7385],
#          [ 3.6079, -0.2874,  5.0444, -4.3620],
#          [-0.9539, -1.4246, -0.5761,  0.9119],
#          [ 2.4284,  3.6939,  1.9870, -0.9413],
#          [-0.3022,  1.2315,  3.4364,  1.9325],
#          [-3.6925, -3.5128,  0.5643,  5.1336],
#          [ 1.9253,  3.1348, -4.7447,  0.1395],
#          [-3.4601,  0.7748, -3.5477,  5.8741],
#          [ 2.6151, -4.8288,  1.5486, -1.0935],
#          [ 0.6514, -2.8742,  3.3474,  1.3997],
#          [-0.4952, -0.8501,  1.0965,  0.5363],
#          [-3.9787, -3.4037, -4.5529,  7.2713],
#          [ 0.6064, -3.7434,  4.7259,  2.1582],
#          [-2.9051,  1.0791, -1.2054,  3.6479],
#          [ 3.1530,  1.8439,  2.0024, -2.7960],
#          [ 3.5902, -2.2518, -2.8698, -2.6723],
#          [ 4.9123,  3.7875,  3.7774, -3.7305],
#          [-2.6744, -0.4743, -0.5850,  2.1382],
#          [-3.1087, -0.8415, -3.6120,  4.8569],
#          [ 2.6976,  1.2085,  2.3228, -2.3188],
#          [ 2.7980,  1.7899,  2.9339, -2.0207],
#          [ 3.1576, -2.0868,  1.2220, -3.2344],
#          [ 4.6988,  0.8575,  3.9918, -4.5993],
#          [-1.4704, -0.4209, -3.1242,  2.2219],
#          [ 4.1786, -1.8555, -0.7947, -5.0017],
#          [ 4.7048,  0.1948, -0.1210, -9.9099],
#          [ 0.7137,  0.4842,  2.7554, -0.6410],
#          [ 3.0662,  4.3282,  3.4630, -1.2958],
#          [-4.5823, -2.6017,  4.7332,  8.3023],
#          [ 1.4921, -1.9138, -3.2825, -0.0835],
#          [-1.2140,  2.7920,  1.9853,  3.3729],
#          [ 1.1114, -4.7311, -3.7334,  1.5372],
#          [ 3.4274, -3.0081, -4.7391, -1.6468],
#          [ 3.7949,  1.1227,  4.6856, -3.0228],
#          [ 0.8114,  4.2512,  2.4697,  1.3251],
#          [-4.8043, -3.7431,  0.6253,  7.3439],
#          [ 0.2347,  1.6062, -0.7096, -0.1750],
#          [-0.8145, -2.6193,  4.5099,  3.3583],
#          [ 0.5974, -0.0491,  4.1168, -2.2719],
#          [-0.1915, -2.6059, -0.3121,  0.0510],
#          [-4.5322,  0.6842,  2.8689,  5.8359],
#          [ 4.7033, -2.5636,  2.1888, -4.5478],
#          [-3.6685,  0.6817,  0.0696,  1.7287],
#          [-3.3473, -2.3138, -4.3396,  6.3660],
#          [-1.9371,  1.3167, -2.7560,  3.6370],
#          [ 3.8857, -4.7816, -4.9060, -1.7521],
#          [ 4.1225,  3.4745, -0.9055, -4.1048],
#          [ 3.7981, -0.1626, -3.5729, -5.5851],
#          [-3.7940,  1.8641,  2.6411,  6.4185],
#          [ 2.2278,  3.1913, -1.4718, -1.1197],
#          [-4.7023, -4.2929, -1.4569,  8.2820],
#          [ 3.3242,  2.3260,  2.9016, -2.5183],
#          [ 0.8308, -3.1331, -2.6571,  1.0994],
#          [ 2.2251,  2.9723, -1.4101, -1.4349],
#          [ 0.9698, -4.6604, -2.4795,  1.3176],
#          [ 2.4285,  2.0447, -1.6650, -2.0832],
#          [ 1.8377, -4.1180, -4.4219,  0.5986],
#          [-2.8377, -2.7423, -1.1991,  4.6377],
#          [-4.9031,  4.2346, -0.4059,  6.4234],
#          [-4.4135,  4.7301,  2.0114,  7.4467],
#          [ 3.4238,  3.6834, -4.3658, -1.7001],
#          [-1.5618, -0.0352, -0.8431, -1.5327],
#          [ 1.0727, -0.3176,  1.2418, -2.2659],
#          [-1.0054,  3.1236, -1.8963,  3.2423],
#          [ 0.7387, -2.3748, -3.3310,  1.1521],
#          [ 4.5788,  3.5411, -3.3296, -3.4063],
#          [ 3.4709, -1.7508, -1.6746, -3.3375],
#          [-1.9622,  0.3512,  4.0119,  2.7259],
#          [ 2.2653, -2.6697,  3.6323, -0.7006],
#          [-3.4834, -3.9730,  3.3372,  7.5975]]])
# Final Embedding Shape: torch.Size([128])
# Final Embedding Values: tensor([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan])
# Generated Tokens: tensor([0])
# Generated Formula: ['[PAD]']

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[72], line 1
# ----> 1 print(f"Final Embedding Values: {final_embedding}")
#
# NameError: name 'final_embedding' is not defined
